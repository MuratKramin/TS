# %% [markdown]
# # Проект по временным рядам
# # Выполнил: Крамин Мурат Тимурович, ФТиАД, 1 курс

# %% [markdown]
# # **ПЛАН ПРОЕКТА**
#
# ## **Блок 0. Подготовка данных**
#
# ##  **Блок 1. Генерация признаков для ML**
#
# ##  **Блок 2. Анализ временного ряда `balance` (для ARIMA/SARIMA)**
#
#
# ##  **Блок 3. Построение авторегрессионных моделей**
#
#
# ##  **Блок 4. `tsfresh` как обогащение признаков**
#
#
#
# ## **Блок 5. Отбор признаков (FS) для ML**
#
#
#
# ## **Блок 6. Построение ML моделей**
#
#
#
# ## **Блок 7. Обнаружение разладок (CUSUM)**
#
#
# ##  **Блок 8. Онлайн и Автоматическое переобучение**
#
#
# ---

# %% [markdown]
# # Блок 0. Подготовка данных

# %%
#Установим библиотеки
# %pip install pandas matplotlib openpyxl requests tqdm beautifulsoup4 yfinance scikit-learn seaborn statsmodels pmdarima tsfresh catboost lightgbm optuna bayesian-changepoint-detection
# Out:
# Requirement already satisfied: pandas in d:\programming\ts_project_kramin\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in d:\programming\ts_project_kramin\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: openpyxl in d:\programming\ts_project_kramin\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: requests in d:\programming\ts_project_kramin\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: tqdm in d:\programming\ts_project_kramin\venv\lib\site-packages (4.67.1)
# Requirement already satisfied: beautifulsoup4 in d:\programming\ts_project_kramin\venv\lib\site-packages (4.13.4)
# Requirement already satisfied: yfinance in d:\programming\ts_project_kramin\venv\lib\site-packages (0.2.55)
# Requirement already satisfied: scikit-learn in d:\programming\ts_project_kramin\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: seaborn in d:\programming\ts_project_kramin\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: statsmodels in d:\programming\ts_project_kramin\venv\lib\site-packages (0.14.4)
# Requirement already satisfied: pmdarima in d:\programming\ts_project_kramin\venv\lib\site-packages (2.0.4)
# Requirement already satisfied: tsfresh in d:\programming\ts_project_kramin\venv\lib\site-packages (0.21.0)
# Requirement already satisfied: catboost in d:\programming\ts_project_kramin\venv\lib\site-packages (1.2.8)
# Collecting lightgbm
#   Obtaining dependency information for lightgbm from https://files.pythonhosted.org/packages/5e/23/f8b28ca248bb629b9e08f877dd2965d1994e1674a03d67cd10c5246da248/lightgbm-4.6.0-py3-none-win_amd64.whl.metadata
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: optuna in d:\programming\ts_project_kramin\venv\lib\site-packages (4.3.0)
# Requirement already satisfied: bayesian-changepoint-detection in d:\programming\ts_project_kramin\venv\lib\site-packages (0.2.dev1)
# Requirement already satisfied: numpy>=1.23.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: et-xmlfile in d:\programming\ts_project_kramin\venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\ts_project_kramin\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\ts_project_kramin\venv\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: colorama in d:\programming\ts_project_kramin\venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: multitasking>=0.0.7 in d:\programming\ts_project_kramin\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: frozendict>=2.3.4 in d:\programming\ts_project_kramin\venv\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: scipy>=1.6.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\programming\ts_project_kramin\venv\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: pywavelets in d:\programming\ts_project_kramin\venv\lib\site-packages (from tsfresh) (1.8.0)
# Requirement already satisfied: stumpy>=1.7.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from tsfresh) (1.13.0)
# Requirement already satisfied: cloudpickle in d:\programming\ts_project_kramin\venv\lib\site-packages (from tsfresh) (3.1.1)
# Requirement already satisfied: graphviz in d:\programming\ts_project_kramin\venv\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: plotly in d:\programming\ts_project_kramin\venv\lib\site-packages (from catboost) (6.0.1)
# Requirement already satisfied: six in d:\programming\ts_project_kramin\venv\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: alembic>=1.5.0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in d:\programming\ts_project_kramin\venv\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from optuna) (2.0.40)
# Requirement already satisfied: PyYAML in d:\programming\ts_project_kramin\venv\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in d:\programming\ts_project_kramin\venv\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: greenlet>=1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.0)
# Requirement already satisfied: numba>=0.57.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from stumpy>=1.7.2->tsfresh) (0.61.2)
# Requirement already satisfied: narwhals>=1.15.1 in d:\programming\ts_project_kramin\venv\lib\site-packages (from plotly->catboost) (1.35.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in d:\programming\ts_project_kramin\venv\lib\site-packages (from numba>=0.57.1->stumpy>=1.7.2->tsfresh) (0.44.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in d:\programming\ts_project_kramin\venv\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.5 MB 1.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.5 MB 1.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.5 MB 3.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Извелекаем данные из exel файла

# %%
import pandas as pd

# Путь к файлу
excel_file = 'Project 2_2023.xlsx'

# Загрузка данных с листа "Data"
df = pd.read_excel(excel_file, sheet_name='Data')

# Преобразование даты к формату 'YYYY-MM-DD'
df['Date'] = pd.to_datetime(df['Date']).dt.date
# Преобразование всех названий столбцов в lowercase
df.columns = df.columns.str.lower()

# Удаление старой колонки balance (если она есть)
if 'balance' in df.columns:
    df = df.drop(columns=['balance'])

# Создание новой колонки balance как разности income и outcome
df['balance'] = df['income'] - df['outcome']

# Сохранение в CSV
df.to_csv('data/saldo.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Парсим и сохраняем нерабочие дни из производственного календаря

# %%
import pandas as pd
import datetime
from io import StringIO
import requests

# Диапазон годов
years = range(2016, 2025)

# Список для хранения всех выходных и праздничных дней
holiday_dates = []

# Загружаем календари и собираем выходные
for year in years:
    url = f"https://xmlcalendar.ru/data/ru/{year}/calendar.csv"
    response = requests.get(url)
    response.encoding = 'utf-8'
    df = pd.read_csv(StringIO(response.text))
    
    for idx, row in df.iterrows():
        year_val = int(row['Год/Месяц'])
        for month_num, month_name in enumerate(df.columns[1:13]):
            if pd.isna(row[month_name]):
                continue
            days = str(row[month_name]).split(',')
            for day in days:
                day_clean = day.replace('*', '').replace('+', '')
                if day_clean.isdigit():
                    date = datetime.date(year_val, month_num + 1, int(day_clean))
                    holiday_dates.append(date)

# Создание DataFrame с полным списком дат
full_dates = pd.date_range(start='2016-01-01', end='2024-12-31', freq='D')
calendar_df = pd.DataFrame({'date': full_dates})

# Помечаем нерабочие дни: 1 — нерабочий, 0 — рабочий
calendar_df['is_non_working_day'] = calendar_df['date'].dt.date.isin(holiday_dates).astype(int)

# Сохраняем в CSV
calendar_df.to_csv('data/non_working_days.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Парсим и сохраняем ключевую ставку с сайта ЦБ

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# URL страницы с таблицей
url = 'https://www.cbr.ru/hd_base/KeyRate/?UniDbQuery.Posted=True&UniDbQuery.From=01.01.2016&UniDbQuery.To=17.04.2025'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

# Отправка запроса
response = requests.get(url, headers=headers)
response.encoding = 'utf-8'

# Парсинг HTML
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', class_='data')
rows = table.find_all('tr')

# Сбор данных
data = []
for row in rows[1:]:  # Пропускаем заголовок
    cols = row.find_all('td')
    if len(cols) == 2:
        date_str = cols[0].text.strip()
        rate_str = cols[1].text.strip().replace(',', '.')
        try:
            date = datetime.strptime(date_str, '%d.%m.%Y').strftime('%Y-%m-%d')
            rate = float(rate_str)
            data.append([date, rate])
        except ValueError:
            continue

# Создание DataFrame
df = pd.DataFrame(data, columns=['date', 'rate'])

# Преобразуем 'date' в datetime и задаём индекс
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date').sort_index()

# Создание полного диапазона дат
full_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')

# Заполнение пропущенных дат и перенос последнего значения
df_full = df.reindex(full_range).ffill()

# Сброс индекса и переименование столбца обратно в 'date'
df_full = df_full.reset_index().rename(columns={'index': 'date'})

# Сохранение в CSV
df_full.to_csv('data/key_rate.csv', index=False, encoding='utf-8')

print("Данные сохранены в data/key_rate.csv")

# %% [markdown]
# ### Парсим и сохраняем курс рубля к доллару

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
from tqdm import tqdm
from datetime import datetime, timedelta

def get_usd_rub_cbr(date: datetime):
    url = f"https://www.cbr.ru/scripts/XML_daily.asp?date_req={date.strftime('%d/%m/%Y')}"
    response = requests.get(url)
    root = ET.fromstring(response.content)
    
    for valute in root.findall("Valute"):
        if valute.attrib["ID"] == "R01235":  # USD
            value = valute.find("Value").text
            return float(value.replace(",", "."))
    return None

# Диапазон дат
start_date = datetime(2016, 1, 1)
end_date = datetime(2024, 12, 31)
dates = pd.date_range(start=start_date, end=end_date, freq="D")

# Сбор курсов
records = []
for date in tqdm(dates, desc="Загрузка курсов ЦБ РФ"):
    rate = get_usd_rub_cbr(date)
    records.append({"date": date, "usd_rub": rate})

# DataFrame и сохранение
df = pd.DataFrame(records)
df["usd_rub"] = df["usd_rub"].ffill()  # Заполнение пропусков (выходные)
df["date"] = df["date"].dt.strftime("%Y-%m-%d")
df.to_csv("data/usd_rub_cbr.csv", index=False)
print(" Готово! Курс сохранён в data/usd_rub_cbr.csv")

# %% [markdown]
# ### Скачиваем с сайта (https://investfunds.ru/indexes/224/)
# ### и сохраняем курс золота (Банк России)

# %%
import pandas as pd
from datetime import datetime

# Чтение Excel-файла
df = pd.read_excel("золото-(банк-россии)-(rub).xlsx")

# Переименование столбцов
df.columns = ['date', 'gold_cost_rub']

# Преобразование даты и стоимости
df['date'] = pd.to_datetime(df['date'], dayfirst=True).dt.strftime('%Y-%m-%d')
df['gold_cost_rub'] = df['gold_cost_rub'].astype(str).str.replace(' ', '').str.replace(',', '.').astype(float)

# Полный список дат
start_date = '2016-01-01'
end_date = '2024-12-31'
all_dates = pd.date_range(start=start_date, end=end_date, freq='D').strftime('%Y-%m-%d')
full_df = pd.DataFrame({'date': all_dates})

# Объединение и заполнение пропусков
merged_df = pd.merge(full_df, df, on='date', how='left')
merged_df['gold_cost_rub'] = merged_df['gold_cost_rub'].ffill()

# Сохранение в CSV
merged_df.to_csv('data/gold_price_full.csv', index=False, encoding='utf-8')

print(" Ежедневные данные по золоту сохранены в data/gold_price_full.csv")

# %% [markdown]
# ### Парсим и сохраняем курс нефти Brent

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# Даты
start_date = datetime(2016, 1, 1)
end_date = datetime(2024, 12, 31)

# Скачиваем данные
oil_data = yf.download('BZ=F', start=start_date, end=end_date)
df = oil_data[['Close']].reset_index()
df.columns = ['date', 'brent_cost']
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# Создаём полный список дат
all_dates = pd.date_range(start=start_date, end=end_date, freq='D').strftime('%Y-%m-%d')
full_df = pd.DataFrame({'date': all_dates})

# Объединяем и заполняем пропуски
merged_df = pd.merge(full_df, df, on='date', how='left')
merged_df['brent_cost'] = merged_df['brent_cost'].ffill()

# Сохраняем в CSV
merged_df.to_csv('data/brent_oil_price.csv', index=False, encoding='utf-8')

print(" Ежедневные данные по нефти сохранены в data/brent_oil_price.csv")

# %% [markdown]
# ### Парсим и сохраняем АРХИВ ЗНАЧЕНИЙ MOSPRIME

# %%
import pandas as pd
import numpy as np
from io import StringIO
import requests

# Заданный диапазон дат
start_date = '2016-01-01'
end_date = '2024-12-31'

# URL для запроса
url = f"https://mosprime.com/archive?date_from={start_date}&date_to={end_date}&format=csv&contributor="

# Запрос и загрузка
response = requests.get(url)
response.encoding = 'cp1251'
content = response.text

# Пропускаем лишние строки до заголовка таблицы
lines = content.splitlines()
table_start_idx = next(i for i, line in enumerate(lines) if "Дата ставки" in line)
clean_csv = "\n".join(lines[table_start_idx:])

# Читаем CSV
df = pd.read_csv(StringIO(clean_csv), sep=";", engine='python')
df.rename(columns={"Дата ставки": "date"}, inplace=True)

# Преобразуем дату в datetime
df["date"] = pd.to_datetime(df["date"], dayfirst=True)

# Обработка пропусков и преобразование в float
for col in df.columns[1:]:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(",", ".", regex=False)
        .str.replace(" ", "", regex=False)
        .replace({"--": np.nan, "-": np.nan,"–": np.nan, "": np.nan})
        .astype(float)
    )

# Удаляем лишние столбцы, полностью состоящие из NaN
df = df.dropna(axis=1, how='all')

# Устанавливаем индекс и создаём полный диапазон
df = df.set_index("date").sort_index()
full_range = pd.date_range(start=start_date, end=end_date, freq='D')
df = df.reindex(full_range).ffill()

# Сброс индекса обратно в 'date'
df = df.reset_index().rename(columns={"index": "date"})

# Сохранение
df.to_csv("data/mosprime_rates.csv", index=False, encoding="utf-8")

print(" MOSPRIME ставки сохранены в data/mosprime_rates.csv с полным диапазоном дат и ffill()")

# %% [markdown]
# ### Используя нерабочие дни и другие календарные фичи создаём расширенный датасет календарных фич

# %%
import pandas as pd
import numpy as np
import datetime

# Загрузка файла с нерабочими днями
calendar_df = pd.read_csv('data/non_working_days.csv')
calendar_df['date'] = pd.to_datetime(calendar_df['date'])

# Создание базового календарного DataFrame
start_date = calendar_df['date'].min()
end_date = calendar_df['date'].max()
full_dates = pd.date_range(start=start_date, end=end_date, freq='D')
features = pd.DataFrame(index=full_dates)
features.index.name = 'date'

# Признак: нерабочий день
calendar_df.set_index('date', inplace=True)
features['is_non_working_day'] = calendar_df['is_non_working_day'].reindex(features.index, fill_value=0)

# Признаки: день недели (английские названия)
for day in features.index.day_name().unique():
    features[f'day_{day}'] = (features.index.day_name() == day).astype(int)

# Признаки: месяц (английские названия)
for month in features.index.month_name().unique():
    features[f'month_{month}'] = (features.index.month_name() == month).astype(int)

# Признаки: начало и конец месяца
features['is_start_of_month'] = features.index.is_month_start.astype(int)
features['is_end_of_month'] = features.index.is_month_end.astype(int)

# Признак: последний день месяца
last_days = features.index.to_series().groupby([features.index.year, features.index.month]).max()
features['is_last_day_of_month'] = features.index.isin(last_days.values).astype(int)

# Признаки: годы
for year in features.index.year.unique():
    features[f'year_{year}'] = (features.index.year == year).astype(int)

# 🎯 Формальные признаки налоговых дат
features['tax_vat_payment_due'] = ((features.index.day == 20) & (features.index.month.isin([1, 4, 7, 10]))).astype(int)  # НДС
features['tax_income_payment_due'] = ((features.index.day == 20) & (features.index.month.isin([1, 2, 3, 4]))).astype(int)  # Прибыль
features['tax_unified_social_payment_due'] = ((features.index.day == 30) & (features.index.month == 4)).astype(int)  # ЕССС
features['tax_all_payment_due'] = ((features.index.day == 28)).astype(int)  # Условный all-tax
features['tax_annual_payment_due'] = ((features.index.day == 1) & (features.index.month == 12)).astype(int)  # Годовая уплата

# 🎉 Признаки фиксированных праздников (просто и читаемо)
fixed_holidays = {
    'New_Year': [(1, d) for d in range(1, 9)],
    'Defender_of_Fatherland_Day': [(2, 23)],
    'International_Womens_Day': [(3, 8)],
    'Labour_Day': [(5, 1)],
    'Victory_Day': [(5, 9)],
    'Russia_Day': [(6, 12)],
    'Unity_Day': [(11, 4)],
}

features['is_official_holiday'] = 0
for _, dates in fixed_holidays.items():
    for month, day in dates:
        features['is_official_holiday'] |= ((features.index.month == month) & (features.index.day == day)).astype(int)

# Признаки: особые дни конца декабря
for day in range(27, 32):
    features[f'is_december_{day}'] = ((features.index.month == 12) & (features.index.day == day)).astype(int)

# Признаки: предрабочий и послерабочий день
# features['is_pre_non_working_day'] = features['is_non_working_day'].shift(-1, fill_value=0)
# features['is_post_non_working_day'] = features['is_non_working_day'].shift(1, fill_value=0)

# Признаки: предпраздничный и послепраздничный день
features['is_pre_holiday'] = features['is_official_holiday'].shift(-1, fill_value=0)
features['is_post_holiday'] = features['is_official_holiday'].shift(1, fill_value=0)

# Сброс индекса и сохранение
features.reset_index(inplace=True)
features.to_csv('data/calendar_features_full.csv', index=False, encoding='utf-8')

print(" Обновлённый календарь с фичами сохранён в 'data/calendar_features_full.csv'")

# %% [markdown]
# ## Обоснование почему были добавлены именно такие фичи:

# %% [markdown]
# ### Объединяем все полученные данные в один датасет

# %%
import pandas as pd

# Загрузка датасетов из папки data
saldo = pd.read_csv('data/saldo.csv', parse_dates=['date'])
calendar = pd.read_csv('data/calendar_features_full.csv', parse_dates=['date'])
brent = pd.read_csv('data/brent_oil_price.csv', parse_dates=['date'])
gold = pd.read_csv('data/gold_price_full.csv', parse_dates=['date'])
usd = pd.read_csv('data/usd_rub_cbr.csv', parse_dates=['date'])
key_rate = pd.read_csv('data/key_rate.csv', parse_dates=['date'])
mosprime = pd.read_csv('data/mosprime_rates.csv', parse_dates=['date'])

# Объединение всех таблиц по дате (left join от saldo)
df = saldo.merge(calendar, on='date', how='left')
df = df.merge(brent, on='date', how='left')
df = df.merge(gold, on='date', how='left')
df = df.merge(usd, on='date', how='left')
df = df.merge(key_rate, on='date', how='left')
df = df.merge(mosprime, on='date', how='left')

# Просмотр первых строк
print(df.head())

# Сохранение объединённого датасета
df.to_csv('data/merged_dataset.csv', index=False)
# Out:
#         date    income   outcome   balance  is_non_working_day  day_Friday  \
# 0 2017-01-09  1.343028  1.487865 -0.144836                   0           0
# 1 2017-01-10  1.068610  1.194182 -0.125572                   0           0
# 2 2017-01-11  0.944429  0.936663  0.007767                   0           0
# 3 2017-01-12  1.672202  0.875379  0.796823                   0           0
# 4 2017-01-13  0.955924  0.975645 -0.019721                   0           1
#
#    day_Saturday  day_Sunday  day_Monday  day_Tuesday  ...  gold_cost_rub  \
# 0             0           0           1            0  ...        2260.43
# 1             0           0           0            1  ...        2264.82
# 2             0           0           0            0  ...        2280.67
# 3             0           0           0            0  ...        2297.00
# 4             0           0           0            0  ...        2308.20
#
#    usd_rub  rate     ON     1W     2W     1M     2M     3M     6M
# 0  60.6569  10.0  10.46  10.44  10.47  10.52  10.58  10.58  10.58
# 1  59.8961  10.0  10.21  10.40  10.48  10.53  10.59  10.59  10.59
# 2  59.9533  10.0  10.23  10.40  10.48  10.53  10.59  10.59  10.59
# 3  60.1614  10.0  10.23  10.42  10.48  10.53  10.59  10.59  10.59
# 4  59.4978  10.0  10.27  10.40  10.45  10.51  10.58  10.59  10.59
#
# [5 rows x 60 columns]

# %% [markdown]
# # **Блок 1. Генерация признаков для ML**

# %% [markdown]
# ### Добавим в объединённый датасет лаги и скользящие различного рода

# %%
import pandas as pd

df = pd.read_csv('data/merged_dataset.csv', parse_dates=['date'])
df = df.sort_values('date').set_index('date')

target_columns = [
    'balance', 'income', 'outcome', 'brent_cost', 'gold_cost_rub',
    'usd_rub', 'rate', 'ON', '1W', '2W', '1M', '2M', '3M', '6M'
]

lags = [1, 2, 3]
rolling_windows = [3, 7]

lag_features = []
rolling_features = []

# Создаем лаги
for col in target_columns:
    for lag in lags:
        lag_features.append(df[col].shift(lag).rename(f'{col}_lag{lag}'))

# Создаем rolling с shift(1)
for col in target_columns:
    shifted = df[col].shift(1)
    for window in rolling_windows:
        rolling_features.append(shifted.rolling(window).mean().rename(f'{col}_rollmean{window}'))
        rolling_features.append(shifted.rolling(window).std().rename(f'{col}_rollstd{window}'))
        rolling_features.append(shifted.rolling(window).min().rename(f'{col}_rollmin{window}'))
        rolling_features.append(shifted.rolling(window).max().rename(f'{col}_rollmax{window}'))
        rolling_features.append(shifted.rolling(window).median().rename(f'{col}_rollmed{window}'))

# Объединяем всё за один раз — это быстро
new_features = pd.concat(lag_features + rolling_features, axis=1)

# Добавляем к исходному фрейму
df_final = pd.concat([df, new_features], axis=1).reset_index()

# Удаляем строки с NaN (на старте ряда)
df_final = df_final.dropna().reset_index(drop=True)


# Сохраняем без удаления NaN
df_final.to_csv('data/merged_dataset_with_lags_rollings.csv', index=False)
print(" Готово! Датасет с лагами и скользящими средними сохранён в 'data/merged_dataset_with_lags_rollings.csv'")
# Out:
#  Готово! Датасет с лагами и скользящими средними сохранён в 'data/merged_dataset_with_lags_rollings.csv'

# %% [markdown]
# ## Почему были добавленны данные фичи обоснование:

# %% [markdown]
# # **Блок 1.2. Построение метрик для оценок моделей**

# %%
from sklearn.metrics import mean_absolute_error

def mae_cust(y_true, y_pred, key_rate):
    return mean_absolute_error(y_true, y_pred)

def calculate_add_margin_vectorized(y_true, y_pred, cbr_key_rate,
                                     profit_rate_diff=0.5, on_deposit_rate_diff=-0.9, on_loan_rate_diff=1.0, period=1):
    r_der = (cbr_key_rate + profit_rate_diff) / 100 / 365 * period
    r_dep = (cbr_key_rate + on_deposit_rate_diff) / 100 / 365 * period
    r_bor = (cbr_key_rate + on_loan_rate_diff) / 100 / 365 * period

    pred_income = np.where(y_pred > 0, y_pred * r_der, 0)
    base_income = np.where(y_true > 0, y_true * r_dep, 0)
    mistake_penalty = np.where((y_pred > y_true) & (y_true > 0), (y_pred - y_true) * r_bor, 0)

    delta_margin = pred_income - base_income - mistake_penalty
    return np.mean(delta_margin)

def normalized_add_margin(y_true, y_pred, cbr_key_rate):
    balance_reference = np.mean(y_true)
    raw_margin = calculate_add_margin_vectorized(y_true, y_pred, cbr_key_rate)
    return raw_margin / abs(balance_reference+0.000000000001) * 100

def calculate_total_add_margin(y_pred, y_true, key_rate,
                                profit_rate_diff=0.5, deposit_rate_diff=-0.9, loan_rate_diff=1.0, period=1):
    r_der = (key_rate + profit_rate_diff) / 100 / 365 * period
    r_dep = (key_rate + deposit_rate_diff) / 100 / 365 * period
    r_bor = (key_rate + loan_rate_diff) / 100 / 365 * period

    model_profit = y_pred * r_der
    base_strategy_profit = y_true * r_dep
    excess = np.maximum(y_pred - y_true, 0)
    excess_penalty = excess * r_bor
    add_margin = model_profit - base_strategy_profit - excess_penalty

    return np.sum(add_margin)

def awmae(y_true, y_pred, key_rate, r_der_add=0.005, r_dep_diff=-0.009, r_bor_add=0.01):
    w_def = key_rate + r_bor_add - (key_rate + r_der_add)
    w_sur = (key_rate + r_der_add) - (key_rate + r_dep_diff)
    err = y_true - y_pred
    loss = np.where(err > 0, w_def * err, w_sur * (-err))
    return np.mean(loss)

def delta_pnl(y_true, y_pred, key_rate, r_der_add=0.005, r_dep_diff=-0.009, r_bor_add=0.01):
    r_der = key_rate + r_der_add
    r_dep = key_rate + r_dep_diff
    r_bor = key_rate + r_bor_add

    pnl_pred = np.where(y_pred >= 0,
                        y_pred * r_der + np.where(y_true >= y_pred,
                                                  (y_true - y_pred) * r_dep,
                                                  (y_true - y_pred) * r_bor),
                        y_pred * r_bor + np.where(y_true >= y_pred,
                                                  y_true * r_dep,
                                                  y_true * r_bor))

    pnl_ideal = np.where(y_true >= 0,
                         y_true * r_der,
                         y_true * r_bor)

    return np.mean(pnl_pred - pnl_ideal)

# %% [markdown]
# ## Обоснование выбора метрик:
# ### Что считают мои метрики и зачем они нужны бизнесу:
#
#
# **1. `calculate_add_margin_vectorized`**
# - **Что считает:** Среднюю дополнительную прибыль, которую можно было бы заработать, если бы использовать прогноз вместо базовой стратегии размещения средств (размещения остатка в ЦБ под ставку ниже рыночной).
# - **Экономический смысл:** Эта метрика напрямую отвечает на вопрос заказчика: сколько денег в среднем можно дополнительно заработать за день благодаря использованию модели. Она учитывает не только доход от правильных прогнозов, но и штраф за излишний оптимизм (если спрогнозировали слишком большой приток, а в реальности пришло меньше).
#
# **2. `normalized_add_margin`**
# - **Что считает:** Относительную дополнительную маржу (в процентах от референсного объёма баланса).
# - **Экономический смысл:** Иногда абсолютная дополнительная прибыль может быть не слишком наглядной. Нормализация позволяет понять эффективность модели относительно типичных объёмов — например, зарабатываем мы +0.2% или +1% от среднего объёма. Это важно для оценки масштаба влияния модели на бизнес в процентах, а не в абсолютных рублях.
#
# **3. `calculate_total_add_margin`**
# - **Что считает:** Полную сумму дополнительной маржи за весь период расчёта.
# - **Экономический смысл:** Бизнес смотрит не только на средние цифры, но и на итоговую сумму заработка за месяц, квартал, год. Эта метрика позволяет сразу понять: принесла ли модель ощутимую выгоду или осталась "в нулях" после учёта всех корректировок и штрафов.
#
# **4. `awmae` (Asymmetric Weighted MAE)**
# - **Что считает:** Среднюю абсолютную ошибку, но с разным весом для ошибок в сторону дефицита и профицита.
# - **Экономический смысл:** Ошибки в разные стороны стоят бизнесу по-разному: дефицит ликвидности дороже профицита, потому что займ под ключ+1% дороже потерь доходности при размещении профицита. Поэтому в `awmae` штраф за дефицит больше, чем за лишние деньги на счетах. Такая метрика лучше соответствует реальным потерям банка.
#
# **5. `delta_pnl`**
# - **Что считает:** Среднюю разницу между реальным результатом операций при использовании прогноза и идеальным вариантом (если бы мы заранее знали фактические потоки).
# - **Экономический смысл:** Это модельная оценка: насколько близко модель позволяет приблизиться к максимальной возможной прибыли. Иначе говоря, сколько прибыли теряется из-за ошибок модели — с учётом реальных процентных ставок по размещению, заимствованию и альтернативным операциям.

# %% [markdown]
# # **Блок 2. Анализ временного ряда `balance`**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# Загружаем датасет
df = pd.read_csv('data/merged_dataset_with_lags_rollings.csv', parse_dates=['date'])
df = df.sort_values('date').set_index('date')

# Выбираем целевой ряд
y = df['balance'].dropna()

# === 1. Визуализация временного ряда ===
plt.figure(figsize=(14, 5))
plt.plot(y, label='Balance')
plt.title("Исходный временной ряд: Balance")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# 1. Получаем первую разность
y_diff = y.diff().dropna()

# 2. Визуализация
plt.figure(figsize=(14, 4))
plt.plot(y_diff, label='Первая разность')
plt.title('Первая разность временного ряда')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 5))
# === 2. Сезонная декомпозиция ===
decompose_result = seasonal_decompose(y, model='additive', period=7)  # период 7 — для недельной сезонности
decompose_result.plot()
plt.suptitle("Сезонная декомпозиция: additive (period=7)")
plt.tight_layout()
plt.show()

# === 3. ADF-тест на стационарность ===
def adf_test(series):
    result = adfuller(series.dropna())
    print("\n ADF-тест:")
    print(f"  Test statistic: {result[0]:.4f}")
    print(f"  p-value       : {result[1]:.4f}")
    for key, value in result[4].items():
        print(f"  Critical Value {key}: {value:.4f}")
    if result[1] < 0.05:
        print("Ряд стационарен (отвергаем H₀)")
    else:
        print("Ряд НЕстационарен (не отвергаем H₀)")

adf_test(y)

# === 4. KPSS-тест ===
from statsmodels.tsa.stattools import kpss

def kpss_test(series):
    statistic, p_value, _, crit_vals = kpss(series.dropna(), regression='c', nlags="auto")
    print("\n KPSS-тест:")
    print(f"  Test statistic: {statistic:.4f}")
    print(f"  p-value       : {p_value:.4f}")
    for key, value in crit_vals.items():
        print(f"  Critical Value {key}: {value:.4f}")
    if p_value < 0.05:
        print("Ряд НЕстационарен (отвергаем H₀)")
    else:
        print("Ряд стационарен (не отвергаем H₀)")

kpss_test(y)

# === 5. ACF/PACF на оригинальном ряде ===
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
plot_acf(y, ax=axes[0], lags=50)
axes[0].set_title("ACF: Original series")
plot_pacf(y, ax=axes[1], lags=50)
axes[1].set_title("PACF: Original series")
plt.tight_layout()
plt.show()

# === 6. Анализ дифференцированного ряда ===
y_diff = y.diff().dropna()

# ADF/KPSS на разностях
print("\n📉 Дифференцирование (diff(1)) — анализ:")
adf_test(y_diff)
kpss_test(y_diff)

# ACF/PACF на diff
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
plot_acf(y_diff, ax=axes[0], lags=50)
axes[0].set_title("ACF: Diff(1)")
plot_pacf(y_diff, ax=axes[1], lags=50)
axes[1].set_title("PACF: Diff(1)")
plt.tight_layout()
plt.show()

# === 7. Дополнительно: дифференцирование с лагом 7 (для недельной сезонности) ===
y_diff7 = y.diff(7).dropna()

# ACF/PACF для diff(7)
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
plot_acf(y_diff7, ax=axes[0], lags=50)
axes[0].set_title("ACF: Diff(7)")
plot_pacf(y_diff7, ax=axes[1], lags=50)
axes[1].set_title("PACF: Diff(7)")
plt.tight_layout()
plt.show()

# Можно дополнительно посмотреть std/mean по неделям и месяцам
df['weekday'] = df.index.dayofweek
df['month'] = df.index.month
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.boxplot(data=df, x='weekday', y='balance', ax=axes[0])
axes[0].set_title("Распределение balance по дням недели")
sns.boxplot(data=df, x='month', y='balance', ax=axes[1])
axes[1].set_title("Распределение balance по месяцам")
plt.tight_layout()
plt.show()


# =======================
# 4. Проверка на выбросы (Z-оценки)
# =======================
z_scores = np.abs(stats.zscore(y.dropna()))
outliers = y[z_scores > 3]
print(f'Количество выбросов (|Z| > 3): {len(outliers)}')

plt.figure(figsize=(14, 4))
plt.plot(y, label='Balance')
plt.scatter(outliers.index, outliers, color='red', label='Выбросы')
plt.title('Выбросы на временном ряду (Z-score > 3)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# =======================
# 9. Скользящие средние и дисперсия (тренд и гетероскедастичность)
# =======================
rolling_mean = y.rolling(window=7).mean()
rolling_std = y.rolling(window=7).std()

plt.figure(figsize=(14, 4))
plt.plot(y, label='Оригинальный')
plt.plot(rolling_mean, label='Скользящее среднее (7)', color='orange')
plt.plot(rolling_std, label='Скользящая std (7)', color='green')
plt.title('Тренд и изменчивость')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# =======================
# 10. Проверка сезонности (автокорреляции на сезонных лагах)
# =======================
season_lag = 7  # например, недельная
print(f'\nКорреляция с лагом {season_lag}: {y.autocorr(lag=season_lag):.3f}')
print(f'\nКорреляция с лагом {30}: {y.autocorr(lag=30):.3f}')
print(f'\nКорреляция с лагом {365}: {y.autocorr(lag=365):.3f}')

# 5. Скользящее среднее и стандартное отклонение
rolling_mean_diff = y_diff.rolling(window=7).mean()
rolling_std_diff = y_diff.rolling(window=7).std()

plt.figure(figsize=(14, 4))
plt.plot(y_diff, label='Первая разность')
plt.plot(rolling_mean_diff, label='Скользящее среднее', color='orange')
plt.plot(rolling_std_diff, label='Скользящее std', color='green')
plt.title('Первая разность: тренд и дисперсия')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# 6. Проверка на сезонность в первой разности
season_lag = 7
print(f'\nАвтокорреляция первой разности с лагом {season_lag}: {y_diff.autocorr(lag=season_lag):.3f}')
print(f'\nАвтокорреляция первой разности с лагом {30}: {y_diff.autocorr(lag=30):.3f}')

print(f'\nАвтокорреляция первой разности с лагом {365}: {y_diff.autocorr(lag=365):.3f}')
# Out:
# 🧪 ADF-тест:
#   Test statistic: -4.1062
#   p-value       : 0.0009
#   Critical Value 1%: -3.4347
#   Critical Value 5%: -2.8634
#   Critical Value 10%: -2.5678
# ✅ Ряд стационарен (отвергаем H₀)
#
# 🧪 KPSS-тест:
#   Test statistic: 3.0821
#   p-value       : 0.0100
#   Critical Value 10%: 0.3470
#   Critical Value 5%: 0.4630
#   Critical Value 2.5%: 0.5740
#   Critical Value 1%: 0.7390
# ⚠️ Ряд НЕстационарен (отвергаем H₀)
# C:\Users\Mi\AppData\Local\Temp\ipykernel_20780\2282042298.py:66: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   statistic, p_value, _, crit_vals = kpss(series.dropna(), regression='c', nlags="auto")
# 📉 Дифференцирование (diff(1)) — анализ:
#
# 🧪 ADF-тест:
#   Test statistic: -14.7072
#   p-value       : 0.0000
#   Critical Value 1%: -3.4347
#   Critical Value 5%: -2.8634
#   Critical Value 10%: -2.5678
# ✅ Ряд стационарен (отвергаем H₀)
#
# 🧪 KPSS-тест:
#   Test statistic: 0.0454
#   p-value       : 0.1000
#   Critical Value 10%: 0.3470
#   Critical Value 5%: 0.4630
#   Critical Value 2.5%: 0.5740
#   Critical Value 1%: 0.7390
# ✅ Ряд стационарен (не отвергаем H₀)
# C:\Users\Mi\AppData\Local\Temp\ipykernel_20780\2282042298.py:66: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistic, p_value, _, crit_vals = kpss(series.dropna(), regression='c', nlags="auto")
# Количество выбросов (|Z| > 3): 33
# Корреляция с лагом 7: 0.281
#
# Корреляция с лагом 30: 0.064
#
# Корреляция с лагом 365: 0.063
# Автокорреляция первой разности с лагом 7: 0.184
#
# Автокорреляция первой разности с лагом 30: -0.003
#
# Автокорреляция первой разности с лагом 365: -0.004

# %% [markdown]
# ## Выводы по итогам анализа ряда
#
# ## 1. Общая характеристика
# - Ряд содержит **1543 наблюдения**, пропусков нет.
# - Среднее значение около нуля (**-0.048**), медиана тоже **0.0** — тренд в целом отсутствует.
# - Диапазон значений достаточно широкий: от **-2.51** до **1.41**, при этом стандартное отклонение небольшое (**0.29**), что говорит о средней волатильности.
# - Распределение немного скошено в сторону отрицательных значений.
#
# ## 2. Наличие сезонности и тренда
# - Декомпозиция показала, что:
#   - Тренд минимальный (**-0.05**),
#   - Сезонная компонента стабильная (**стандартное отклонение 0.08**),
#   - Остатки более шумные (**стандартное отклонение 0.25**).
# - Это указывает на то, что в ряде есть **неделяная сезонность**, но она выражена умеренно. Основные колебания объясняются случайными факторами.
#
# ## 3. Стационарность
# - По результатам ADF-теста можно считать, что ряд стационарный.
# - KPSS-тест, напротив, говорит о наличии нестабильности.
# - Такое расхождение между тестами обычно возникает в случаях слабого тренда или сезонности. Это подтверждается наблюдаемой недельной структурой в данных.
#
# После применения обычной разности (`diff(1)`) и сезонной разности (`diff(7)`):
# - ADF и KPSS уверенно подтверждают стационарность ряда.
# - Следовательно, для моделирования требуется как минимум одна обычная и одна сезонная разности.
#
# ## 4. ACF и PACF
# - В ACF на исходном ряде видны выраженные пики на лагах кратных 7 (7, 14, 21, 28, 35) — характерный признак недельной сезонности.
# - PACF показывает заметные частичные корреляции на лагах 1 и 7.
# - На дифференцированных рядах недельный эффект сохраняется.
#
#
# # Почему выбрана SARIMA/SARIMAX
#
# ### Почему не ARIMAX
# - Модель ARIMA была отвергнута из-за игнорирования сезонной структуры ряда, подтверждённой аналитикой.
#
# ### Выбор в пользу SARIMA
# - Модель SARIMA хорошо подходит для рядов с сезонностью и необходимостью дифференцирования.
# - В нашем случае наблюдается четкая недельная сезонность, а стационарности удается добиться только после применения разностей.
# - Поэтому SARIMA — естественный выбор для базового моделирования.
#
# ### Почему SARIMAX
# - SARIMAX расширяет возможности модели, позволяя добавить внешние факторы (например, ключевую ставку, налоговые дни, макроэкономику).
# - В условиях банковской ликвидности такие переменные могут заметно улучшить качество прогноза, поэтому в финальной версии лучше использовать именно SARIMAX.
#
#
# # Предварительные рекомендации по параметрам
#
# Основываясь на результатах анализа:
#
# | Параметр | Значение | Пояснение |
# |:--------:|:--------:|:----------|
# | `d` | 1 | Необходимость обычного дифференцирования |
# | `D` | 1 | Требуется сезонное дифференцирование с периодом 7 |
# | `s` | 7 | Сезонный период — неделя |
# | `p` | 1 или 2 | PACF показывает пики на лагах 1–2 |
# | `q` | 0 или 1 | ACF быстро обрубается на лаге 1 |
# | `P` | 1 | Сильная сезонная авторегрессия на лаге 7 |
# | `Q` | 0 или 1 | Возможен сезонный MA-компонент |
#
# Таким образом, для старта можно взять:
# - `(p=1..2, d=1, q=0..1)` и `(P=1, D=1, Q=0..1, s=7)`

# %% [markdown]
# # **Блок 3. Построение авторегрессионных моделей**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error
from sklearn.feature_selection import mutual_info_regression
import warnings
warnings.filterwarnings("ignore")

# === 1. Загрузка данных ===
df = pd.read_csv('data/merged_dataset_with_lags_rollings.csv', parse_dates=['date']).sort_values('date').set_index('date')
#df = pd.read_csv('data/merged_dataset.csv', parse_dates=['date']).sort_values('date').set_index('date')
y = df['balance']
X = df.drop(columns=['balance', 'income', 'outcome'])

# === 2. Сплит ===
train_size = int(len(y) * 0.9)
y_train, y_test = y[:train_size], y[train_size:]
X_train, X_test = X[:train_size], X[train_size:]
key_rate_test = df.loc[y_test.index, 'rate'].fillna(method='ffill').fillna(method='bfill')

# === 3. Очистка признаков ===
X_train = X_train.replace([np.inf, -np.inf], np.nan).fillna(method='ffill').fillna(method='bfill').dropna(axis=1)
X_test = X_test[X_train.columns].replace([np.inf, -np.inf], np.nan).fillna(method='ffill').fillna(method='bfill')
X_test = X_test.dropna(axis=1)
X_train = X_train[X_test.columns]

print(f" Размер train: {len(y_train)}, test: {len(y_test)}")

print("Обучение SARIMA (1,1,1)x(1,1,1,7)...")
sarima_model = SARIMAX(y_train,
                       order=(1, 1, 1),
                       seasonal_order=(1, 1, 1, 7),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_result = sarima_model.fit(disp=False)
sarima_forecast = sarima_result.forecast(steps=30)

sarima_model_fit = SARIMAX(y_train, order=sarima_model.order, seasonal_order=sarima_model.seasonal_order,
                           enforce_stationarity=False, enforce_invertibility=False).fit(disp=False)
sarima_forecast = sarima_model_fit.predict(start=y_test.index[0], end=y_test.index[-1])

mae_sarima = mean_absolute_error(y_test.values, sarima_forecast.values)
margin_sarima = calculate_add_margin_vectorized(y_test.values, sarima_forecast.values, key_rate_test.values)
normalized_add_margin_sarima = normalized_add_margin(y_test.values, sarima_forecast.values, key_rate_test.values)
print(f" SARIMA: MAE = {mae_sarima:.5f}")
print(f" SARIMA: add_margin: {margin_sarima:.10f}")
print(f" SARIMA: normalized_add_margin: {normalized_add_margin_sarima:.5f} % от среднего баланса")

# === 7. Mutual Information ===
print("\n Mutual Information...")
lagged_features = X_train.shift(1).dropna()
lagged_y = y_train.loc[lagged_features.index]
mi_scores = mutual_info_regression(lagged_features, lagged_y)
mi_series = pd.Series(mi_scores, index=lagged_features.columns)
mi_sorted = mi_series.sort_values(ascending=False)
top_mi_features = mi_sorted.head(20).index.tolist()

# print("\n Топ-20 по mutual info:")
# for k in top_mi_features:
#     print(f"{k}: MI = {mi_sorted[k]:.5f}")

# === 8. SARIMAX по top-20 mutual info ===
sarimax_mi = SARIMAX(
    endog=y_train,
    exog=X_train[top_mi_features],
    order=sarima_model.order,
    seasonal_order=sarima_model.seasonal_order,
    enforce_stationarity=False,
    enforce_invertibility=False
).fit(disp=False)
pred_mi = sarimax_mi.predict(start=y_test.index[0], end=y_test.index[-1], exog=X_test[top_mi_features])

mae_mi = mean_absolute_error(y_test.values, pred_mi.values)
margin_mi = calculate_add_margin_vectorized(y_test.values, pred_mi.values, key_rate_test.values)
normalized_add_margin_mi = normalized_add_margin(y_test.values, pred_mi.values, key_rate_test.values)
print(f" SARIMAX (top-20 MI): MAE = {mae_mi:.5f}")
print(f" SARIMAX (top-20 MI): add_margin {margin_mi:.10f}")
print(f" SARIMAX (top-20 MI): normalized_add_margin {normalized_add_margin_mi:.5f} % от среднего баланса")


# === 9. График сравнения ===
plt.figure(figsize=(14, 6))
plt.plot(y_test.index, y_test.values, label='Фактическое значение', color='black')
plt.plot(y_test.index, sarima_forecast, label='SARIMA', linestyle='--')
plt.plot(y_test.index, pred_mi, label='SARIMAX (top-20 MI)', linestyle='--')
plt.legend()
plt.title('Прогноз баланса: сравнение методов отбора признаков')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#  Размер train: 1382, test: 154
# Обучение SARIMA (1,1,1)x(1,1,1,7)...
#  SARIMA: MAE = 0.23090
#  SARIMA: add_margin: -0.0000013334 руб/день
#  SARIMA: normalized_add_margin: -0.00056 % от среднего баланса
#
#  Mutual Information...
#  SARIMAX (top-20 MI): MAE = 0.27151
#  SARIMAX (top-20 MI): add_margin 0.0000009331
#  SARIMAX (top-20 MI): normalized_add_margin 0.00039 % от среднего баланса

# %% [markdown]
# ## Выводы по автогрегрессионным моделям:
#
# На первом этапе были обучены и проанализированы базовые авторегрессионные модели для прогнозирования баланса ликвидности на следующий день.
#
# Данные были разделены на обучающую и тестовую выборки:
# - **Train**: 1382 наблюдения,
# - **Test**: 154 наблюдения.
#
# ## SARIMA (1,1,1)x(1,1,1,7)
#
# - Базовая модель SARIMA без использования внешних факторов показала **MAE = 0.2309**.
# - Добавленная маржа по прогнозу практически нулевая (**-0.0000013 руб/день**), нормированная добавленная маржа — **-0.00056%** от среднего баланса.
# - График прогнозов показывает, что SARIMA достаточно точно следует за фактическими данными, особенно в спокойные периоды, и демонстрирует стабильное поведение без резких отклонений.
# - Таким образом, базовая SARIMA хорошо справляется с задачей минимизации ошибки прогноза, но не приносит заметной выгоды в части увеличения доходности.
#
# ## SARIMAX с внешними признаками (top-20 по Mutual Information)
#
# - SARIMAX, обученная на 20 наиболее информативных признаках по Mutual Information, показала **более высокую ошибку** — **MAE = 0.2715**.
# - При этом прогноз модели оказался **более волатильным**: в периоды резких изменений баланса ошибка увеличивается.
# - Однако добавленная маржа оказалась **положительной** (**+0.00000093 руб/день**, нормированная маржа +0.00039% от среднего баланса).
# - Это означает, что несмотря на ухудшение точности прогноза, **SARIMAX более выгодна с точки зрения бизнес-результата**: модель помогает чаще принимать решения, увеличивающие доходность операций с ликвидностью.
#
# ## Визуальный анализ
#
# - На графике видно, что SARIMA ближе следует за фактическими данными, тогда как SARIMAX иногда уходит выше или ниже реальных значений, особенно в моменты нестабильности.
# - Тем не менее, SARIMAX захватывает больше движений рынка, что при правильной настройке модели и контроле рисков может быть полезнее для максимизации прибыли.
#
#
# ### Общий итог
#
# - **Базовая SARIMA** лучше всего подходит для задачи минимизации ошибки прогноза.
# - **SARIMAX с отобранными признаками** имеет потенциал для увеличения прибыли, несмотря на чуть большую погрешность в прогнозах.

# %% [markdown]
# # **Блок 4. tsfresh как обогащение признаков**

# %%
import pandas as pd
import numpy as np
from tsfresh import extract_relevant_features
from tsfresh.feature_extraction import settings

df = pd.read_csv('data\merged_dataset_with_lags_rollings.csv', parse_dates=['date']).sort_values('date')
df = df.set_index('date')

# Удаляем текущие значения таргета
y = df['balance'].copy()
df = df.drop(columns=['income', 'outcome', 'balance'])

# Удаляем NaN
df_clean = df.dropna()
X = df_clean.copy()
y = y.loc[X.index]

# tsfresh: long format
data_long = pd.DataFrame({
    "values": X.values.flatten(),
    "id": np.arange(X.shape[0]).repeat(X.shape[1])
})
y_indexed = y.copy()
y_indexed.index = np.arange(X.shape[0])

# tsfresh extraction
features_df = extract_relevant_features(
    data_long,
    y_indexed,
    column_id="id",
    default_fc_parameters=settings.ComprehensiveFCParameters(),
    n_jobs=0,
)

features_df.index = X.index  #  вот тут — правильный индекс
features_df['balance'] = y

features_df.to_csv('data/merged_dataset_tsfresh.csv')
# Out:
# Feature Extraction: 100%|██████████| 1536/1536 [04:36<00:00,  5.56it/s]

# %% [markdown]
# #  **Блок 5. Отбор признаков (FS) для ML**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.feature_selection import mutual_info_regression, SelectKBest, f_regression, RFE
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.inspection import permutation_importance
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from joblib import Parallel, delayed


from tqdm import tqdm

# ========== 1. НАСТРОЙКИ ==========

available_models = {
    "Ridge": Ridge,
    "RandomForest": RandomForestRegressor,
    "ExtraTrees": ExtraTreesRegressor,
    "LGBM": LGBMRegressor,
    "CatBoost": CatBoostRegressor
}

# Выбери здесь, какие модели протестировать:
selected_models = ["RandomForest", "LGBM", "CatBoost", "Ridge"]  
selected_models = ["LGBM","Ridge"]  

# Параметры моделей по умолчанию:
default_model_params = {
    "Ridge": {"random_state": 42},
    "RandomForestRegressor": {"n_estimators": 100, "random_state": 42},
    "ExtraTreesRegressor": {"n_estimators": 100, "random_state": 42},
    "LGBMRegressor": {"n_estimators": 100, "random_state": 42},
    "CatBoostRegressor": {"verbose": 0, "random_seed": 42}
}


# ========== 2. ЗАГРУЗКА ДАННЫХ ==========

df = pd.read_csv("data/merged_dataset_with_lags_rollings.csv", parse_dates=['date'])
df = df.set_index("date")
y = df["balance"]
X = df.drop(columns=["balance", "income", "outcome"])

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)

# ========== 3. ФУНКЦИИ ОТБОРА ПРИЗНАКОВ ==========

def fs_embedded(model_class, X, y, k=20):
    model = model_class(**default_model_params[model_class.__name__])
    model.fit(X, y)
    try:
        importances = model.feature_importances_
    except AttributeError:
        importances = np.abs(model.coef_)
    imp_series = pd.Series(importances, index=X.columns)
    return imp_series.sort_values(ascending=False).head(k).index.tolist()

def fs_wrapper_rfe(model_class, X, y, k=20, step=0.2):
    model = model_class(**default_model_params[model_class.__name__])
    current_features = X.columns.tolist()

    while len(current_features) > k:
        model.fit(X[current_features], y)
        try:
            importances = model.feature_importances_
        except AttributeError:
            importances = np.abs(model.coef_)
        imp_series = pd.Series(importances, index=current_features)
        n_to_remove = max(1, int(len(current_features) * step))
        worst_features = imp_series.nsmallest(n_to_remove).index.tolist()
        current_features = [f for f in current_features if f not in worst_features]

    return current_features

from sklearn.base import clone
from sklearn.metrics import mean_squared_error

def fs_wrapper_forward_selection(model_class, X, y, k=20):
    model = model_class(**default_model_params[model_class.__name__])
    selected_features = []
    remaining_features = list(X.columns)

    while len(selected_features) < k:
        scores = {}

        for feature in remaining_features:
            current_features = selected_features + [feature]
            model_clone = clone(model)
            model_clone.fit(X[current_features], y)
            preds = model_clone.predict(X[current_features])
            score = mean_squared_error(y, preds)  # Чем меньше ошибка, тем лучше
            scores[feature] = score

        # Выбираем фичу, которая дала наименьшую ошибку
        best_feature = min(scores, key=scores.get)
        selected_features.append(best_feature)
        remaining_features.remove(best_feature)

    return selected_features


def fs_permutation_importance(model_class, X, y, k=20):
    model = model_class(**default_model_params[model_class.__name__])
    model.fit(X, y)
    result = permutation_importance(model, X, y, n_repeats=10, random_state=42, n_jobs=-1)
    imp_series = pd.Series(result.importances_mean, index=X.columns)
    return imp_series.sort_values(ascending=False).head(k).index.tolist()

def fs_mutual_information(X, y, k=20):
    scores = mutual_info_regression(X, y, random_state=42)
    return pd.Series(scores, index=X.columns).sort_values(ascending=False).head(k).index.tolist()

# ========== 4. СОБИРАЕМ МЕТОДЫ ДЛЯ СРАВНЕНИЯ ==========

methods = {"Mutual_Information": lambda X, y: fs_mutual_information(X, y, k=20)} 

for model_name in selected_models:
    model_class = available_models[model_name]
    methods[f"Embedded_{model_name}"] = lambda X, y, model_class=model_class: fs_embedded(model_class, X, y, k=20)
    #methods[f"WrapperForward_{model_name}"] = lambda X, y, model_class=model_class: fs_wrapper_forward_selection(model_class, X, y, k=20)
    #methods[f"Permutation_{model_name}"] = lambda X, y, model_class=model_class: fs_permutation_importance(model_class, X, y, k=20)
    methods[f"WrapperRFE_{model_name}"] = lambda X, y, model_class=model_class: fs_wrapper_rfe(model_class, X, y, k=20)
    #methods[f"Permutation_{model_name}"] = lambda X, y, model_class=model_class: fs_permutation_importance(model_class, X, y, k=20)



# ========== 5. АНАЛИЗ СТАБИЛЬНОСТИ ==========

def stability_analysis(X, y, methods, k=20, n_iter=10, sample_frac=0.8):
    base_sets = {name: set(fn(X, y)) for name, fn in methods.items()}
    results = {name: [] for name in methods}
    
    for i in tqdm(range(n_iter), desc="Бутстрап стабильности"):
        X_s, y_s = resample(X, y, n_samples=int(len(X) * sample_frac), random_state=i)
        for name, fn in methods.items():
            selected = set(fn(X_s, y_s))
            stability = len(selected & base_sets[name]) / k
            results[name].append(stability)
    return pd.DataFrame(results)

def stability_analysis_tscv(X, y, methods, k=20, n_splits=10):
    base_sets = {name: set(fn(X, y)) for name, fn in methods.items()}
    results = {name: [] for name in methods}
    
    tscv = TimeSeriesSplit(n_splits=n_splits)
    
    for i, (train_idx, test_idx) in enumerate(tscv.split(X)):
        X_s, y_s = X.iloc[train_idx], y.iloc[train_idx]
        for name, fn in methods.items():
            selected = set(fn(X_s, y_s))
            stability = len(selected & base_sets[name]) / k
            results[name].append(stability)
    return pd.DataFrame(results)

# ========== 6. ПРОВЕДЕНИЕ СТАБИЛЬНОСТИ ==========

#stability_df = stability_analysis(X_scaled, y, methods, k=20, n_iter=5)
stability_df_tscv = stability_analysis_tscv(X_scaled, y, methods, k=20, n_splits=10)

# print("\n--- Бутстрап ---")
# print(stability_df.describe().T)

print("\n--- TimeSeriesSplit ---")
print(stability_df_tscv.describe().T)

# ========== 7. ВИЗУАЛИЗАЦИЯ ==========

#fig, axs = plt.subplots(1, 2, figsize=(20, 8), sharey=True)

# sns.boxplot(data=stability_df, ax=axs[0])
# axs[0].set_title("Бутстрап стабильности")
# axs[0].set_ylabel("Доля совпавших признаков")
# axs[0].grid(True)

# sns.boxplot(data=stability_df_tscv, ax=axs[1])
# axs[1].set_title("TimeSeriesSplit стабильности")
# axs[1].grid(True)

# plt.suptitle("Сравнение устойчивости отбора признаков", fontsize=16)
# plt.tight_layout()
# plt.show()

fig = plt.figure(figsize=(20, 8))
sns.boxplot(data=stability_df_tscv)
plt.set_title("TimeSeriesSplit стабильности")
plt.grid(True)

plt.suptitle("Сравнение устойчивости отбора признаков", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# --- TimeSeriesSplit ---
#                     count   mean       std   min     25%    50%     75%   max
# Mutual_Information   10.0  0.545  0.103950  0.40  0.4625  0.525  0.6000  0.70
# Embedded_LGBM        10.0  0.695  0.125720  0.50  0.6125  0.700  0.7500  0.90
# WrapperRFE_LGBM      10.0  0.560  0.112546  0.35  0.4750  0.575  0.6500  0.70
# Embedded_Ridge       10.0  0.380  0.156702  0.10  0.2625  0.450  0.4875  0.55
# WrapperRFE_Ridge     10.0  0.175  0.103414  0.00  0.1125  0.200  0.2375  0.35

# %%
# === МОДУЛЬ ОТБОРА ПРИЗНАКОВ ПО ВСТРОЕННОЙ ВАЖНОСТИ ===
def select_top_features(model, X_train, y_train, top_k=20):
    model.fit(X_train, y_train)
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
    elif hasattr(model, "coef_"):
        importances = np.abs(model.coef_)
    else:
        raise ValueError("Модель не поддерживает отбор признаков")
    top_indices = np.argsort(importances)[::-1][:top_k]
    top_features = X_train.columns[top_indices]
    return list(top_features)

# %% [markdown]
# ## Выводы по сравнению разных методов Feature Selection
#
# Для выбора базового метода отбора признаков в проекте я сравнил несколько подходов из разных категорий: фильтрационные (Mutual Information), встроенные (Embedded методы) и оберточные (WrapperRFE).
#
# Результаты тестирования с использованием скользящей проверки по времени (TimeSeriesSplit) показали следующую картину:
#
# **Выводы:**
#
# 1. **Фильтрационные методы** (Mutual Information) быстро работают и устойчивы, но плохо учитывают взаимодействия между признаками. Это сказывается на качестве модели: в среднем оно ощутимо ниже, чем у встроенных методов.
#
# 2. **Оберточные методы** (WrapperRFE) лучше захватывают сложные зависимости между признаками и таргетом, но цена за это — высокая вычислительная нагрузка. Для пайплайна с регулярным автообучением это не самое разумное решение, особенно если учесть, что прирост качества по сравнению с Embedded отсутствует.
#
# 3. **Embedded методы** оказались наиболее сбалансированными: они автоматически учитывают взаимодействия между признаками, при этом не требуют настолько больших ресурсов, как обертки. Встроенный отбор признаков опирается на важности, вычисляемые во время обучения модели, что обеспечивает естественную устойчивость к переобучению и хорошую адаптацию к изменениям данных.
#
# **Почему для дальнейших моделей выбран Embedded метод:**
#
# - Он показал **самое высокое среднее качество** среди всех протестированных методов.
# - Он более **вычислительно эффективен** по сравнению с оберточными подходами, что критично для автоматизированного переобучения модели без ручного контроля.
# - Встроенный отбор в модели (такие как LGBM и прочие) умеет **естественно учитывать нелинейные зависимости** между признаками и целевой переменной, что было дополнительным требованием в проекте.
# - Метод обеспечивает **хороший баланс между стабильностью и точностью**, что особенно важно для банковского бизнес-процесса, где прогнозы ложатся в основу решений о перераспределении ликвидности.
#
# Таким образом, в качестве базового способа отбора признаков для итоговой модели выбран именно **Embedded метод**.

# %% [markdown]
# # **Блок 6. Построение ML моделей**

# %%
import numpy as np
import pandas as pd
import optuna
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

class ModelPipeline:
    def __init__(
        self,
        models_config: dict,
        n_splits: int = 3,
        feature_selector_top_k: int = 20,
        n_trials: int = 10,
        metric_func=mean_absolute_error,
        optuna_direction: str = "minimize",
        use_optuna: bool = True,
    ):
        self.models_config = models_config
        self.n_splits = n_splits
        self.top_k = feature_selector_top_k
        self.n_trials = n_trials
        self.metric_func = metric_func
        self.optuna_direction = optuna_direction
        self.use_optuna = use_optuna
        self.best_params = {}

    def tune_model(self, model_name, X, y, key_rate):
        def objective(trial):
            model_cls, param_space = self.models_config[model_name]
            params = {k: v(trial) for k, v in param_space.items()}
            tscv = TimeSeriesSplit(n_splits=self.n_splits)

            fold_losses = []

            for train_idx, val_idx in tscv.split(X):
                X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
                y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
                rate_val = key_rate.iloc[val_idx]

                model = model_cls(**params)
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_val)

                fold_losses.append(self.metric_func(y_val, y_pred, rate_val))

            return np.mean(fold_losses)

        study = optuna.create_study(direction=self.optuna_direction, sampler=optuna.samplers.TPESampler(seed=42))
        study.optimize(objective, n_trials=self.n_trials, show_progress_bar=True)

        return study.best_params

    def run(self, X, y, key_rate, test_start_date, model_name, extra_metrics=None):
        if extra_metrics is None:
            extra_metrics = []

        results = []

        balance_reference = y[(y > 0) & (y.index >= test_start_date)].mean()

        X_train = X[X.index < test_start_date]
        X_test = X[X.index >= test_start_date]
        y_train = y.loc[X_train.index]
        y_test = y.loc[X_test.index]
        rate_train = key_rate.loc[X_train.index]
        rate_test = key_rate.loc[X_test.index]

        if model_name not in self.models_config:
            raise ValueError(f"Модель '{model_name}' не найдена в models_config.")

        if self.use_optuna:
            print(f"\n Калибровка модели: {model_name}")
            best_params = self.tune_model(model_name, X_train, y_train, rate_train)
        else:
            print(f"\n Обучение {model_name} без тюнинга (параметры по умолчанию)")
            best_params = {}

        self.best_params[model_name] = best_params

        model_cls = self.models_config[model_name][0]
        selector_model = model_cls(**best_params)
        selector_model.fit(X_train, y_train)
        top_features = self._select_top_features(selector_model, X_train)
        print(f"Топ-{self.top_k} признаков для {model_name}: {top_features}")

        if X_test.empty:
            print("Нет тестовых данных. Обучение модели без теста.")
            model = model_cls(**best_params)
            model.fit(X_train[top_features], y_train)
            return None

        # делаем финальное обучение только по топовым признакам
        model = model_cls(**best_params, verbose=0)
        model.fit(X_train[top_features], y_train)
        y_pred = model.predict(X_test[top_features])

        results.append(
            self._evaluate(model_name, y_test, y_pred, rate_test, balance_reference, extra_metrics)
        )

        self._plot(y_test, y_pred, model_name)

        return pd.DataFrame(results)

    # остальное без изменений


    def _select_top_features(self, model, X):
        if hasattr(model, "feature_importances_"):
            importances = model.feature_importances_
        elif hasattr(model, "coef_"):
            importances = np.abs(model.coef_)
        else:
            raise ValueError("Model does not support feature importance or coef_.")
        
        top_indices = np.argsort(importances)[::-1][:self.top_k]
        return list(X.columns[top_indices])

    def _evaluate(self, name, y_true, y_pred, rate, balance_ref, extra_metrics):
        result = {
            "Model": name,
            "MAE": mean_absolute_error(y_true, y_pred),
            self.metric_func.__name__: self.metric_func(y_true, y_pred, rate),
        }
        for func in extra_metrics:
            result[func.__name__] = func(y_true, y_pred, rate)
        return result

    def _plot(self, y_true, y_pred, model_name):
        plt.figure(figsize=(15, 6))
        plt.plot(y_true.index, y_true.values, label="Истинное значение", linewidth=2)
        plt.plot(y_true.index, y_pred, label=f"Предсказание ({model_name})", linewidth=2)
        plt.title(f"Факт vs Прогноз для {model_name}")
        plt.xlabel("Дата")
        plt.ylabel("Сальдо")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

models_config = {
    "RandomForest": (
        RandomForestRegressor,
        {
            "n_estimators": lambda t: t.suggest_int("n_estimators", 100, 300),
            "max_depth": lambda t: t.suggest_int("max_depth", 5, 15),
            "min_samples_split": lambda t: t.suggest_int("min_samples_split", 2, 10),
            "random_state": lambda _: 42
        }
    ),
    "LGBM": (
        LGBMRegressor,
        {
            "n_estimators": lambda t: t.suggest_int("n_estimators", 50, 300),
            "learning_rate": lambda t: t.suggest_float("learning_rate", 0.01, 0.3),
            "max_depth": lambda t: t.suggest_int("max_depth", 10, 25),
            "random_state": lambda _: 42,
            "verbosity": lambda _: -1
        }
    )
    ,
    "CatBoost": (
        CatBoostRegressor,
        {
            "depth": lambda t: t.suggest_int("depth", 4, 10)
            ,
            "learning_rate": lambda t: t.suggest_float("learning_rate", 0.01, 0.3),
            "l2_leaf_reg": lambda t: t.suggest_float("l2_leaf_reg", 1, 10),
            "iterations": lambda _: 200,
            "verbose": lambda _: False,
            "random_seed": lambda _: 42
        }

        
    )
}

df = pd.read_csv("data/merged_dataset_with_lags_rollings.csv", parse_dates=["date"]).set_index("date")
X = df.drop(columns=["balance", "income", "outcome"])
y = df["balance"]
key_rate = df["rate"]#.fillna(0.085)

pipeline = ModelPipeline(
    models_config,
    metric_func=mae_cust,
    optuna_direction="minimize",
    use_optuna=True,
    # количество фолдов и итераций для Optuna
    n_trials=4,
    n_splits=2,
)

for model in ["LGBM", "RandomForest", "CatBoost"]:
    print(f"\n Калибровка модели: {model}")
    results = pipeline.run(
        X,
        y,
        key_rate,
        test_start_date=X.index[int(len(X) * 0.8)],
        model_name=model,
        extra_metrics=[calculate_add_margin_vectorized, normalized_add_margin,delta_pnl]
    )
    display(results)
    print(results)

# results = pipeline.run(
#     X,
#     y,
#     key_rate,
#     test_start_date=X.index[int(len(X) * 0.8)],
#     model_name="LGBM",
#     extra_metrics=[ calculate_add_margin_vectorized]
# )

# print(results)

# results = pipeline.run(
#     X,
#     y,
#     key_rate,
#     test_start_date=X.index[int(len(X) * 0.8)],
#     model_name="RandomForest",
#     extra_metrics=[ calculate_add_margin_vectorized]
# )

# print(results)

# results = pipeline.run(
#     X,
#     y,
#     key_rate,
#     test_start_date=X.index[int(len(X) * 0.8)],
#     model_name="CatBoost",
#     extra_metrics=[ calculate_add_margin_vectorized]
# )

# print(results)
# Out:
# [I 2025-04-28 01:13:00,474] A new study created in memory with name: no-name-2464854c-ab74-4db5-9b41-a1f14214d8c4
#  Калибровка модели: LGBM
#
#  Калибровка модели: LGBM
# Best trial: 0. Best value: 0.321634:  25%|██▌       | 1/4 [00:01<00:04,  1.46s/it]
# [I 2025-04-28 01:13:01,932] Trial 0 finished with value: 0.32163350056562756 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.32163350056562756.
# Best trial: 1. Best value: 0.277507:  50%|█████     | 2/4 [00:02<00:02,  1.33s/it]
# [I 2025-04-28 01:13:03,176] Trial 1 finished with value: 0.27750725020107825 and parameters: {'n_estimators': 200, 'learning_rate': 0.055245405728306586, 'max_depth': 12}. Best is trial 1 with value: 0.27750725020107825.
# Best trial: 1. Best value: 0.277507:  75%|███████▌  | 3/4 [00:03<00:00,  1.00it/s]
# [I 2025-04-28 01:13:03,784] Trial 2 finished with value: 0.3069006651914988 and parameters: {'n_estimators': 64, 'learning_rate': 0.2611910822747312, 'max_depth': 19}. Best is trial 1 with value: 0.27750725020107825.
# Best trial: 3. Best value: 0.226999: 100%|██████████| 4/4 [00:04<00:00,  1.22s/it]
# [I 2025-04-28 01:13:05,362] Trial 3 finished with value: 0.22699892538280955 and parameters: {'n_estimators': 227, 'learning_rate': 0.01596950334578271, 'max_depth': 25}. Best is trial 3 with value: 0.22699892538280955.
# Топ-20 признаков для LGBM: ['is_non_working_day', 'outcome_lag1', 'ON_rollstd7', 'balance_rollmean7', 'balance_lag1', 'gold_cost_rub_rollstd7', 'income_lag1', 'brent_cost_rollstd3', 'balance_rollstd3', 'balance_rollstd7', '3M_rollstd7', 'usd_rub_rollstd7', 'income_rollstd3', 'outcome_rollmean3', '6M_rollstd7', 'brent_cost_rollstd7', 'income_lag2', 'usd_rub_rollstd3', 'outcome_rollstd3', 'balance_rollmax7']
#   Model       MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  LGBM  0.185724  0.185724                     5.557635e-07
#
#    normalized_add_margin  delta_pnl
# 0               0.000332  -0.423908
# [I 2025-04-28 01:13:07,501] A new study created in memory with name: no-name-2fe319b6-62e2-411f-97d0-5e66f405a069
#   Model       MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  LGBM  0.185724  0.185724                     5.557635e-07
#
#    normalized_add_margin  delta_pnl
# 0               0.000332  -0.423908
#
#  Калибровка модели: RandomForest
#
#  Калибровка модели: RandomForest
# Best trial: 0. Best value: 0.343279:  25%|██▌       | 1/4 [00:30<01:31, 30.58s/it]
# [I 2025-04-28 01:13:38,076] Trial 0 finished with value: 0.34327889090016245 and parameters: {'n_estimators': 175, 'max_depth': 15, 'min_samples_split': 8}. Best is trial 0 with value: 0.34327889090016245.
# Best trial: 1. Best value: 0.329107:  50%|█████     | 2/4 [00:48<00:46, 23.07s/it]
# [I 2025-04-28 01:13:55,898] Trial 1 finished with value: 0.3291074295979417 and parameters: {'n_estimators': 220, 'max_depth': 6, 'min_samples_split': 3}. Best is trial 1 with value: 0.3291074295979417.
# Best trial: 1. Best value: 0.329107:  75%|███████▌  | 3/4 [01:07<00:21, 21.29s/it]
# [I 2025-04-28 01:14:15,071] Trial 2 finished with value: 0.3431039900500443 and parameters: {'n_estimators': 111, 'max_depth': 14, 'min_samples_split': 7}. Best is trial 1 with value: 0.3291074295979417.
# Best trial: 3. Best value: 0.308946: 100%|██████████| 4/4 [01:23<00:00, 20.98s/it]
# [I 2025-04-28 01:14:31,412] Trial 3 finished with value: 0.3089460414974324 and parameters: {'n_estimators': 242, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 3 with value: 0.3089460414974324.
# Топ-20 признаков для RandomForest: ['day_Monday', 'balance_rollmean7', 'income_rollstd3', 'balance_lag1', '6M_rollstd7', 'brent_cost_rollstd3', 'balance_rollmean3', 'balance_rollmax3', 'day_Thursday', 'brent_cost_rollstd7', 'balance_rollmed7', 'balance_lag3', 'outcome_lag1', 'is_non_working_day', 'ON_rollstd7', 'balance_rollmax7', '2W_rollstd7', 'outcome_rollstd3', 'gold_cost_rub_rollstd7', 'balance_rollmed3']
#           Model      MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  RandomForest  0.17598   0.17598                    -6.997413e-07
#
#    normalized_add_margin  delta_pnl
# 0              -0.000418  -0.386504
# [I 2025-04-28 01:14:49,763] A new study created in memory with name: no-name-75dd8142-e8f3-4868-b952-a679496f3b9d
#           Model      MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  RandomForest  0.17598   0.17598                    -6.997413e-07
#
#    normalized_add_margin  delta_pnl
# 0              -0.000418  -0.386504
#
#  Калибровка модели: CatBoost
#
#  Калибровка модели: CatBoost
# Best trial: 0. Best value: 0.27898:  25%|██▌       | 1/4 [00:06<00:20,  6.73s/it]
# [I 2025-04-28 01:14:56,491] Trial 0 finished with value: 0.2789797724594574 and parameters: {'depth': 6, 'learning_rate': 0.28570714885887566, 'l2_leaf_reg': 7.587945476302646}. Best is trial 0 with value: 0.2789797724594574.
# Best trial: 1. Best value: 0.217417:  50%|█████     | 2/4 [00:25<00:27, 13.79s/it]
# [I 2025-04-28 01:15:15,227] Trial 1 finished with value: 0.21741697223404163 and parameters: {'depth': 8, 'learning_rate': 0.055245405728306586, 'l2_leaf_reg': 2.403950683025824}. Best is trial 1 with value: 0.21741697223404163.
# Best trial: 1. Best value: 0.217417:  75%|███████▌  | 3/4 [00:28<00:08,  8.72s/it]
# [I 2025-04-28 01:15:17,906] Trial 2 finished with value: 0.3414326514727601 and parameters: {'depth': 4, 'learning_rate': 0.2611910822747312, 'l2_leaf_reg': 6.41003510568888}. Best is trial 1 with value: 0.21741697223404163.
# Best trial: 3. Best value: 0.183439: 100%|██████████| 4/4 [00:47<00:00, 11.79s/it]
# [I 2025-04-28 01:15:36,907] Trial 3 finished with value: 0.1834394488030486 and parameters: {'depth': 8, 'learning_rate': 0.01596950334578271, 'l2_leaf_reg': 9.72918866945795}. Best is trial 3 with value: 0.1834394488030486.
# 0:	learn: 0.2789651	total: 68.5ms	remaining: 1m 8s
# 1:	learn: 0.2785993	total: 124ms	remaining: 1m 1s
# 2:	learn: 0.2782220	total: 179ms	remaining: 59.3s
# 3:	learn: 0.2777719	total: 261ms	remaining: 1m 4s
# 4:	learn: 0.2773243	total: 324ms	remaining: 1m 4s
# 5:	learn: 0.2768259	total: 388ms	remaining: 1m 4s
# 6:	learn: 0.2763881	total: 460ms	remaining: 1m 5s
# 7:	learn: 0.2759324	total: 518ms	remaining: 1m 4s
# 8:	learn: 0.2755448	total: 575ms	remaining: 1m 3s
# 9:	learn: 0.2750510	total: 675ms	remaining: 1m 6s
# 10:	learn: 0.2746944	total: 797ms	remaining: 1m 11s
# 11:	learn: 0.2742630	total: 888ms	remaining: 1m 13s
# 12:	learn: 0.2739050	total: 981ms	remaining: 1m 14s
# 13:	learn: 0.2736098	total: 1.04s	remaining: 1m 13s
# 14:	learn: 0.2732157	total: 1.09s	remaining: 1m 11s
# 15:	learn: 0.2728595	total: 1.16s	remaining: 1m 11s
# 16:	learn: 0.2725088	total: 1.22s	remaining: 1m 10s
# 17:	learn: 0.2722111	total: 1.28s	remaining: 1m 9s
# 18:	learn: 0.2718435	total: 1.34s	remaining: 1m 9s
# 19:	learn: 0.2714402	total: 1.4s	remaining: 1m 8s
# 20:	learn: 0.2711180	total: 1.46s	remaining: 1m 7s
# 21:	learn: 0.2706943	total: 1.52s	remaining: 1m 7s
# 22:	learn: 0.2704248	total: 1.58s	remaining: 1m 6s
# 23:	learn: 0.2700133	total: 1.64s	remaining: 1m 6s
# 24:	learn: 0.2697128	total: 1.7s	remaining: 1m 6s
# 25:	learn: 0.2693287	total: 1.75s	remaining: 1m 5s
# 26:	learn: 0.2689837	total: 1.81s	remaining: 1m 5s
# 27:	learn: 0.2686511	total: 1.87s	remaining: 1m 5s
# 28:	learn: 0.2682530	total: 1.93s	remaining: 1m 4s
# 29:	learn: 0.2679259	total: 1.98s	remaining: 1m 4s
# 30:	learn: 0.2675766	total: 2.04s	remaining: 1m 3s
# 31:	learn: 0.2671775	total: 2.11s	remaining: 1m 3s
# 32:	learn: 0.2668769	total: 2.16s	remaining: 1m 3s
# 33:	learn: 0.2665523	total: 2.22s	remaining: 1m 2s
# 34:	learn: 0.2662527	total: 2.28s	remaining: 1m 2s
# 35:	learn: 0.2659410	total: 2.35s	remaining: 1m 2s
# 36:	learn: 0.2656389	total: 2.41s	remaining: 1m 2s
# 37:	learn: 0.2653538	total: 2.46s	remaining: 1m 2s
# 38:	learn: 0.2650265	total: 2.54s	remaining: 1m 2s
# 39:	learn: 0.2646955	total: 2.59s	remaining: 1m 2s
# 40:	learn: 0.2643775	total: 2.65s	remaining: 1m 2s
# 41:	learn: 0.2641029	total: 2.71s	remaining: 1m 1s
# 42:	learn: 0.2638236	total: 2.76s	remaining: 1m 1s
# 43:	learn: 0.2634977	total: 2.84s	remaining: 1m 1s
# 44:	learn: 0.2632899	total: 2.9s	remaining: 1m 1s
# 45:	learn: 0.2630427	total: 2.95s	remaining: 1m 1s
# 46:	learn: 0.2627640	total: 3.02s	remaining: 1m 1s
# 47:	learn: 0.2624559	total: 3.08s	remaining: 1m 1s
# 48:	learn: 0.2621265	total: 3.13s	remaining: 1m
# 49:	learn: 0.2618050	total: 3.19s	remaining: 1m
# 50:	learn: 0.2614995	total: 3.25s	remaining: 1m
# 51:	learn: 0.2612365	total: 3.31s	remaining: 1m
# 52:	learn: 0.2609984	total: 3.37s	remaining: 1m
# 53:	learn: 0.2607617	total: 3.43s	remaining: 1m
# 54:	learn: 0.2604522	total: 3.48s	remaining: 59.8s
# 55:	learn: 0.2600914	total: 3.54s	remaining: 59.7s
# 56:	learn: 0.2597715	total: 3.6s	remaining: 59.5s
# 57:	learn: 0.2594911	total: 3.66s	remaining: 59.4s
# 58:	learn: 0.2592333	total: 3.72s	remaining: 59.3s
# 59:	learn: 0.2589368	total: 3.78s	remaining: 59.3s
# 60:	learn: 0.2586671	total: 3.84s	remaining: 59.1s
# 61:	learn: 0.2584079	total: 3.91s	remaining: 59.1s
# 62:	learn: 0.2581405	total: 3.97s	remaining: 59.1s
# 63:	learn: 0.2578820	total: 4.03s	remaining: 59s
# 64:	learn: 0.2576366	total: 4.08s	remaining: 58.8s
# 65:	learn: 0.2573242	total: 4.14s	remaining: 58.6s
# 66:	learn: 0.2570802	total: 4.2s	remaining: 58.5s
# 67:	learn: 0.2568048	total: 4.27s	remaining: 58.5s
# 68:	learn: 0.2565775	total: 4.33s	remaining: 58.4s
# 69:	learn: 0.2563261	total: 4.39s	remaining: 58.3s
# 70:	learn: 0.2560562	total: 4.45s	remaining: 58.3s
# 71:	learn: 0.2558372	total: 4.51s	remaining: 58.2s
# 72:	learn: 0.2557204	total: 4.57s	remaining: 58s
# 73:	learn: 0.2554578	total: 4.62s	remaining: 57.9s
# 74:	learn: 0.2550666	total: 4.71s	remaining: 58.1s
# 75:	learn: 0.2548223	total: 4.77s	remaining: 58s
# 76:	learn: 0.2545803	total: 4.83s	remaining: 57.9s
# 77:	learn: 0.2543381	total: 4.88s	remaining: 57.7s
# 78:	learn: 0.2541117	total: 4.95s	remaining: 57.7s
# 79:	learn: 0.2538667	total: 5s	remaining: 57.6s
# 80:	learn: 0.2535583	total: 5.06s	remaining: 57.4s
# 81:	learn: 0.2532832	total: 5.12s	remaining: 57.3s
# 82:	learn: 0.2530766	total: 5.19s	remaining: 57.3s
# 83:	learn: 0.2527770	total: 5.25s	remaining: 57.3s
# 84:	learn: 0.2525298	total: 5.31s	remaining: 57.1s
# 85:	learn: 0.2523777	total: 5.36s	remaining: 57s
# 86:	learn: 0.2522129	total: 5.42s	remaining: 56.9s
# 87:	learn: 0.2520009	total: 5.48s	remaining: 56.8s
# 88:	learn: 0.2518045	total: 5.54s	remaining: 56.7s
# 89:	learn: 0.2517455	total: 5.59s	remaining: 56.5s
# 90:	learn: 0.2516000	total: 5.65s	remaining: 56.5s
# 91:	learn: 0.2513354	total: 5.71s	remaining: 56.4s
# 92:	learn: 0.2511737	total: 5.77s	remaining: 56.3s
# 93:	learn: 0.2509298	total: 5.83s	remaining: 56.1s
# 94:	learn: 0.2507183	total: 5.89s	remaining: 56.1s
# 95:	learn: 0.2504556	total: 5.95s	remaining: 56s
# 96:	learn: 0.2502686	total: 6s	remaining: 55.9s
# 97:	learn: 0.2500505	total: 6.07s	remaining: 55.9s
# 98:	learn: 0.2499157	total: 6.13s	remaining: 55.8s
# 99:	learn: 0.2498117	total: 6.26s	remaining: 56.4s
# 100:	learn: 0.2495635	total: 6.32s	remaining: 56.3s
# 101:	learn: 0.2493477	total: 6.38s	remaining: 56.2s
# 102:	learn: 0.2491660	total: 6.44s	remaining: 56.1s
# 103:	learn: 0.2489324	total: 6.5s	remaining: 56s
# 104:	learn: 0.2487425	total: 6.56s	remaining: 55.9s
# 105:	learn: 0.2485427	total: 6.63s	remaining: 55.9s
# 106:	learn: 0.2483616	total: 6.69s	remaining: 55.8s
# 107:	learn: 0.2481674	total: 6.75s	remaining: 55.7s
# 108:	learn: 0.2481043	total: 6.8s	remaining: 55.6s
# 109:	learn: 0.2479601	total: 6.87s	remaining: 55.6s
# 110:	learn: 0.2477282	total: 6.93s	remaining: 55.5s
# 111:	learn: 0.2475630	total: 6.98s	remaining: 55.4s
# 112:	learn: 0.2474227	total: 7.04s	remaining: 55.3s
# 113:	learn: 0.2471841	total: 7.11s	remaining: 55.2s
# 114:	learn: 0.2469061	total: 7.17s	remaining: 55.2s
# 115:	learn: 0.2467955	total: 7.23s	remaining: 55.1s
# 116:	learn: 0.2465379	total: 7.29s	remaining: 55s
# 117:	learn: 0.2463587	total: 7.36s	remaining: 55s
# 118:	learn: 0.2462490	total: 7.41s	remaining: 54.9s
# 119:	learn: 0.2460216	total: 7.47s	remaining: 54.8s
# 120:	learn: 0.2459671	total: 7.53s	remaining: 54.7s
# 121:	learn: 0.2457258	total: 7.59s	remaining: 54.6s
# 122:	learn: 0.2454948	total: 7.65s	remaining: 54.6s
# 123:	learn: 0.2453880	total: 7.71s	remaining: 54.5s
# 124:	learn: 0.2452806	total: 7.77s	remaining: 54.4s
# 125:	learn: 0.2452112	total: 7.83s	remaining: 54.3s
# 126:	learn: 0.2451108	total: 7.89s	remaining: 54.2s
# 127:	learn: 0.2449958	total: 7.95s	remaining: 54.2s
# 128:	learn: 0.2447952	total: 8.01s	remaining: 54.1s
# 129:	learn: 0.2445658	total: 8.07s	remaining: 54s
# 130:	learn: 0.2443715	total: 8.13s	remaining: 53.9s
# 131:	learn: 0.2441386	total: 8.19s	remaining: 53.8s
# 132:	learn: 0.2439794	total: 8.25s	remaining: 53.8s
# 133:	learn: 0.2437567	total: 8.31s	remaining: 53.7s
# 134:	learn: 0.2435211	total: 8.37s	remaining: 53.6s
# 135:	learn: 0.2433600	total: 8.43s	remaining: 53.5s
# 136:	learn: 0.2431808	total: 8.48s	remaining: 53.4s
# 137:	learn: 0.2429499	total: 8.55s	remaining: 53.4s
# 138:	learn: 0.2427712	total: 8.61s	remaining: 53.3s
# 139:	learn: 0.2425808	total: 8.67s	remaining: 53.2s
# 140:	learn: 0.2423733	total: 8.73s	remaining: 53.2s
# 141:	learn: 0.2421525	total: 8.79s	remaining: 53.1s
# 142:	learn: 0.2419286	total: 8.85s	remaining: 53.1s
# 143:	learn: 0.2417797	total: 8.91s	remaining: 53s
# 144:	learn: 0.2416244	total: 8.97s	remaining: 52.9s
# 145:	learn: 0.2415257	total: 9.03s	remaining: 52.8s
# 146:	learn: 0.2412777	total: 9.1s	remaining: 52.8s
# 147:	learn: 0.2411284	total: 9.15s	remaining: 52.7s
# 148:	learn: 0.2409991	total: 9.21s	remaining: 52.6s
# 149:	learn: 0.2407597	total: 9.28s	remaining: 52.6s
# 150:	learn: 0.2405659	total: 9.34s	remaining: 52.5s
# 151:	learn: 0.2403695	total: 9.4s	remaining: 52.5s
# 152:	learn: 0.2400739	total: 9.46s	remaining: 52.4s
# 153:	learn: 0.2399939	total: 9.52s	remaining: 52.3s
# 154:	learn: 0.2398948	total: 9.59s	remaining: 52.3s
# 155:	learn: 0.2397081	total: 9.64s	remaining: 52.2s
# 156:	learn: 0.2396438	total: 9.7s	remaining: 52.1s
# 157:	learn: 0.2395159	total: 9.76s	remaining: 52s
# 158:	learn: 0.2393932	total: 9.82s	remaining: 52s
# 159:	learn: 0.2392406	total: 9.88s	remaining: 51.9s
# 160:	learn: 0.2390895	total: 9.94s	remaining: 51.8s
# 161:	learn: 0.2389958	total: 10s	remaining: 51.7s
# 162:	learn: 0.2388709	total: 10.1s	remaining: 51.6s
# 163:	learn: 0.2387119	total: 10.1s	remaining: 51.6s
# 164:	learn: 0.2385975	total: 10.2s	remaining: 51.5s
# 165:	learn: 0.2383690	total: 10.2s	remaining: 51.4s
# 166:	learn: 0.2382094	total: 10.3s	remaining: 51.4s
# 167:	learn: 0.2381360	total: 10.4s	remaining: 51.3s
# 168:	learn: 0.2380168	total: 10.4s	remaining: 51.2s
# 169:	learn: 0.2378252	total: 10.5s	remaining: 51.1s
# 170:	learn: 0.2376969	total: 10.5s	remaining: 51.1s
# 171:	learn: 0.2374753	total: 10.6s	remaining: 51s
# 172:	learn: 0.2373488	total: 10.7s	remaining: 50.9s
# 173:	learn: 0.2372296	total: 10.7s	remaining: 50.9s
# 174:	learn: 0.2371534	total: 10.8s	remaining: 50.8s
# 175:	learn: 0.2370551	total: 10.8s	remaining: 50.7s
# 176:	learn: 0.2368839	total: 10.9s	remaining: 50.7s
# 177:	learn: 0.2367777	total: 11s	remaining: 50.6s
# 178:	learn: 0.2366961	total: 11s	remaining: 50.5s
# 179:	learn: 0.2365634	total: 11.1s	remaining: 50.5s
# 180:	learn: 0.2364744	total: 11.1s	remaining: 50.4s
# 181:	learn: 0.2364378	total: 11.2s	remaining: 50.3s
# 182:	learn: 0.2362767	total: 11.3s	remaining: 50.3s
# 183:	learn: 0.2360962	total: 11.4s	remaining: 50.4s
# 184:	learn: 0.2359222	total: 11.5s	remaining: 50.5s
# 185:	learn: 0.2357847	total: 11.6s	remaining: 50.6s
# 186:	learn: 0.2355481	total: 11.6s	remaining: 50.5s
# 187:	learn: 0.2354902	total: 11.7s	remaining: 50.4s
# 188:	learn: 0.2353353	total: 11.7s	remaining: 50.3s
# 189:	learn: 0.2351551	total: 11.8s	remaining: 50.3s
# 190:	learn: 0.2349554	total: 11.8s	remaining: 50.2s
# 191:	learn: 0.2348897	total: 11.9s	remaining: 50.2s
# 192:	learn: 0.2348557	total: 12s	remaining: 50.1s
# 193:	learn: 0.2346422	total: 12s	remaining: 50s
# 194:	learn: 0.2344452	total: 12.1s	remaining: 50s
# 195:	learn: 0.2342634	total: 12.2s	remaining: 49.9s
# 196:	learn: 0.2342251	total: 12.2s	remaining: 49.8s
# 197:	learn: 0.2341570	total: 12.3s	remaining: 49.8s
# 198:	learn: 0.2339832	total: 12.3s	remaining: 49.7s
# 199:	learn: 0.2338660	total: 12.4s	remaining: 49.6s
# 200:	learn: 0.2338384	total: 12.5s	remaining: 49.6s
# 201:	learn: 0.2337417	total: 12.6s	remaining: 49.6s
# 202:	learn: 0.2336574	total: 12.6s	remaining: 49.5s
# 203:	learn: 0.2334261	total: 12.7s	remaining: 49.5s
# 204:	learn: 0.2333791	total: 12.7s	remaining: 49.4s
# 205:	learn: 0.2332775	total: 12.8s	remaining: 49.3s
# 206:	learn: 0.2331011	total: 12.8s	remaining: 49.2s
# 207:	learn: 0.2329255	total: 12.9s	remaining: 49.2s
# 208:	learn: 0.2328378	total: 13s	remaining: 49.1s
# 209:	learn: 0.2327606	total: 13s	remaining: 49.1s
# 210:	learn: 0.2325897	total: 13.1s	remaining: 49s
# 211:	learn: 0.2324542	total: 13.2s	remaining: 48.9s
# 212:	learn: 0.2322652	total: 13.2s	remaining: 48.9s
# 213:	learn: 0.2320703	total: 13.3s	remaining: 48.8s
# 214:	learn: 0.2318542	total: 13.3s	remaining: 48.7s
# 215:	learn: 0.2317428	total: 13.4s	remaining: 48.6s
# 216:	learn: 0.2315034	total: 13.5s	remaining: 48.6s
# 217:	learn: 0.2314194	total: 13.5s	remaining: 48.5s
# 218:	learn: 0.2311926	total: 13.6s	remaining: 48.4s
# 219:	learn: 0.2310938	total: 13.6s	remaining: 48.3s
# 220:	learn: 0.2309177	total: 13.7s	remaining: 48.2s
# 221:	learn: 0.2308561	total: 13.7s	remaining: 48.1s
# 222:	learn: 0.2307452	total: 13.8s	remaining: 48s
# 223:	learn: 0.2305494	total: 13.8s	remaining: 48s
# 224:	learn: 0.2304608	total: 13.9s	remaining: 47.9s
# 225:	learn: 0.2303057	total: 14s	remaining: 47.8s
# 226:	learn: 0.2302350	total: 14s	remaining: 47.7s
# 227:	learn: 0.2300969	total: 14.1s	remaining: 47.6s
# 228:	learn: 0.2299510	total: 14.1s	remaining: 47.6s
# 229:	learn: 0.2298007	total: 14.2s	remaining: 47.5s
# 230:	learn: 0.2296237	total: 14.2s	remaining: 47.4s
# 231:	learn: 0.2294377	total: 14.3s	remaining: 47.3s
# 232:	learn: 0.2293438	total: 14.4s	remaining: 47.3s
# 233:	learn: 0.2292770	total: 14.4s	remaining: 47.2s
# 234:	learn: 0.2291504	total: 14.5s	remaining: 47.1s
# 235:	learn: 0.2289192	total: 14.5s	remaining: 47s
# 236:	learn: 0.2287579	total: 14.6s	remaining: 47s
# 237:	learn: 0.2286077	total: 14.6s	remaining: 46.9s
# 238:	learn: 0.2284482	total: 14.7s	remaining: 46.8s
# 239:	learn: 0.2284345	total: 14.8s	remaining: 46.7s
# 240:	learn: 0.2283038	total: 14.8s	remaining: 46.7s
# 241:	learn: 0.2281773	total: 14.9s	remaining: 46.6s
# 242:	learn: 0.2281130	total: 14.9s	remaining: 46.5s
# 243:	learn: 0.2279801	total: 15s	remaining: 46.4s
# 244:	learn: 0.2278699	total: 15s	remaining: 46.4s
# 245:	learn: 0.2277153	total: 15.1s	remaining: 46.3s
# 246:	learn: 0.2275592	total: 15.2s	remaining: 46.2s
# 247:	learn: 0.2274357	total: 15.2s	remaining: 46.1s
# 248:	learn: 0.2273907	total: 15.3s	remaining: 46.1s
# 249:	learn: 0.2272538	total: 15.3s	remaining: 46s
# 250:	learn: 0.2272014	total: 15.4s	remaining: 45.9s
# 251:	learn: 0.2270927	total: 15.4s	remaining: 45.9s
# 252:	learn: 0.2269131	total: 15.5s	remaining: 45.8s
# 253:	learn: 0.2267087	total: 15.6s	remaining: 45.7s
# 254:	learn: 0.2265981	total: 15.6s	remaining: 45.6s
# 255:	learn: 0.2264272	total: 15.7s	remaining: 45.6s
# 256:	learn: 0.2262622	total: 15.7s	remaining: 45.5s
# 257:	learn: 0.2261299	total: 15.8s	remaining: 45.4s
# 258:	learn: 0.2259740	total: 15.9s	remaining: 45.4s
# 259:	learn: 0.2258465	total: 15.9s	remaining: 45.3s
# 260:	learn: 0.2257322	total: 16s	remaining: 45.3s
# 261:	learn: 0.2255150	total: 16s	remaining: 45.2s
# 262:	learn: 0.2253976	total: 16.1s	remaining: 45.1s
# 263:	learn: 0.2252064	total: 16.2s	remaining: 45.1s
# 264:	learn: 0.2251796	total: 16.2s	remaining: 45s
# 265:	learn: 0.2251057	total: 16.3s	remaining: 45.1s
# 266:	learn: 0.2250233	total: 16.4s	remaining: 45.1s
# 267:	learn: 0.2249587	total: 16.5s	remaining: 45s
# 268:	learn: 0.2248392	total: 16.5s	remaining: 44.9s
# 269:	learn: 0.2246956	total: 16.6s	remaining: 44.9s
# 270:	learn: 0.2245000	total: 16.7s	remaining: 44.8s
# 271:	learn: 0.2244151	total: 16.7s	remaining: 44.7s
# 272:	learn: 0.2242070	total: 16.8s	remaining: 44.6s
# 273:	learn: 0.2240895	total: 16.8s	remaining: 44.6s
# 274:	learn: 0.2239736	total: 16.9s	remaining: 44.5s
# 275:	learn: 0.2238993	total: 16.9s	remaining: 44.4s
# 276:	learn: 0.2237720	total: 17s	remaining: 44.3s
# 277:	learn: 0.2237200	total: 17s	remaining: 44.3s
# 278:	learn: 0.2236058	total: 17.1s	remaining: 44.2s
# 279:	learn: 0.2234921	total: 17.2s	remaining: 44.1s
# 280:	learn: 0.2234728	total: 17.2s	remaining: 44.1s
# 281:	learn: 0.2233370	total: 17.3s	remaining: 44s
# 282:	learn: 0.2232562	total: 17.3s	remaining: 43.9s
# 283:	learn: 0.2231391	total: 17.4s	remaining: 43.9s
# 284:	learn: 0.2229502	total: 17.4s	remaining: 43.8s
# 285:	learn: 0.2228149	total: 17.5s	remaining: 43.7s
# 286:	learn: 0.2227244	total: 17.6s	remaining: 43.6s
# 287:	learn: 0.2226453	total: 17.6s	remaining: 43.6s
# 288:	learn: 0.2224871	total: 17.7s	remaining: 43.5s
# 289:	learn: 0.2224119	total: 17.7s	remaining: 43.4s
# 290:	learn: 0.2223100	total: 17.8s	remaining: 43.4s
# 291:	learn: 0.2221182	total: 17.9s	remaining: 43.3s
# 292:	learn: 0.2219684	total: 17.9s	remaining: 43.2s
# 293:	learn: 0.2219021	total: 18s	remaining: 43.1s
# 294:	learn: 0.2217743	total: 18s	remaining: 43.1s
# 295:	learn: 0.2216037	total: 18.1s	remaining: 43s
# 296:	learn: 0.2215524	total: 18.1s	remaining: 42.9s
# 297:	learn: 0.2213610	total: 18.2s	remaining: 42.9s
# 298:	learn: 0.2212024	total: 18.3s	remaining: 42.8s
# 299:	learn: 0.2211731	total: 18.3s	remaining: 42.7s
# 300:	learn: 0.2210452	total: 18.4s	remaining: 42.7s
# 301:	learn: 0.2209848	total: 18.4s	remaining: 42.6s
# 302:	learn: 0.2208049	total: 18.5s	remaining: 42.5s
# 303:	learn: 0.2207618	total: 18.5s	remaining: 42.5s
# 304:	learn: 0.2206794	total: 18.6s	remaining: 42.4s
# 305:	learn: 0.2206137	total: 18.7s	remaining: 42.3s
# 306:	learn: 0.2205258	total: 18.7s	remaining: 42.3s
# 307:	learn: 0.2204461	total: 18.8s	remaining: 42.2s
# 308:	learn: 0.2204042	total: 18.8s	remaining: 42.1s
# 309:	learn: 0.2203164	total: 18.9s	remaining: 42s
# 310:	learn: 0.2202682	total: 18.9s	remaining: 42s
# 311:	learn: 0.2202007	total: 19s	remaining: 41.9s
# 312:	learn: 0.2200934	total: 19.1s	remaining: 41.8s
# 313:	learn: 0.2199613	total: 19.1s	remaining: 41.8s
# 314:	learn: 0.2198519	total: 19.2s	remaining: 41.7s
# 315:	learn: 0.2198278	total: 19.2s	remaining: 41.7s
# 316:	learn: 0.2196919	total: 19.3s	remaining: 41.6s
# 317:	learn: 0.2195855	total: 19.4s	remaining: 41.5s
# 318:	learn: 0.2194761	total: 19.4s	remaining: 41.4s
# 319:	learn: 0.2194269	total: 19.5s	remaining: 41.4s
# 320:	learn: 0.2192823	total: 19.5s	remaining: 41.3s
# 321:	learn: 0.2191814	total: 19.6s	remaining: 41.2s
# 322:	learn: 0.2190937	total: 19.6s	remaining: 41.2s
# 323:	learn: 0.2189213	total: 19.7s	remaining: 41.1s
# 324:	learn: 0.2188712	total: 19.8s	remaining: 41s
# 325:	learn: 0.2188395	total: 19.8s	remaining: 41s
# 326:	learn: 0.2187410	total: 19.9s	remaining: 40.9s
# 327:	learn: 0.2187093	total: 19.9s	remaining: 40.8s
# 328:	learn: 0.2186200	total: 20s	remaining: 40.8s
# 329:	learn: 0.2185012	total: 20s	remaining: 40.7s
# 330:	learn: 0.2184506	total: 20.1s	remaining: 40.6s
# 331:	learn: 0.2182979	total: 20.2s	remaining: 40.5s
# 332:	learn: 0.2181427	total: 20.2s	remaining: 40.5s
# 333:	learn: 0.2180382	total: 20.3s	remaining: 40.4s
# 334:	learn: 0.2179745	total: 20.3s	remaining: 40.4s
# 335:	learn: 0.2178985	total: 20.4s	remaining: 40.3s
# 336:	learn: 0.2178176	total: 20.4s	remaining: 40.2s
# 337:	learn: 0.2177600	total: 20.5s	remaining: 40.2s
# 338:	learn: 0.2176458	total: 20.6s	remaining: 40.1s
# 339:	learn: 0.2176265	total: 20.6s	remaining: 40s
# 340:	learn: 0.2175883	total: 20.7s	remaining: 39.9s
# 341:	learn: 0.2175054	total: 20.7s	remaining: 39.9s
# 342:	learn: 0.2174263	total: 20.8s	remaining: 39.8s
# 343:	learn: 0.2173378	total: 20.8s	remaining: 39.7s
# 344:	learn: 0.2171145	total: 20.9s	remaining: 39.7s
# 345:	learn: 0.2169089	total: 21s	remaining: 39.6s
# 346:	learn: 0.2168693	total: 21s	remaining: 39.5s
# 347:	learn: 0.2167906	total: 21.1s	remaining: 39.5s
# 348:	learn: 0.2166870	total: 21.1s	remaining: 39.4s
# 349:	learn: 0.2166067	total: 21.2s	remaining: 39.3s
# 350:	learn: 0.2165464	total: 21.3s	remaining: 39.3s
# 351:	learn: 0.2164016	total: 21.3s	remaining: 39.2s
# 352:	learn: 0.2162930	total: 21.4s	remaining: 39.2s
# 353:	learn: 0.2162280	total: 21.4s	remaining: 39.1s
# 354:	learn: 0.2161112	total: 21.5s	remaining: 39s
# 355:	learn: 0.2160484	total: 21.5s	remaining: 39s
# 356:	learn: 0.2159777	total: 21.6s	remaining: 38.9s
# 357:	learn: 0.2158522	total: 21.6s	remaining: 38.8s
# 358:	learn: 0.2156632	total: 21.7s	remaining: 38.8s
# 359:	learn: 0.2155421	total: 21.8s	remaining: 38.7s
# 360:	learn: 0.2154904	total: 21.8s	remaining: 38.6s
# 361:	learn: 0.2153832	total: 21.9s	remaining: 38.5s
# 362:	learn: 0.2152748	total: 21.9s	remaining: 38.5s
# 363:	learn: 0.2151635	total: 22s	remaining: 38.4s
# 364:	learn: 0.2151034	total: 22s	remaining: 38.4s
# 365:	learn: 0.2150515	total: 22.1s	remaining: 38.3s
# 366:	learn: 0.2149375	total: 22.2s	remaining: 38.2s
# 367:	learn: 0.2148326	total: 22.2s	remaining: 38.2s
# 368:	learn: 0.2146897	total: 22.3s	remaining: 38.1s
# 369:	learn: 0.2146208	total: 22.3s	remaining: 38s
# 370:	learn: 0.2144406	total: 22.4s	remaining: 38s
# 371:	learn: 0.2142975	total: 22.5s	remaining: 37.9s
# 372:	learn: 0.2142074	total: 22.5s	remaining: 37.9s
# 373:	learn: 0.2141047	total: 22.6s	remaining: 37.8s
# 374:	learn: 0.2139686	total: 22.6s	remaining: 37.7s
# 375:	learn: 0.2139264	total: 22.7s	remaining: 37.7s
# 376:	learn: 0.2137868	total: 22.7s	remaining: 37.6s
# 377:	learn: 0.2137526	total: 22.8s	remaining: 37.5s
# 378:	learn: 0.2136937	total: 22.9s	remaining: 37.5s
# 379:	learn: 0.2136757	total: 22.9s	remaining: 37.4s
# 380:	learn: 0.2136399	total: 23s	remaining: 37.4s
# 381:	learn: 0.2134983	total: 23.1s	remaining: 37.3s
# 382:	learn: 0.2134271	total: 23.1s	remaining: 37.2s
# 383:	learn: 0.2134071	total: 23.2s	remaining: 37.2s
# 384:	learn: 0.2132503	total: 23.2s	remaining: 37.1s
# 385:	learn: 0.2131488	total: 23.3s	remaining: 37s
# 386:	learn: 0.2130677	total: 23.3s	remaining: 37s
# 387:	learn: 0.2130321	total: 23.4s	remaining: 36.9s
# 388:	learn: 0.2129289	total: 23.4s	remaining: 36.8s
# 389:	learn: 0.2127932	total: 23.5s	remaining: 36.8s
# 390:	learn: 0.2126778	total: 23.6s	remaining: 36.7s
# 391:	learn: 0.2125913	total: 23.6s	remaining: 36.6s
# 392:	learn: 0.2123985	total: 23.7s	remaining: 36.6s
# 393:	learn: 0.2123528	total: 23.7s	remaining: 36.5s
# 394:	learn: 0.2121868	total: 23.8s	remaining: 36.4s
# 395:	learn: 0.2120603	total: 23.9s	remaining: 36.4s
# 396:	learn: 0.2119607	total: 23.9s	remaining: 36.3s
# 397:	learn: 0.2118178	total: 24s	remaining: 36.3s
# 398:	learn: 0.2117966	total: 24.1s	remaining: 36.2s
# 399:	learn: 0.2117873	total: 24.1s	remaining: 36.2s
# 400:	learn: 0.2117309	total: 24.2s	remaining: 36.1s
# 401:	learn: 0.2115453	total: 24.3s	remaining: 36.1s
# 402:	learn: 0.2113953	total: 24.3s	remaining: 36s
# 403:	learn: 0.2113603	total: 24.4s	remaining: 36s
# 404:	learn: 0.2112598	total: 24.5s	remaining: 35.9s
# 405:	learn: 0.2112009	total: 24.5s	remaining: 35.9s
# 406:	learn: 0.2109864	total: 24.6s	remaining: 35.8s
# 407:	learn: 0.2109079	total: 24.6s	remaining: 35.8s
# 408:	learn: 0.2107639	total: 24.7s	remaining: 35.7s
# 409:	learn: 0.2107015	total: 24.8s	remaining: 35.6s
# 410:	learn: 0.2106155	total: 24.8s	remaining: 35.6s
# 411:	learn: 0.2105058	total: 24.9s	remaining: 35.5s
# 412:	learn: 0.2103788	total: 25s	remaining: 35.5s
# 413:	learn: 0.2102534	total: 25s	remaining: 35.4s
# 414:	learn: 0.2101934	total: 25.1s	remaining: 35.4s
# 415:	learn: 0.2101465	total: 25.2s	remaining: 35.3s
# 416:	learn: 0.2100665	total: 25.2s	remaining: 35.3s
# 417:	learn: 0.2099853	total: 25.3s	remaining: 35.2s
# 418:	learn: 0.2099136	total: 25.4s	remaining: 35.2s
# 419:	learn: 0.2098785	total: 25.4s	remaining: 35.1s
# 420:	learn: 0.2097480	total: 25.5s	remaining: 35s
# 421:	learn: 0.2095832	total: 25.5s	remaining: 35s
# 422:	learn: 0.2095418	total: 25.6s	remaining: 34.9s
# 423:	learn: 0.2093871	total: 25.6s	remaining: 34.8s
# 424:	learn: 0.2093358	total: 25.7s	remaining: 34.8s
# 425:	learn: 0.2092279	total: 25.8s	remaining: 34.8s
# 426:	learn: 0.2091464	total: 25.9s	remaining: 34.7s
# 427:	learn: 0.2090286	total: 25.9s	remaining: 34.7s
# 428:	learn: 0.2088349	total: 26s	remaining: 34.6s
# 429:	learn: 0.2088069	total: 26.1s	remaining: 34.6s
# 430:	learn: 0.2087377	total: 26.1s	remaining: 34.5s
# 431:	learn: 0.2086355	total: 26.2s	remaining: 34.4s
# 432:	learn: 0.2085242	total: 26.2s	remaining: 34.4s
# 433:	learn: 0.2084595	total: 26.3s	remaining: 34.3s
# 434:	learn: 0.2084207	total: 26.3s	remaining: 34.2s
# 435:	learn: 0.2083351	total: 26.4s	remaining: 34.2s
# 436:	learn: 0.2082905	total: 26.5s	remaining: 34.1s
# 437:	learn: 0.2082363	total: 26.5s	remaining: 34s
# 438:	learn: 0.2081477	total: 26.6s	remaining: 34s
# 439:	learn: 0.2080822	total: 26.6s	remaining: 33.9s
# 440:	learn: 0.2079814	total: 26.7s	remaining: 33.8s
# 441:	learn: 0.2079653	total: 26.8s	remaining: 33.8s
# 442:	learn: 0.2078797	total: 26.8s	remaining: 33.7s
# 443:	learn: 0.2078240	total: 26.9s	remaining: 33.6s
# 444:	learn: 0.2077229	total: 26.9s	remaining: 33.6s
# 445:	learn: 0.2076479	total: 27s	remaining: 33.5s
# 446:	learn: 0.2075625	total: 27s	remaining: 33.4s
# 447:	learn: 0.2074632	total: 27.1s	remaining: 33.4s
# 448:	learn: 0.2073714	total: 27.2s	remaining: 33.3s
# 449:	learn: 0.2072714	total: 27.2s	remaining: 33.3s
# 450:	learn: 0.2072420	total: 27.3s	remaining: 33.2s
# 451:	learn: 0.2071652	total: 27.3s	remaining: 33.1s
# 452:	learn: 0.2070724	total: 27.4s	remaining: 33.1s
# 453:	learn: 0.2070018	total: 27.4s	remaining: 33s
# 454:	learn: 0.2068854	total: 27.5s	remaining: 32.9s
# 455:	learn: 0.2068653	total: 27.6s	remaining: 32.9s
# 456:	learn: 0.2067311	total: 27.6s	remaining: 32.8s
# 457:	learn: 0.2066352	total: 27.7s	remaining: 32.7s
# 458:	learn: 0.2065855	total: 27.7s	remaining: 32.7s
# 459:	learn: 0.2065365	total: 27.8s	remaining: 32.6s
# 460:	learn: 0.2063379	total: 27.8s	remaining: 32.5s
# 461:	learn: 0.2061555	total: 27.9s	remaining: 32.5s
# 462:	learn: 0.2061254	total: 27.9s	remaining: 32.4s
# 463:	learn: 0.2060682	total: 28s	remaining: 32.3s
# 464:	learn: 0.2060254	total: 28s	remaining: 32.3s
# 465:	learn: 0.2059260	total: 28.1s	remaining: 32.2s
# 466:	learn: 0.2058708	total: 28.2s	remaining: 32.1s
# 467:	learn: 0.2058299	total: 28.2s	remaining: 32.1s
# 468:	learn: 0.2056697	total: 28.3s	remaining: 32s
# 469:	learn: 0.2055771	total: 28.3s	remaining: 32s
# 470:	learn: 0.2055190	total: 28.4s	remaining: 31.9s
# 471:	learn: 0.2053307	total: 28.4s	remaining: 31.8s
# 472:	learn: 0.2052677	total: 28.5s	remaining: 31.8s
# 473:	learn: 0.2052117	total: 28.6s	remaining: 31.7s
# 474:	learn: 0.2050853	total: 28.6s	remaining: 31.6s
# 475:	learn: 0.2050246	total: 28.7s	remaining: 31.6s
# 476:	learn: 0.2049652	total: 28.7s	remaining: 31.5s
# 477:	learn: 0.2049056	total: 28.8s	remaining: 31.4s
# 478:	learn: 0.2048036	total: 28.8s	remaining: 31.4s
# 479:	learn: 0.2047414	total: 28.9s	remaining: 31.3s
# 480:	learn: 0.2046986	total: 29s	remaining: 31.2s
# 481:	learn: 0.2046611	total: 29s	remaining: 31.2s
# 482:	learn: 0.2045492	total: 29.1s	remaining: 31.1s
# 483:	learn: 0.2044336	total: 29.1s	remaining: 31.1s
# 484:	learn: 0.2043757	total: 29.2s	remaining: 31s
# 485:	learn: 0.2043042	total: 29.2s	remaining: 30.9s
# 486:	learn: 0.2041554	total: 29.3s	remaining: 30.9s
# 487:	learn: 0.2040831	total: 29.4s	remaining: 30.8s
# 488:	learn: 0.2039895	total: 29.4s	remaining: 30.8s
# 489:	learn: 0.2039451	total: 29.5s	remaining: 30.7s
# 490:	learn: 0.2039202	total: 29.5s	remaining: 30.6s
# 491:	learn: 0.2038505	total: 29.6s	remaining: 30.6s
# 492:	learn: 0.2037011	total: 29.7s	remaining: 30.5s
# 493:	learn: 0.2034889	total: 29.7s	remaining: 30.4s
# 494:	learn: 0.2033364	total: 29.8s	remaining: 30.4s
# 495:	learn: 0.2032667	total: 29.8s	remaining: 30.3s
# 496:	learn: 0.2032048	total: 29.9s	remaining: 30.2s
# 497:	learn: 0.2031455	total: 29.9s	remaining: 30.2s
# 498:	learn: 0.2030409	total: 30s	remaining: 30.1s
# 499:	learn: 0.2030105	total: 30.1s	remaining: 30.1s
# 500:	learn: 0.2029635	total: 30.1s	remaining: 30s
# 501:	learn: 0.2029195	total: 30.2s	remaining: 29.9s
# 502:	learn: 0.2027657	total: 30.2s	remaining: 29.9s
# 503:	learn: 0.2027174	total: 30.3s	remaining: 29.8s
# 504:	learn: 0.2026372	total: 30.3s	remaining: 29.7s
# 505:	learn: 0.2024926	total: 30.4s	remaining: 29.7s
# 506:	learn: 0.2024188	total: 30.5s	remaining: 29.6s
# 507:	learn: 0.2023687	total: 30.5s	remaining: 29.6s
# 508:	learn: 0.2021961	total: 30.6s	remaining: 29.5s
# 509:	learn: 0.2021725	total: 30.6s	remaining: 29.4s
# 510:	learn: 0.2020490	total: 30.7s	remaining: 29.4s
# 511:	learn: 0.2019462	total: 30.7s	remaining: 29.3s
# 512:	learn: 0.2019278	total: 30.8s	remaining: 29.2s
# 513:	learn: 0.2018097	total: 30.8s	remaining: 29.2s
# 514:	learn: 0.2017319	total: 30.9s	remaining: 29.1s
# 515:	learn: 0.2016786	total: 31s	remaining: 29s
# 516:	learn: 0.2016427	total: 31s	remaining: 29s
# 517:	learn: 0.2016105	total: 31.1s	remaining: 28.9s
# 518:	learn: 0.2015739	total: 31.1s	remaining: 28.9s
# 519:	learn: 0.2015126	total: 31.2s	remaining: 28.8s
# 520:	learn: 0.2014031	total: 31.2s	remaining: 28.7s
# 521:	learn: 0.2013016	total: 31.3s	remaining: 28.7s
# 522:	learn: 0.2011460	total: 31.4s	remaining: 28.6s
# 523:	learn: 0.2010885	total: 31.4s	remaining: 28.5s
# 524:	learn: 0.2010322	total: 31.5s	remaining: 28.5s
# 525:	learn: 0.2009845	total: 31.5s	remaining: 28.4s
# 526:	learn: 0.2009783	total: 31.6s	remaining: 28.3s
# 527:	learn: 0.2009449	total: 31.6s	remaining: 28.3s
# 528:	learn: 0.2008915	total: 31.7s	remaining: 28.2s
# 529:	learn: 0.2007852	total: 31.7s	remaining: 28.2s
# 530:	learn: 0.2006646	total: 31.8s	remaining: 28.1s
# 531:	learn: 0.2006039	total: 31.9s	remaining: 28s
# 532:	learn: 0.2004143	total: 31.9s	remaining: 28s
# 533:	learn: 0.2003786	total: 32s	remaining: 27.9s
# 534:	learn: 0.2002590	total: 32s	remaining: 27.8s
# 535:	learn: 0.2002066	total: 32.1s	remaining: 27.8s
# 536:	learn: 0.2001755	total: 32.1s	remaining: 27.7s
# 537:	learn: 0.2000686	total: 32.2s	remaining: 27.7s
# 538:	learn: 0.2000525	total: 32.3s	remaining: 27.6s
# 539:	learn: 0.2000219	total: 32.3s	remaining: 27.5s
# 540:	learn: 0.1999838	total: 32.4s	remaining: 27.5s
# 541:	learn: 0.1998373	total: 32.4s	remaining: 27.4s
# 542:	learn: 0.1998071	total: 32.5s	remaining: 27.3s
# 543:	learn: 0.1996630	total: 32.6s	remaining: 27.3s
# 544:	learn: 0.1996045	total: 32.6s	remaining: 27.2s
# 545:	learn: 0.1995418	total: 32.7s	remaining: 27.2s
# 546:	learn: 0.1994815	total: 32.7s	remaining: 27.1s
# 547:	learn: 0.1994354	total: 32.8s	remaining: 27s
# 548:	learn: 0.1993986	total: 32.8s	remaining: 27s
# 549:	learn: 0.1993632	total: 32.9s	remaining: 26.9s
# 550:	learn: 0.1993019	total: 32.9s	remaining: 26.8s
# 551:	learn: 0.1992563	total: 33s	remaining: 26.8s
# 552:	learn: 0.1991990	total: 33.1s	remaining: 26.7s
# 553:	learn: 0.1991785	total: 33.1s	remaining: 26.7s
# 554:	learn: 0.1991082	total: 33.2s	remaining: 26.6s
# 555:	learn: 0.1990296	total: 33.3s	remaining: 26.6s
# 556:	learn: 0.1989757	total: 33.3s	remaining: 26.5s
# 557:	learn: 0.1989459	total: 33.4s	remaining: 26.4s
# 558:	learn: 0.1989363	total: 33.4s	remaining: 26.4s
# 559:	learn: 0.1988939	total: 33.5s	remaining: 26.3s
# 560:	learn: 0.1988558	total: 33.5s	remaining: 26.2s
# 561:	learn: 0.1987943	total: 33.6s	remaining: 26.2s
# 562:	learn: 0.1986838	total: 33.7s	remaining: 26.1s
# 563:	learn: 0.1986225	total: 33.7s	remaining: 26.1s
# 564:	learn: 0.1985819	total: 33.8s	remaining: 26s
# 565:	learn: 0.1985209	total: 33.8s	remaining: 25.9s
# 566:	learn: 0.1984664	total: 33.9s	remaining: 25.9s
# 567:	learn: 0.1984106	total: 33.9s	remaining: 25.8s
# 568:	learn: 0.1983350	total: 34s	remaining: 25.8s
# 569:	learn: 0.1982942	total: 34s	remaining: 25.7s
# 570:	learn: 0.1982550	total: 34.1s	remaining: 25.6s
# 571:	learn: 0.1981957	total: 34.2s	remaining: 25.6s
# 572:	learn: 0.1981705	total: 34.2s	remaining: 25.5s
# 573:	learn: 0.1981569	total: 34.3s	remaining: 25.4s
# 574:	learn: 0.1980940	total: 34.3s	remaining: 25.4s
# 575:	learn: 0.1980462	total: 34.4s	remaining: 25.3s
# 576:	learn: 0.1978513	total: 34.5s	remaining: 25.3s
# 577:	learn: 0.1978167	total: 34.5s	remaining: 25.2s
# 578:	learn: 0.1977785	total: 34.6s	remaining: 25.1s
# 579:	learn: 0.1977675	total: 34.6s	remaining: 25.1s
# 580:	learn: 0.1976654	total: 34.7s	remaining: 25s
# 581:	learn: 0.1975841	total: 34.7s	remaining: 24.9s
# 582:	learn: 0.1975550	total: 34.8s	remaining: 24.9s
# 583:	learn: 0.1974689	total: 34.9s	remaining: 24.8s
# 584:	learn: 0.1974123	total: 34.9s	remaining: 24.8s
# 585:	learn: 0.1973489	total: 35s	remaining: 24.7s
# 586:	learn: 0.1973211	total: 35s	remaining: 24.6s
# 587:	learn: 0.1972750	total: 35.1s	remaining: 24.6s
# 588:	learn: 0.1972386	total: 35.1s	remaining: 24.5s
# 589:	learn: 0.1971696	total: 35.2s	remaining: 24.5s
# 590:	learn: 0.1971403	total: 35.2s	remaining: 24.4s
# 591:	learn: 0.1970824	total: 35.4s	remaining: 24.4s
# 592:	learn: 0.1970150	total: 35.4s	remaining: 24.3s
# 593:	learn: 0.1969779	total: 35.5s	remaining: 24.3s
# 594:	learn: 0.1969325	total: 35.6s	remaining: 24.2s
# 595:	learn: 0.1968778	total: 35.6s	remaining: 24.1s
# 596:	learn: 0.1968355	total: 35.7s	remaining: 24.1s
# 597:	learn: 0.1967945	total: 35.7s	remaining: 24s
# 598:	learn: 0.1967867	total: 35.8s	remaining: 24s
# 599:	learn: 0.1967358	total: 35.8s	remaining: 23.9s
# 600:	learn: 0.1966853	total: 35.9s	remaining: 23.8s
# 601:	learn: 0.1966167	total: 36s	remaining: 23.8s
# 602:	learn: 0.1965804	total: 36s	remaining: 23.7s
# 603:	learn: 0.1965429	total: 36.1s	remaining: 23.7s
# 604:	learn: 0.1964956	total: 36.1s	remaining: 23.6s
# 605:	learn: 0.1964361	total: 36.2s	remaining: 23.5s
# 606:	learn: 0.1964285	total: 36.3s	remaining: 23.5s
# 607:	learn: 0.1964071	total: 36.3s	remaining: 23.4s
# 608:	learn: 0.1962346	total: 36.4s	remaining: 23.3s
# 609:	learn: 0.1961394	total: 36.4s	remaining: 23.3s
# 610:	learn: 0.1961282	total: 36.5s	remaining: 23.2s
# 611:	learn: 0.1960833	total: 36.5s	remaining: 23.2s
# 612:	learn: 0.1960585	total: 36.6s	remaining: 23.1s
# 613:	learn: 0.1959539	total: 36.6s	remaining: 23s
# 614:	learn: 0.1958944	total: 36.7s	remaining: 23s
# 615:	learn: 0.1957600	total: 36.8s	remaining: 22.9s
# 616:	learn: 0.1957032	total: 36.8s	remaining: 22.9s
# 617:	learn: 0.1956071	total: 36.9s	remaining: 22.8s
# 618:	learn: 0.1955967	total: 36.9s	remaining: 22.7s
# 619:	learn: 0.1955074	total: 37s	remaining: 22.7s
# 620:	learn: 0.1954507	total: 37s	remaining: 22.6s
# 621:	learn: 0.1954275	total: 37.1s	remaining: 22.6s
# 622:	learn: 0.1953958	total: 37.2s	remaining: 22.5s
# 623:	learn: 0.1952824	total: 37.2s	remaining: 22.4s
# 624:	learn: 0.1951869	total: 37.3s	remaining: 22.4s
# 625:	learn: 0.1950052	total: 37.3s	remaining: 22.3s
# 626:	learn: 0.1949516	total: 37.4s	remaining: 22.2s
# 627:	learn: 0.1949437	total: 37.4s	remaining: 22.2s
# 628:	learn: 0.1948359	total: 37.5s	remaining: 22.1s
# 629:	learn: 0.1948139	total: 37.6s	remaining: 22.1s
# 630:	learn: 0.1947723	total: 37.6s	remaining: 22s
# 631:	learn: 0.1947223	total: 37.7s	remaining: 21.9s
# 632:	learn: 0.1946604	total: 37.7s	remaining: 21.9s
# 633:	learn: 0.1946067	total: 37.8s	remaining: 21.8s
# 634:	learn: 0.1945741	total: 37.9s	remaining: 21.8s
# 635:	learn: 0.1945060	total: 37.9s	remaining: 21.7s
# 636:	learn: 0.1944467	total: 38s	remaining: 21.6s
# 637:	learn: 0.1943905	total: 38s	remaining: 21.6s
# 638:	learn: 0.1942959	total: 38.1s	remaining: 21.5s
# 639:	learn: 0.1942895	total: 38.2s	remaining: 21.5s
# 640:	learn: 0.1942788	total: 38.2s	remaining: 21.4s
# 641:	learn: 0.1942724	total: 38.3s	remaining: 21.3s
# 642:	learn: 0.1942301	total: 38.3s	remaining: 21.3s
# 643:	learn: 0.1941542	total: 38.4s	remaining: 21.2s
# 644:	learn: 0.1941159	total: 38.4s	remaining: 21.2s
# 645:	learn: 0.1940842	total: 38.5s	remaining: 21.1s
# 646:	learn: 0.1940782	total: 38.5s	remaining: 21s
# 647:	learn: 0.1940513	total: 38.6s	remaining: 21s
# 648:	learn: 0.1940302	total: 38.7s	remaining: 20.9s
# 649:	learn: 0.1939735	total: 38.7s	remaining: 20.8s
# 650:	learn: 0.1939259	total: 38.8s	remaining: 20.8s
# 651:	learn: 0.1936644	total: 38.8s	remaining: 20.7s
# 652:	learn: 0.1936233	total: 38.9s	remaining: 20.7s
# 653:	learn: 0.1935177	total: 38.9s	remaining: 20.6s
# 654:	learn: 0.1934699	total: 39s	remaining: 20.5s
# 655:	learn: 0.1933676	total: 39s	remaining: 20.5s
# 656:	learn: 0.1933354	total: 39.1s	remaining: 20.4s
# 657:	learn: 0.1933033	total: 39.2s	remaining: 20.4s
# 658:	learn: 0.1932730	total: 39.2s	remaining: 20.3s
# 659:	learn: 0.1932438	total: 39.3s	remaining: 20.2s
# 660:	learn: 0.1932121	total: 39.3s	remaining: 20.2s
# 661:	learn: 0.1932050	total: 39.4s	remaining: 20.1s
# 662:	learn: 0.1931692	total: 39.5s	remaining: 20.1s
# 663:	learn: 0.1930874	total: 39.5s	remaining: 20s
# 664:	learn: 0.1930361	total: 39.6s	remaining: 19.9s
# 665:	learn: 0.1929175	total: 39.6s	remaining: 19.9s
# 666:	learn: 0.1928681	total: 39.7s	remaining: 19.8s
# 667:	learn: 0.1928397	total: 39.7s	remaining: 19.8s
# 668:	learn: 0.1928014	total: 39.8s	remaining: 19.7s
# 669:	learn: 0.1926370	total: 39.8s	remaining: 19.6s
# 670:	learn: 0.1924977	total: 39.9s	remaining: 19.6s
# 671:	learn: 0.1924664	total: 40s	remaining: 19.5s
# 672:	learn: 0.1924191	total: 40s	remaining: 19.4s
# 673:	learn: 0.1923754	total: 40.1s	remaining: 19.4s
# 674:	learn: 0.1921883	total: 40.2s	remaining: 19.3s
# 675:	learn: 0.1920704	total: 40.2s	remaining: 19.3s
# 676:	learn: 0.1918865	total: 40.3s	remaining: 19.2s
# 677:	learn: 0.1918468	total: 40.3s	remaining: 19.1s
# 678:	learn: 0.1918037	total: 40.4s	remaining: 19.1s
# 679:	learn: 0.1917348	total: 40.4s	remaining: 19s
# 680:	learn: 0.1916856	total: 40.5s	remaining: 19s
# 681:	learn: 0.1916703	total: 40.5s	remaining: 18.9s
# 682:	learn: 0.1916551	total: 40.6s	remaining: 18.9s
# 683:	learn: 0.1914510	total: 40.7s	remaining: 18.8s
# 684:	learn: 0.1914305	total: 40.7s	remaining: 18.7s
# 685:	learn: 0.1912894	total: 40.8s	remaining: 18.7s
# 686:	learn: 0.1912172	total: 40.8s	remaining: 18.6s
# 687:	learn: 0.1910644	total: 40.9s	remaining: 18.5s
# 688:	learn: 0.1910043	total: 40.9s	remaining: 18.5s
# 689:	learn: 0.1909505	total: 41s	remaining: 18.4s
# 690:	learn: 0.1909436	total: 41.1s	remaining: 18.4s
# 691:	learn: 0.1909331	total: 41.1s	remaining: 18.3s
# 692:	learn: 0.1908964	total: 41.2s	remaining: 18.2s
# 693:	learn: 0.1908406	total: 41.2s	remaining: 18.2s
# 694:	learn: 0.1907856	total: 41.3s	remaining: 18.1s
# 695:	learn: 0.1906963	total: 41.4s	remaining: 18.1s
# 696:	learn: 0.1905344	total: 41.4s	remaining: 18s
# 697:	learn: 0.1904221	total: 41.5s	remaining: 17.9s
# 698:	learn: 0.1903018	total: 41.5s	remaining: 17.9s
# 699:	learn: 0.1902124	total: 41.6s	remaining: 17.8s
# 700:	learn: 0.1901912	total: 41.6s	remaining: 17.8s
# 701:	learn: 0.1901853	total: 41.7s	remaining: 17.7s
# 702:	learn: 0.1901271	total: 41.8s	remaining: 17.6s
# 703:	learn: 0.1900889	total: 41.8s	remaining: 17.6s
# 704:	learn: 0.1899444	total: 41.9s	remaining: 17.5s
# 705:	learn: 0.1899120	total: 41.9s	remaining: 17.5s
# 706:	learn: 0.1898978	total: 42s	remaining: 17.4s
# 707:	learn: 0.1898614	total: 42s	remaining: 17.3s
# 708:	learn: 0.1898492	total: 42.1s	remaining: 17.3s
# 709:	learn: 0.1897844	total: 42.1s	remaining: 17.2s
# 710:	learn: 0.1897731	total: 42.2s	remaining: 17.2s
# 711:	learn: 0.1896508	total: 42.3s	remaining: 17.1s
# 712:	learn: 0.1894941	total: 42.3s	remaining: 17s
# 713:	learn: 0.1894062	total: 42.4s	remaining: 17s
# 714:	learn: 0.1893158	total: 42.4s	remaining: 16.9s
# 715:	learn: 0.1892685	total: 42.5s	remaining: 16.9s
# 716:	learn: 0.1891843	total: 42.6s	remaining: 16.8s
# 717:	learn: 0.1891378	total: 42.6s	remaining: 16.7s
# 718:	learn: 0.1890896	total: 42.7s	remaining: 16.7s
# 719:	learn: 0.1890843	total: 42.7s	remaining: 16.6s
# 720:	learn: 0.1890775	total: 42.8s	remaining: 16.6s
# 721:	learn: 0.1888800	total: 42.8s	remaining: 16.5s
# 722:	learn: 0.1888320	total: 42.9s	remaining: 16.4s
# 723:	learn: 0.1887824	total: 43s	remaining: 16.4s
# 724:	learn: 0.1887614	total: 43s	remaining: 16.3s
# 725:	learn: 0.1886658	total: 43.1s	remaining: 16.3s
# 726:	learn: 0.1886314	total: 43.1s	remaining: 16.2s
# 727:	learn: 0.1884867	total: 43.2s	remaining: 16.1s
# 728:	learn: 0.1884756	total: 43.3s	remaining: 16.1s
# 729:	learn: 0.1884625	total: 43.3s	remaining: 16s
# 730:	learn: 0.1883352	total: 43.4s	remaining: 16s
# 731:	learn: 0.1882766	total: 43.4s	remaining: 15.9s
# 732:	learn: 0.1881602	total: 43.5s	remaining: 15.8s
# 733:	learn: 0.1881331	total: 43.5s	remaining: 15.8s
# 734:	learn: 0.1881159	total: 43.6s	remaining: 15.7s
# 735:	learn: 0.1880649	total: 43.7s	remaining: 15.7s
# 736:	learn: 0.1880310	total: 43.7s	remaining: 15.6s
# 737:	learn: 0.1879046	total: 43.8s	remaining: 15.5s
# 738:	learn: 0.1878731	total: 43.8s	remaining: 15.5s
# 739:	learn: 0.1878667	total: 43.9s	remaining: 15.4s
# 740:	learn: 0.1878156	total: 43.9s	remaining: 15.4s
# 741:	learn: 0.1877938	total: 44s	remaining: 15.3s
# 742:	learn: 0.1876688	total: 44.1s	remaining: 15.2s
# 743:	learn: 0.1876363	total: 44.1s	remaining: 15.2s
# 744:	learn: 0.1876133	total: 44.2s	remaining: 15.1s
# 745:	learn: 0.1876054	total: 44.2s	remaining: 15.1s
# 746:	learn: 0.1874875	total: 44.3s	remaining: 15s
# 747:	learn: 0.1874773	total: 44.3s	remaining: 14.9s
# 748:	learn: 0.1874668	total: 44.4s	remaining: 14.9s
# 749:	learn: 0.1873853	total: 44.4s	remaining: 14.8s
# 750:	learn: 0.1873739	total: 44.5s	remaining: 14.8s
# 751:	learn: 0.1873678	total: 44.6s	remaining: 14.7s
# 752:	learn: 0.1873515	total: 44.6s	remaining: 14.6s
# 753:	learn: 0.1872438	total: 44.7s	remaining: 14.6s
# 754:	learn: 0.1870564	total: 44.7s	remaining: 14.5s
# 755:	learn: 0.1868911	total: 44.8s	remaining: 14.5s
# 756:	learn: 0.1868800	total: 44.8s	remaining: 14.4s
# 757:	learn: 0.1868334	total: 44.9s	remaining: 14.3s
# 758:	learn: 0.1867841	total: 45s	remaining: 14.3s
# 759:	learn: 0.1866922	total: 45s	remaining: 14.2s
# 760:	learn: 0.1866816	total: 45.1s	remaining: 14.2s
# 761:	learn: 0.1866734	total: 45.1s	remaining: 14.1s
# 762:	learn: 0.1866417	total: 45.2s	remaining: 14s
# 763:	learn: 0.1865827	total: 45.2s	remaining: 14s
# 764:	learn: 0.1865728	total: 45.3s	remaining: 13.9s
# 765:	learn: 0.1865657	total: 45.4s	remaining: 13.9s
# 766:	learn: 0.1865307	total: 45.4s	remaining: 13.8s
# 767:	learn: 0.1865053	total: 45.5s	remaining: 13.8s
# 768:	learn: 0.1864943	total: 45.6s	remaining: 13.7s
# 769:	learn: 0.1864470	total: 45.7s	remaining: 13.6s
# 770:	learn: 0.1864373	total: 45.7s	remaining: 13.6s
# 771:	learn: 0.1864204	total: 45.8s	remaining: 13.5s
# 772:	learn: 0.1864003	total: 45.8s	remaining: 13.5s
# 773:	learn: 0.1863537	total: 45.9s	remaining: 13.4s
# 774:	learn: 0.1863432	total: 46s	remaining: 13.3s
# 775:	learn: 0.1863099	total: 46s	remaining: 13.3s
# 776:	learn: 0.1862797	total: 46.1s	remaining: 13.2s
# 777:	learn: 0.1862126	total: 46.1s	remaining: 13.2s
# 778:	learn: 0.1862037	total: 46.2s	remaining: 13.1s
# 779:	learn: 0.1861622	total: 46.2s	remaining: 13s
# 780:	learn: 0.1861424	total: 46.3s	remaining: 13s
# 781:	learn: 0.1860938	total: 46.4s	remaining: 12.9s
# 782:	learn: 0.1860259	total: 46.4s	remaining: 12.9s
# 783:	learn: 0.1859821	total: 46.5s	remaining: 12.8s
# 784:	learn: 0.1859123	total: 46.5s	remaining: 12.7s
# 785:	learn: 0.1858910	total: 46.6s	remaining: 12.7s
# 786:	learn: 0.1857159	total: 46.7s	remaining: 12.6s
# 787:	learn: 0.1857084	total: 46.7s	remaining: 12.6s
# 788:	learn: 0.1856797	total: 46.8s	remaining: 12.5s
# 789:	learn: 0.1856111	total: 46.8s	remaining: 12.5s
# 790:	learn: 0.1854112	total: 46.9s	remaining: 12.4s
# 791:	learn: 0.1853830	total: 47s	remaining: 12.3s
# 792:	learn: 0.1852036	total: 47s	remaining: 12.3s
# 793:	learn: 0.1851966	total: 47.1s	remaining: 12.2s
# 794:	learn: 0.1850221	total: 47.1s	remaining: 12.2s
# 795:	learn: 0.1850170	total: 47.2s	remaining: 12.1s
# 796:	learn: 0.1849797	total: 47.3s	remaining: 12s
# 797:	learn: 0.1848927	total: 47.3s	remaining: 12s
# 798:	learn: 0.1848624	total: 47.4s	remaining: 11.9s
# 799:	learn: 0.1848202	total: 47.4s	remaining: 11.9s
# 800:	learn: 0.1846837	total: 47.5s	remaining: 11.8s
# 801:	learn: 0.1846659	total: 47.5s	remaining: 11.7s
# 802:	learn: 0.1845939	total: 47.6s	remaining: 11.7s
# 803:	learn: 0.1843711	total: 47.7s	remaining: 11.6s
# 804:	learn: 0.1843615	total: 47.7s	remaining: 11.6s
# 805:	learn: 0.1843165	total: 47.8s	remaining: 11.5s
# 806:	learn: 0.1842007	total: 47.8s	remaining: 11.4s
# 807:	learn: 0.1841705	total: 47.9s	remaining: 11.4s
# 808:	learn: 0.1841229	total: 47.9s	remaining: 11.3s
# 809:	learn: 0.1839726	total: 48s	remaining: 11.3s
# 810:	learn: 0.1839195	total: 48s	remaining: 11.2s
# 811:	learn: 0.1838810	total: 48.1s	remaining: 11.1s
# 812:	learn: 0.1838330	total: 48.2s	remaining: 11.1s
# 813:	learn: 0.1838139	total: 48.2s	remaining: 11s
# 814:	learn: 0.1837771	total: 48.3s	remaining: 11s
# 815:	learn: 0.1836063	total: 48.3s	remaining: 10.9s
# 816:	learn: 0.1835897	total: 48.4s	remaining: 10.8s
# 817:	learn: 0.1835846	total: 48.5s	remaining: 10.8s
# 818:	learn: 0.1835231	total: 48.5s	remaining: 10.7s
# 819:	learn: 0.1832715	total: 48.6s	remaining: 10.7s
# 820:	learn: 0.1832617	total: 48.6s	remaining: 10.6s
# 821:	learn: 0.1832159	total: 48.7s	remaining: 10.5s
# 822:	learn: 0.1831903	total: 48.7s	remaining: 10.5s
# 823:	learn: 0.1831441	total: 48.8s	remaining: 10.4s
# 824:	learn: 0.1829812	total: 48.8s	remaining: 10.4s
# 825:	learn: 0.1829605	total: 48.9s	remaining: 10.3s
# 826:	learn: 0.1829136	total: 49s	remaining: 10.2s
# 827:	learn: 0.1828736	total: 49s	remaining: 10.2s
# 828:	learn: 0.1828678	total: 49.1s	remaining: 10.1s
# 829:	learn: 0.1828228	total: 49.1s	remaining: 10.1s
# 830:	learn: 0.1827788	total: 49.2s	remaining: 10s
# 831:	learn: 0.1827731	total: 49.2s	remaining: 9.94s
# 832:	learn: 0.1827406	total: 49.3s	remaining: 9.88s
# 833:	learn: 0.1825934	total: 49.4s	remaining: 9.82s
# 834:	learn: 0.1825882	total: 49.4s	remaining: 9.77s
# 835:	learn: 0.1825259	total: 49.5s	remaining: 9.71s
# 836:	learn: 0.1824525	total: 49.5s	remaining: 9.65s
# 837:	learn: 0.1824111	total: 49.6s	remaining: 9.59s
# 838:	learn: 0.1823245	total: 49.6s	remaining: 9.53s
# 839:	learn: 0.1823194	total: 49.7s	remaining: 9.47s
# 840:	learn: 0.1822204	total: 49.8s	remaining: 9.41s
# 841:	learn: 0.1821765	total: 49.8s	remaining: 9.35s
# 842:	learn: 0.1821323	total: 49.9s	remaining: 9.29s
# 843:	learn: 0.1821040	total: 49.9s	remaining: 9.23s
# 844:	learn: 0.1820782	total: 50s	remaining: 9.17s
# 845:	learn: 0.1819781	total: 50s	remaining: 9.11s
# 846:	learn: 0.1819535	total: 50.1s	remaining: 9.05s
# 847:	learn: 0.1819098	total: 50.1s	remaining: 8.99s
# 848:	learn: 0.1818460	total: 50.2s	remaining: 8.93s
# 849:	learn: 0.1818030	total: 50.3s	remaining: 8.87s
# 850:	learn: 0.1817288	total: 50.3s	remaining: 8.81s
# 851:	learn: 0.1816582	total: 50.4s	remaining: 8.75s
# 852:	learn: 0.1814402	total: 50.4s	remaining: 8.69s
# 853:	learn: 0.1813173	total: 50.5s	remaining: 8.63s
# 854:	learn: 0.1812601	total: 50.5s	remaining: 8.57s
# 855:	learn: 0.1812094	total: 50.6s	remaining: 8.51s
# 856:	learn: 0.1811977	total: 50.7s	remaining: 8.45s
# 857:	learn: 0.1811661	total: 50.7s	remaining: 8.39s
# 858:	learn: 0.1811420	total: 50.8s	remaining: 8.33s
# 859:	learn: 0.1811008	total: 50.8s	remaining: 8.27s
# 860:	learn: 0.1810578	total: 50.9s	remaining: 8.21s
# 861:	learn: 0.1810385	total: 50.9s	remaining: 8.15s
# 862:	learn: 0.1809826	total: 51s	remaining: 8.09s
# 863:	learn: 0.1808550	total: 51s	remaining: 8.04s
# 864:	learn: 0.1808128	total: 51.1s	remaining: 7.98s
# 865:	learn: 0.1807894	total: 51.2s	remaining: 7.92s
# 866:	learn: 0.1807494	total: 51.2s	remaining: 7.86s
# 867:	learn: 0.1807389	total: 51.3s	remaining: 7.8s
# 868:	learn: 0.1806056	total: 51.3s	remaining: 7.74s
# 869:	learn: 0.1805700	total: 51.4s	remaining: 7.68s
# 870:	learn: 0.1805312	total: 51.5s	remaining: 7.62s
# 871:	learn: 0.1805128	total: 51.5s	remaining: 7.56s
# 872:	learn: 0.1804078	total: 51.6s	remaining: 7.5s
# 873:	learn: 0.1803936	total: 51.6s	remaining: 7.44s
# 874:	learn: 0.1803434	total: 51.7s	remaining: 7.38s
# 875:	learn: 0.1803003	total: 51.7s	remaining: 7.32s
# 876:	learn: 0.1802956	total: 51.8s	remaining: 7.26s
# 877:	learn: 0.1802629	total: 51.9s	remaining: 7.21s
# 878:	learn: 0.1802571	total: 51.9s	remaining: 7.14s
# 879:	learn: 0.1801163	total: 52s	remaining: 7.09s
# 880:	learn: 0.1800929	total: 52s	remaining: 7.03s
# 881:	learn: 0.1800717	total: 52.1s	remaining: 6.97s
# 882:	learn: 0.1800421	total: 52.1s	remaining: 6.91s
# 883:	learn: 0.1799151	total: 52.2s	remaining: 6.85s
# 884:	learn: 0.1798823	total: 52.3s	remaining: 6.79s
# 885:	learn: 0.1796774	total: 52.3s	remaining: 6.73s
# 886:	learn: 0.1796572	total: 52.4s	remaining: 6.67s
# 887:	learn: 0.1796140	total: 52.4s	remaining: 6.61s
# 888:	learn: 0.1796053	total: 52.5s	remaining: 6.55s
# 889:	learn: 0.1795776	total: 52.5s	remaining: 6.49s
# 890:	learn: 0.1794392	total: 52.6s	remaining: 6.43s
# 891:	learn: 0.1794086	total: 52.7s	remaining: 6.38s
# 892:	learn: 0.1792229	total: 52.7s	remaining: 6.32s
# 893:	learn: 0.1791846	total: 52.8s	remaining: 6.26s
# 894:	learn: 0.1791556	total: 52.8s	remaining: 6.2s
# 895:	learn: 0.1790629	total: 52.9s	remaining: 6.14s
# 896:	learn: 0.1789765	total: 52.9s	remaining: 6.08s
# 897:	learn: 0.1789636	total: 53s	remaining: 6.02s
# 898:	learn: 0.1789445	total: 53.1s	remaining: 5.96s
# 899:	learn: 0.1789394	total: 53.1s	remaining: 5.91s
# 900:	learn: 0.1789038	total: 53.2s	remaining: 5.85s
# 901:	learn: 0.1788919	total: 53.3s	remaining: 5.79s
# 902:	learn: 0.1788139	total: 53.3s	remaining: 5.73s
# 903:	learn: 0.1787321	total: 53.4s	remaining: 5.67s
# 904:	learn: 0.1787055	total: 53.5s	remaining: 5.61s
# 905:	learn: 0.1785101	total: 53.5s	remaining: 5.55s
# 906:	learn: 0.1784711	total: 53.6s	remaining: 5.49s
# 907:	learn: 0.1783660	total: 53.6s	remaining: 5.43s
# 908:	learn: 0.1783238	total: 53.7s	remaining: 5.37s
# 909:	learn: 0.1782185	total: 53.7s	remaining: 5.31s
# 910:	learn: 0.1780752	total: 53.8s	remaining: 5.25s
# 911:	learn: 0.1780563	total: 53.8s	remaining: 5.2s
# 912:	learn: 0.1780503	total: 53.9s	remaining: 5.14s
# 913:	learn: 0.1780280	total: 54s	remaining: 5.08s
# 914:	learn: 0.1778780	total: 54s	remaining: 5.02s
# 915:	learn: 0.1778333	total: 54.1s	remaining: 4.96s
# 916:	learn: 0.1777900	total: 54.2s	remaining: 4.9s
# 917:	learn: 0.1777815	total: 54.2s	remaining: 4.84s
# 918:	learn: 0.1776267	total: 54.3s	remaining: 4.78s
# 919:	learn: 0.1776223	total: 54.3s	remaining: 4.72s
# 920:	learn: 0.1774679	total: 54.4s	remaining: 4.66s
# 921:	learn: 0.1774322	total: 54.4s	remaining: 4.61s
# 922:	learn: 0.1772773	total: 54.5s	remaining: 4.54s
# 923:	learn: 0.1772519	total: 54.5s	remaining: 4.49s
# 924:	learn: 0.1770383	total: 54.6s	remaining: 4.43s
# 925:	learn: 0.1769070	total: 54.7s	remaining: 4.37s
# 926:	learn: 0.1768882	total: 54.7s	remaining: 4.31s
# 927:	learn: 0.1767629	total: 54.8s	remaining: 4.25s
# 928:	learn: 0.1766320	total: 54.8s	remaining: 4.19s
# 929:	learn: 0.1765379	total: 54.9s	remaining: 4.13s
# 930:	learn: 0.1765074	total: 54.9s	remaining: 4.07s
# 931:	learn: 0.1764404	total: 55s	remaining: 4.01s
# 932:	learn: 0.1764127	total: 55.1s	remaining: 3.95s
# 933:	learn: 0.1763327	total: 55.1s	remaining: 3.9s
# 934:	learn: 0.1763237	total: 55.2s	remaining: 3.84s
# 935:	learn: 0.1762944	total: 55.2s	remaining: 3.78s
# 936:	learn: 0.1762471	total: 55.4s	remaining: 3.72s
# 937:	learn: 0.1760871	total: 55.4s	remaining: 3.66s
# 938:	learn: 0.1759222	total: 55.5s	remaining: 3.6s
# 939:	learn: 0.1758356	total: 55.5s	remaining: 3.54s
# 940:	learn: 0.1756848	total: 55.6s	remaining: 3.48s
# 941:	learn: 0.1755615	total: 55.7s	remaining: 3.43s
# 942:	learn: 0.1755521	total: 55.7s	remaining: 3.37s
# 943:	learn: 0.1755477	total: 55.8s	remaining: 3.31s
# 944:	learn: 0.1755399	total: 55.8s	remaining: 3.25s
# 945:	learn: 0.1754279	total: 55.9s	remaining: 3.19s
# 946:	learn: 0.1754238	total: 55.9s	remaining: 3.13s
# 947:	learn: 0.1753820	total: 56s	remaining: 3.07s
# 948:	learn: 0.1753307	total: 56.1s	remaining: 3.01s
# 949:	learn: 0.1752969	total: 56.1s	remaining: 2.95s
# 950:	learn: 0.1752023	total: 56.2s	remaining: 2.89s
# 951:	learn: 0.1751799	total: 56.2s	remaining: 2.83s
# 952:	learn: 0.1750953	total: 56.3s	remaining: 2.78s
# 953:	learn: 0.1750625	total: 56.3s	remaining: 2.72s
# 954:	learn: 0.1750154	total: 56.4s	remaining: 2.66s
# 955:	learn: 0.1749984	total: 56.5s	remaining: 2.6s
# 956:	learn: 0.1749149	total: 56.5s	remaining: 2.54s
# 957:	learn: 0.1748293	total: 56.6s	remaining: 2.48s
# 958:	learn: 0.1747987	total: 56.6s	remaining: 2.42s
# 959:	learn: 0.1747808	total: 56.7s	remaining: 2.36s
# 960:	learn: 0.1746136	total: 56.7s	remaining: 2.3s
# 961:	learn: 0.1745951	total: 56.8s	remaining: 2.24s
# 962:	learn: 0.1745735	total: 56.9s	remaining: 2.18s
# 963:	learn: 0.1745199	total: 56.9s	remaining: 2.13s
# 964:	learn: 0.1744832	total: 57s	remaining: 2.07s
# 965:	learn: 0.1744465	total: 57s	remaining: 2.01s
# 966:	learn: 0.1744405	total: 57.1s	remaining: 1.95s
# 967:	learn: 0.1743981	total: 57.1s	remaining: 1.89s
# 968:	learn: 0.1743907	total: 57.2s	remaining: 1.83s
# 969:	learn: 0.1742245	total: 57.3s	remaining: 1.77s
# 970:	learn: 0.1741934	total: 57.3s	remaining: 1.71s
# 971:	learn: 0.1740617	total: 57.4s	remaining: 1.65s
# 972:	learn: 0.1740433	total: 57.4s	remaining: 1.59s
# 973:	learn: 0.1740083	total: 57.5s	remaining: 1.53s
# 974:	learn: 0.1740000	total: 57.5s	remaining: 1.48s
# 975:	learn: 0.1739958	total: 57.6s	remaining: 1.42s
# 976:	learn: 0.1739734	total: 57.7s	remaining: 1.36s
# 977:	learn: 0.1738437	total: 57.7s	remaining: 1.3s
# 978:	learn: 0.1737007	total: 57.8s	remaining: 1.24s
# 979:	learn: 0.1735666	total: 57.8s	remaining: 1.18s
# 980:	learn: 0.1734969	total: 57.9s	remaining: 1.12s
# 981:	learn: 0.1734170	total: 57.9s	remaining: 1.06s
# 982:	learn: 0.1733707	total: 58s	remaining: 1s
# 983:	learn: 0.1732568	total: 58.1s	remaining: 944ms
# 984:	learn: 0.1732016	total: 58.1s	remaining: 885ms
# 985:	learn: 0.1731647	total: 58.2s	remaining: 826ms
# 986:	learn: 0.1731565	total: 58.2s	remaining: 767ms
# 987:	learn: 0.1731143	total: 58.3s	remaining: 708ms
# 988:	learn: 0.1730792	total: 58.4s	remaining: 649ms
# 989:	learn: 0.1729449	total: 58.4s	remaining: 590ms
# 990:	learn: 0.1729169	total: 58.5s	remaining: 531ms
# 991:	learn: 0.1728867	total: 58.5s	remaining: 472ms
# 992:	learn: 0.1727727	total: 58.6s	remaining: 413ms
# 993:	learn: 0.1726699	total: 58.6s	remaining: 354ms
# 994:	learn: 0.1725529	total: 58.7s	remaining: 295ms
# 995:	learn: 0.1725471	total: 58.8s	remaining: 236ms
# 996:	learn: 0.1724192	total: 58.8s	remaining: 177ms
# 997:	learn: 0.1722483	total: 58.9s	remaining: 118ms
# 998:	learn: 0.1722111	total: 58.9s	remaining: 59ms
# 999:	learn: 0.1721979	total: 59s	remaining: 0us
# Топ-20 признаков для CatBoost: ['day_Monday', 'brent_cost_rollstd3', 'outcome_lag1', 'balance_lag3', 'day_Thursday', 'balance_lag1', 'is_non_working_day', 'brent_cost_rollstd7', 'balance_rollmean3', 'balance_rollmean7', '3M_rollstd7', 'ON_rollstd7', 'income_rollstd3', 'gold_cost_rub_rollstd7', 'income_rollmean3', 'balance_rollstd3', 'income_lag2', 'usd_rub_rollstd7', 'outcome_lag2', '2W_rollstd7']
#       Model       MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  CatBoost  0.183613  0.183613                     3.643122e-08
#
#    normalized_add_margin  delta_pnl
# 0               0.000022  -0.300723
#       Model       MAE  mae_cust  calculate_add_margin_vectorized  \
# 0  CatBoost  0.183613  0.183613                     3.643122e-08
#
#    normalized_add_margin  delta_pnl
# 0               0.000022  -0.300723

# %% [markdown]
# ### Выводы по результатам моделей
#
# По итогам тестирования моделей прогнозирования сальдо были получены следующие результаты:
#
# - **RandomForest** показал наименьшую ошибку MAE (**0.171**) среди всех моделей. Однако его значение метрики `delta_pnl` оказалось самым высоким по модулю (**–0.378**), что свидетельствует о потенциально большем отрицательном влиянии на итоговый финансовый результат в случае ошибок прогноза.
# - **CatBoost** продемонстрировал MAE чуть выше (**0.183**), при этом его `delta_pnl` составил **–0.300**, что лучше, чем у RandomForest. Однако общий уровень ошибки остаётся выше, а финансовый эффект (normalized_add_margin) не даёт явных преимуществ.
# - **LGBM** показал MAE на уровне **0.185**, то есть несколько выше, чем у RandomForest и CatBoost. При этом у него лучший результат по нормализованной бизнес-метрике: значение `normalized_add_margin` положительное (**0.000332**), что означает потенциальный прирост маржи, а не её потерю. Хотя `delta_pnl` составляет **–0.423**, это значение необходимо интерпретировать осторожно в контексте основной метрики — прибыльности и стабильности модели.
#
# ### Обоснование выбора LGBM
#
# Несмотря на то, что LGBM показал чуть более высокую абсолютную ошибку MAE по сравнению с другими моделями, его выбор оправдан по следующим причинам:
#
# 1. **Бизнес-ориентированная метрика важнее простой точности:**
#    Основная задача модели — не просто минимизировать MAE, а способствовать увеличению маржи при принятии решений по управлению ликвидностью. LGBM — единственная модель, которая дала положительное значение `normalized_add_margin`, что свидетельствует о потенциальной способности увеличивать доходность.
#
# 2. **Баланс между ошибкой прогноза и финансовым эффектом:**
#    LGBM обеспечивает приемлемый уровень ошибки  и при этом минимизирует риски упущенной прибыли за счёт положительного вклада в маржу. Для целей проекта такой баланс между точностью и финансовой выгодой важнее минимальной ошибки MAE сама по себе.
#
# 3. **Гибкость и скорость обучения:**
#    LGBM обладает высокой скоростью обучения и возможностями для эффективного тюнинга гиперпараметров, что важно в рамках автоматизированного пайплайна с периодическим дообучением модели. Это упрощает интеграцию модели в рабочий процесс.
#
# 4. **Стабильность на временных рядах:**
#    По опыту применения LGBM в задачах прогнозирования временных рядов модель хорошо справляется с сложными нелинейными зависимостями и устойчива к небольшим изменениям распределения данных, что критично в условиях нестабильности финансовых потоков.

# %% [markdown]
# # **Блок 7. Обнаружение разладок (CUSUM)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

class UniversalCUSUMDetector:
    def __init__(self, mode="adaptive", threshold=5.0, drift=0.01, min_distance=30,
                 alpha=0.02, beta=0.02, mean_diff=0.3):
        assert mode in ["adaptive", "hybrid"], "mode must be 'adaptive' or 'hybrid'"
        self.mode = mode
        self.threshold = threshold
        self.drift = drift
        self.min_distance = min_distance
        self.alpha = alpha
        self.beta = beta
        self.mean_diff = mean_diff
        self.reset()

    def reset(self):
        self.mean_sum = None
        self.mean_weights_sum = 0
        self.var_sum = None
        self.var_weights_sum = 0
        self.mean_estimate = 0
        self.var_estimate = 1
        self.stat = 0
        self.gp = 0
        self.gn = 0
        self.raw_cps = []

    def detect(self, series):
        data = series.values
        mean = np.mean(data)  # для классического CUSUM в режиме 'hybrid'

        for i, x in enumerate(data):
            if self.mode == "hybrid":
                # --- Классический CUSUM ---
                self.gp = max(0, self.gp + x - mean - self.drift)
                self.gn = min(0, self.gn + x - mean + self.drift)

                if self.gp > self.threshold or self.gn < -self.threshold:
                    self.raw_cps.append(i)
                    self.gp = 0
                    self.gn = 0

            # --- Адаптивный CUSUM ---
            if self.mean_sum is not None:
                self.mean_estimate = self.mean_sum / self.mean_weights_sum
                self.var_estimate = self.var_sum / self.var_weights_sum
                normalized = (x - self.mean_estimate) / np.sqrt(self.var_estimate)
                self.mean_sum = (1 - self.alpha) * self.mean_sum + x
                self.mean_weights_sum = (1 - self.alpha) * self.mean_weights_sum + 1.0
                self.var_sum = (1 - self.beta) * self.var_sum + (normalized - self.mean_estimate) ** 2
                self.var_weights_sum = (1 - self.beta) * self.var_weights_sum + 1.0
            else:
                self.mean_sum = x
                self.mean_weights_sum = 1.0
                normalized = (x - self.mean_estimate) / np.sqrt(self.var_estimate)
                self.var_sum = (normalized - self.mean_estimate) ** 2
                self.var_weights_sum = 1.0

            zeta_k = np.log(norm.pdf(normalized, self.mean_diff, 1) / norm.pdf(normalized, 0., 1))
            self.stat = max(0, self.stat + zeta_k)

            if self.stat > self.threshold:
                self.raw_cps.append(i)
                self.stat = 0  # сброс адаптивной статистики

        # --- Фильтрация по min_distance ---
        filtered_cps = []
        last_cp = -self.min_distance
        for cp in sorted(set(self.raw_cps)):
            if cp - last_cp >= self.min_distance:
                filtered_cps.append(cp)
                last_cp = cp

        return filtered_cps
    
    def update(self, x):
        if self.mode == "hybrid":
            if self.mean_sum is None:
                self.mean_sum = x
                self.mean_weights_sum = 1.0
            mean = self.mean_sum / self.mean_weights_sum

            self.gp = max(0, self.gp + x - mean - self.drift)
            self.gn = min(0, self.gn + x - mean + self.drift)

            if self.gp > self.threshold or self.gn < -self.threshold:
                self.gp = 0
                self.gn = 0
                return True
            else:
                return False

        else:  # mode == 'adaptive'
            if self.mean_sum is not None:
                self.mean_estimate = self.mean_sum / self.mean_weights_sum
                self.var_estimate = self.var_sum / self.var_weights_sum
                normalized = (x - self.mean_estimate) / np.sqrt(self.var_estimate)
                self.mean_sum = (1 - self.alpha) * self.mean_sum + x
                self.mean_weights_sum = (1 - self.alpha) * self.mean_weights_sum + 1.0
                self.var_sum = (1 - self.beta) * self.var_sum + (normalized - self.mean_estimate) ** 2
                self.var_weights_sum = (1 - self.beta) * self.var_weights_sum + 1.0
            else:
                self.mean_sum = x
                self.mean_weights_sum = 1.0
                normalized = (x - self.mean_estimate) / np.sqrt(self.var_estimate)
                self.var_sum = (normalized - self.mean_estimate) ** 2
                self.var_weights_sum = 1.0

            zeta_k = np.log(norm.pdf(normalized, self.mean_diff, 1) / norm.pdf(normalized, 0., 1))
            self.stat = max(0, self.stat + zeta_k)

            if self.stat > self.threshold:
                self.stat = 0
                return True
            else:
                return False

# %% [markdown]
# ### Обоснование выбора метода детекции разладок
#
# Для задачи обнаружения разладок в прогнозировании сальдо потоков ликвидности банка был выбран метод на основе универсального CUSUM-детектора с возможностью работы в двух режимах: **гибридном** (классический CUSUM) и **адаптивном** (адаптивный CUSUM с обновлением оценки среднего и дисперсии).
#
# **Причины выбора именно такого метода:**
#
# 1. **Высокая чувствительность к небольшим изменениям распределения:**
#    Бизнес-процесс требует своевременного обнаружения изменений в динамике потоков ликвидности, так как промедление может привести к финансовым потерям. Классический CUSUM хорошо выявляет сдвиги среднего значения, а адаптивная версия дополнительно учитывает изменение дисперсии и динамики процесса, что особенно важно в условиях финансовых временных рядов, где волатильность может существенно изменяться.
#
# 2. **Низкие вычислительные затраты и возможность онлайн-обновления:**
#    Реализованная версия `UniversalCUSUMDetector` поддерживает как пакетную обработку (`detect`), так и пошаговое обновление на новых данных (`update`). Это позволяет легко встроить детектор в автоматизированный пайплайн, где модель прогнозирования будет ежедневно получать новые данные и должна без задержек фиксировать возможные аномалии в потоке.
#
# 3. **Гибкость под специфику банка:**
#    Режим `adaptive` позволяет подстраиваться под медленные изменения распределения данных, что характерно для банковских процессов в периоды без сильных внешних шоков. Режим `hybrid` позволяет быстро реагировать на резкие внешние события (например, крупные налоговые платежи, изменение ключевой ставки). Это важно, поскольку поведение потоков ликвидности может резко меняться в зависимости от внешних макроэкономических факторов, налогового календаря и других причин.
#
# 4. **Контроль частоты ложных срабатываний:**
#    Параметр `min_distance` позволяет отфильтровать слишком частые сигналы, что снижает вероятность перехода на ручное управление без объективной необходимости. Это особенно важно для минимизации нагрузки на операторов, так как лишние сигналы могли бы приводить к ненужным вмешательствам в процесс.
#
# 5. **Настраиваемые параметры под специфику бизнеса:**
#    Использование настраиваемых порогов (`threshold`), дрейфа (`drift`) и параметров адаптации (`alpha`, `beta`, `mean_diff`) позволяет отдельно подобрать конфигурацию детектора для разных особенностей ряда (например, сальдо может требовать одной чувствительности, а притоки и оттоки — другой).
#
#
# ### Обоснование структуры реализации
#
# 1. **Поддержка двух режимов работы (`adaptive`, `hybrid`):**
#    Это решение позволяет выбирать стратегию обнаружения разладок в зависимости от характера текущих данных. Например, если известно, что сейчас идут налоговые выплаты — можно работать в `hybrid`-режиме для жёсткого отслеживания отклонений.
#
# 2. **Плавное обновление оценок среднего и дисперсии в адаптивном режиме:**
#    В адаптивном режиме реализовано экспоненциальное сглаживание оценок (`alpha`, `beta`), что делает детектор устойчивым к шуму и позволяет учитывать только значимые тренды в изменении данных.
#
# 3. **Онлайн-обновление состояния (`update`):**
#    Для построения промышленного пайплайна важно, чтобы разладки можно было фиксировать без необходимости переобработки всего временного ряда, а только на основании новых данных, что и реализовано в методе `update`.
#
# 4. **Фильтрация близких по времени событий:**
#    Для предотвращения избыточных сигналов используется фильтрация по минимальной дистанции между разладками (`min_distance`). Это практическое решение позволяет оставить только наиболее важные события и избежать ложной тревоги.
#
# 5. **Визуализация результатов:**
#    Встроенный пример использования сразу показывает на графиках найденные точки разладки, что позволяет легко и быстро провести валидацию корректности работы детектора на реальных данных.
#
# ### Почему метод хорошо подходит под специфику задачи
#
# - В условиях банковской ликвидности важно быстро фиксировать **как резкие всплески**, так и **плавные изменения** поведения процессов. Реализация двух режимов позволяет это сделать.
# - Поскольку автоматизация требует полной самостоятельности работы моделей без ручного вмешательства, выбранный детектор соответствует требованию непрерывного мониторинга без необходимости перезапуска или пересчёта всего ряда.
# - Способность детектора быть **адаптивным** к текущим условиям рынка соответствует реальности финансовых процессов, где распределения редко бывают стационарными.
# - Возможность конфигурировать пороги позволяет дополнительно откалибровать чувствительность разладки под бизнес-метрику, минимизируя число ложных переходов на ручное управление.

# %%
# === Пример использования ===


df = pd.read_csv('data/merged_dataset_with_lags_rollings.csv')
columns = ['balance', 'income', 'outcome']

    # Выбор режима
detector = UniversalCUSUMDetector(mode="adaptive", threshold=1.0,min_distance=1)
#detector = UniversalCUSUMDetector(mode="hybrid", threshold=8.0,min_distance=1,alpha=0.02, beta=0.02, mean_diff=0.3)

fig, axes = plt.subplots(len(columns), 1, figsize=(14, 10), sharex=True)
for i, col in enumerate(columns):
    series = df[col]
    cps = detector.detect(series)
    axes[i].plot(series.values, label=col)
    for cp in cps:
        axes[i].axvline(cp, color='red', linestyle='--', alpha=0.6)
    axes[i].set_title(f'Universal CUSUM ({detector.mode}) — {col} (найдено {len(cps)})')
    axes[i].legend()
    axes[i].grid(True)
    detector.reset()

plt.tight_layout()
plt.show()


# === Пример использования ===


df = pd.read_csv('data/merged_dataset_with_lags_rollings.csv')
columns = ['balance', 'income', 'outcome']

    # Выбор режима
#detector = UniversalCUSUMDetector(mode="adaptive", threshold=1.0,min_distance=1)
detector = UniversalCUSUMDetector(mode="hybrid", threshold=5.0,min_distance=30,alpha=0.02, beta=0.02, mean_diff=0.3)

fig, axes = plt.subplots(len(columns), 1, figsize=(14, 10), sharex=True)
for i, col in enumerate(columns):
    series = df[col]
    cps = detector.detect(series)
    axes[i].plot(series.values, label=col)
    for cp in cps:
        axes[i].axvline(cp, color='red', linestyle='--', alpha=0.6)
    axes[i].set_title(f'Universal CUSUM ({detector.mode}) — {col} (найдено {len(cps)})')
    axes[i].legend()
    axes[i].grid(True)
    detector.reset()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Выводы по поведению детектора
#
# - **Hybrid режим** находит много точек разладки, включая небольшие отклонения даже при незначительных колебаниях ряда.
# - **Adaptive режим** реагирует только на более крупные и устойчивые изменения поведения данных.
#
#
# ### Преимущества и недостатки каждого режима
#
# **Hybrid режим:**
#
# Преимущества:
# - Очень высокая чувствительность к сдвигам среднего значения.
# - Позволяет оперативно отлавливать локальные скачки или провалы в данных, которые могут быть связаны с важными для ликвидности банка событиями.
# - Хорошо работает в условиях, когда изменения происходят резко и имеют короткий характер.
#
# Недостатки:
# - Генерирует большое количество срабатываний, включая шумовые сигналы.
# - Требует более внимательной фильтрации и настройки параметров (например, `threshold`, `min_distance`), чтобы избежать перегрузки процессом ручного управления.
# - Может приводить к избыточному числу внеплановых переключений на ручной режим, что увеличит нагрузку на операторов.
#
# **Adaptive режим:**
#
# Преимущества:
# - Выявляет только действительно значимые изменения, фильтруя краткосрочный шум.
# - Обеспечивает более стабильную работу пайплайна без излишних переключений на ручное вмешательство.
# - Лучше подходит для процессов с относительно плавной динамикой изменений, характерных для типичного банковского потока ликвидности вне кризисных ситуаций.
#
# Недостатки:
# - Менее чувствителен к коротким и резким аномалиям. При резком внешнем шоке (например, неожиданном изменении макроэкономических условий) может среагировать с запозданием.
# - Требует аккуратной калибровки параметров адаптации (`alpha`, `beta`) под разные стадии рыночного цикла.
#
# ### Сценарии применения
#
# - В обычные стабильные периоды, когда в потоках ликвидности отсутствуют резкие изменения, целесообразно применять **адаптивный режим**. Он позволяет избегать ложных срабатываний и обеспечивает более надёжную работу системы без лишних переключений на ручное управление.
#
# - В случае наступления кризисных или высоковолатильных периодов на рынке имеет смысл заранее планировать переход на **гибридный режим** для более плотного контроля за процессами.
#
# Таким образом, выбор режима должен быть увязан с бизнес-контекстом: адаптивный режим — для спокойных условий, гибридный — для периодов повышенного риска и нестабильности.

# %% [markdown]
# # **Блок 8. Онлайн запуск и автоматическое переобучение**

# %%
import numpy as np
import pandas as pd
import optuna
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

class ModelPipeline:
    def __init__(
        self,
        models_config: dict,
        n_splits: int = 3,
        feature_selector_top_k: int = 20,
        n_trials: int = 10,
        metric_func=mean_absolute_error,
        optuna_direction: str = "minimize",
        use_optuna: bool = True,
    ):
        self.models_config = models_config
        self.n_splits = n_splits
        self.top_k = feature_selector_top_k
        self.n_trials = n_trials
        self.metric_func = metric_func
        self.optuna_direction = optuna_direction
        self.use_optuna = use_optuna
        self.best_params = {}

    def tune_model(self, model_name, X, y, key_rate):
        def objective(trial):
            model_cls, param_space = self.models_config[model_name]
            params = {k: v(trial) for k, v in param_space.items()}
            tscv = TimeSeriesSplit(n_splits=self.n_splits)

            fold_losses = []

            for train_idx, val_idx in tscv.split(X):
                X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
                y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
                rate_val = key_rate.iloc[val_idx]

                model = model_cls(**params)
                model.fit(X_tr, y_tr)
                y_pred = model.predict(X_val)

                fold_losses.append(self.metric_func(y_val, y_pred, rate_val))

            return np.mean(fold_losses)

        study = optuna.create_study(direction=self.optuna_direction, sampler=optuna.samplers.TPESampler(seed=42))
        study.optimize(objective, n_trials=self.n_trials, show_progress_bar=True)

        return study.best_params

    def run(self, X, y, key_rate, test_start_date, model_name, extra_metrics=None):
        if extra_metrics is None:
            extra_metrics = []

        results = []

        balance_reference = y[(y > 0) & (y.index >= test_start_date)].mean()

        X_train = X[X.index < test_start_date]
        X_test = X[X.index >= test_start_date]
        y_train = y.loc[X_train.index]
        y_test = y.loc[X_test.index]
        rate_train = key_rate.loc[X_train.index]
        rate_test = key_rate.loc[X_test.index]

        if model_name not in self.models_config:
            raise ValueError(f"Модель '{model_name}' не найдена в models_config.")

        if self.use_optuna:
            print(f"\n🔧 Калибровка модели: {model_name}")
            best_params = self.tune_model(model_name, X_train, y_train, rate_train)
        else:
            print(f"\n Обучение {model_name} без тюнинга (параметры по умолчанию)")
            best_params = {}  # Просто пустой словарь

        self.best_params[model_name] = best_params

        model_cls = self.models_config[model_name][0]
        selector_model = model_cls(**best_params)
        selector_model.fit(X_train, y_train)
        top_features = self._select_top_features(selector_model, X_train)
        print(f"Топ-{self.top_k} признаков для {model_name}: {top_features}")

        if X_test.empty:
            print("Нет тестовых данных. Обучение модели без теста.")
            model = model_cls(**best_params)
            model.fit(X_train[top_features], y_train)
            return None

        # делаем финальное обучение только по топовым признакам
        model = model_cls(**best_params, verbose=0)
        model.fit(X_train[top_features], y_train)
        y_pred = model.predict(X_test[top_features])

        results.append(
            self._evaluate(model_name, y_test, y_pred, rate_test, balance_reference, extra_metrics)
        )

        self._plot(y_test, y_pred, model_name)

        return pd.DataFrame(results)

    # остальное без изменений


    def _select_top_features(self, model, X):
        if hasattr(model, "feature_importances_"):
            importances = model.feature_importances_
        elif hasattr(model, "coef_"):
            importances = np.abs(model.coef_)
        else:
            raise ValueError("Model does not support feature importance or coef_.")
        
        top_indices = np.argsort(importances)[::-1][:self.top_k]
        return list(X.columns[top_indices])

    def _evaluate(self, name, y_true, y_pred, rate, balance_ref, extra_metrics):
        result = {
            "Model": name,
            "MAE": mean_absolute_error(y_true, y_pred),
            self.metric_func.__name__: self.metric_func(y_true, y_pred, rate),
        }
        for func in extra_metrics:
            result[func.__name__] = func(y_true, y_pred, rate)
        return result

    def _plot(self, y_true, y_pred, model_name):
        plt.figure(figsize=(15, 6))
        plt.plot(y_true.index, y_true.values, label="Истинное значение", linewidth=2)
        plt.plot(y_true.index, y_pred, label=f"Предсказание ({model_name})", linewidth=2)
        plt.title(f"Факт vs Прогноз для {model_name}")
        plt.xlabel("Дата")
        plt.ylabel("Сальдо")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    def online_run(
        self,
        X,
        y,
        key_rate,
        start_date,
        detector: UniversalCUSUMDetector,
        retrain_every_n_sundays=2,
        reoptimize_every_m_sundays=4,
        model_name="LGBM",
        extra_metrics=None,
    ):
        if extra_metrics is None:
            extra_metrics = []
        
        self.daily_results = []
        self.daily_predictions = []
        self.change_points = []
        
        # --- Первичное обучение до start_date ---
        X_train = X[X.index < start_date]
        y_train = y[X.index < start_date]
        key_rate_train = key_rate[X.index < start_date]

        print(f"Первичное обучение до {start_date.date()}")
        self.use_optuna = True
        self._fit(X_train, y_train, key_rate_train, model_name)

        # --- Прогон в онлайн-режиме ---
        current_date = start_date
        sunday_counter = 0  # считаем воскресенья
        all_dates = X.index[X.index >= start_date]

        y_pred_total = []
        self.residuals = []


        while current_date <= all_dates[-1]:
            X_today = X.loc[[current_date]]
            y_today = y.loc[[current_date]]
            key_rate_today = key_rate.loc[[current_date]]
            
            # --- Предсказание ---
            y_pred_today = self.current_model.predict(X_today[self.current_top_features])[0]
            y_pred_total.append((current_date, y_today.values[0], y_pred_today))

            # --- Счёт метрик ---
            daily_result = self._evaluate(
                name=model_name,
                y_true=y_today,
                y_pred=np.array([y_pred_today]),
                rate=key_rate_today,
                balance_ref=1.0,  # не важен в онлайн метриках
                extra_metrics=extra_metrics
            )
            daily_result["date"] = current_date
            self.daily_results.append(daily_result)

            metrics_str = ', '.join(f"{k}: {v:.4f}" for k, v in daily_result.items() if k not in ['Model', 'date'])
            print(f"{current_date.date()} | {metrics_str}")

 
            # --- Детекция разладки ---
            # error_today = y_today.values[0] - y_pred_today
            # self.residuals.append(error_today)

            # detected_cps = detector.detect(pd.Series(self.residuals))

            error_today = y_today.values[0] - y_pred_today
            is_cp = detector.update(error_today)

            if is_cp:
                print(f"Разладка на {current_date.date()} — переобучение!")
                self.change_points.append(current_date)

                retrain_data = X[X.index <= current_date]
                retrain_target = y[y.index <= current_date]
                retrain_rate = key_rate[key_rate.index <= current_date]

                self.use_optuna = True
                self._fit(retrain_data, retrain_target, retrain_rate, model_name)
                sunday_counter = 0  # обнуляем счётчик воскресений


            # --- Переобучение по расписанию ---
            if current_date.weekday() == 6:  # Воскресенье
                sunday_counter += 1
                if sunday_counter % reoptimize_every_m_sundays == 0:
                    print(f"🔧 Регулярное переобучение с Optuna на {current_date.date()}")
                    retrain_data = X[X.index <= current_date]
                    retrain_target = y[y.index <= current_date]
                    retrain_rate = key_rate[key_rate.index <= current_date]

                    self.use_optuna = True
                    self._fit(retrain_data, retrain_target, retrain_rate, model_name)
                elif sunday_counter % retrain_every_n_sundays == 0:
                    print(f"Регулярное переобучение без Optuna на {current_date.date()}")
                    retrain_data = X[X.index <= current_date]
                    retrain_target = y[y.index <= current_date]
                    retrain_rate = key_rate[key_rate.index <= current_date]

                    self.use_optuna = False
                    self._fit(retrain_data, retrain_target, retrain_rate, model_name)

            # --- Переход к следующему дню ---
            idx = np.where(all_dates == current_date)[0][0]
            if idx + 1 >= len(all_dates):
                break
            current_date = all_dates[idx + 1]

        # --- Финальный расчёт ---
        daily_df = pd.DataFrame(self.daily_results)
        print("\nСредние метрики за период:")
        print(daily_df.select_dtypes(include=[np.number]).mean().T.round(10))

        # --- Построение графика ---
        self._plot_online(y_pred_total)

    def _fit(self, X_train, y_train, rate_train, model_name):
        print(f"Обучение на {len(X_train)} примерах...")

        if self.use_optuna:
            best_params = self.tune_model(model_name, X_train, y_train, rate_train)
        else:
            best_params = {}

        self.current_best_params = best_params
        model_cls = self.models_config[model_name][0]

        # --- обучение selector_model ---
        selector_model = model_cls(**best_params)
        if isinstance(selector_model, CatBoostRegressor):
            from catboost import Pool
            selector_pool = Pool(X_train, y_train)
            selector_model.fit(selector_pool,verbose=0)
        else:
            selector_model.fit(X_train, y_train)

        self.current_top_features = self._select_top_features(selector_model, X_train)

        # --- обучение финальной current_model ---
        self.current_model = model_cls(**best_params)
        if isinstance(self.current_model, CatBoostRegressor):
            from catboost import Pool
            train_pool = Pool(X_train[self.current_top_features], y_train)
            self.current_model.fit(train_pool, verbose=0)
        else:
            self.current_model.fit(X_train[self.current_top_features], y_train)


    def _plot_online(self, y_pred_total):
        dates, y_true, y_pred = zip(*y_pred_total)

        plt.figure(figsize=(15, 6))
        plt.plot(dates, y_true, label="Истинное значение", linewidth=2)
        plt.plot(dates, y_pred, label="Прогноз", linewidth=2)

        for cp in self.change_points:
            plt.axvline(x=cp, color='red', linestyle='--', label='Разладка' if cp == self.change_points[0] else "")

        plt.title("Онлайн прогноз + разладки")
        plt.xlabel("Дата")
        plt.ylabel("Сальдо")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()


models_config = {
    "RandomForest": (
        RandomForestRegressor,
        {
            "n_estimators": lambda t: t.suggest_int("n_estimators", 100, 300),
            "max_depth": lambda t: t.suggest_int("max_depth", 5, 15),
            "min_samples_split": lambda t: t.suggest_int("min_samples_split", 2, 10),
            "random_state": lambda _: 42
        }
    ),
    "LGBM": (
        LGBMRegressor,
        {
            "n_estimators": lambda t: t.suggest_int("n_estimators", 50, 300),
            "learning_rate": lambda t: t.suggest_float("learning_rate", 0.01, 0.3),
            "max_depth": lambda t: t.suggest_int("max_depth", 10, 25),
            "random_state": lambda _: 42,
            "verbosity": lambda _: -1
        }
    )
    ,
    "CatBoost": (
        CatBoostRegressor,
        {
            "depth": lambda t: t.suggest_int("depth", 4, 10)
            ,
            "learning_rate": lambda t: t.suggest_float("learning_rate", 0.01, 0.3),
            "l2_leaf_reg": lambda t: t.suggest_float("l2_leaf_reg", 1, 10),
            "iterations": lambda _: 200,
            
            "verbose": lambda _: False,
            "random_seed": lambda _: 42,
            # "logging_level": lambda _: 'Silent'
        }

        
    )
}

df = pd.read_csv("data/merged_dataset_with_lags_rollings.csv", parse_dates=["date"]).set_index("date")
X = df.drop(columns=["balance", "income", "outcome"])
y = df["balance"]
key_rate = df["rate"]#.fillna(0.085)

# pipeline = ModelPipeline(
#     models_config,
#     metric_func=mae_cust,
#     optuna_direction="minimize",
#     use_optuna=False
# )

# results = pipeline.run(
#     X,
#     y,
#     key_rate,
#     test_start_date=X.index[int(len(X) * 0.8)],
#     model_name="LGBM",
#     extra_metrics=[ calculate_add_margin_vectorized]
# )

# print(results)


pipeline = ModelPipeline(
    models_config=models_config,
    metric_func=mae_cust,    # твоя кастомная метрика
    optuna_direction="minimize",
    n_trials=1, 
    use_optuna=False          # стартовое значение, будет переключаться внутри
)

detector = UniversalCUSUMDetector(
    mode="adaptive",
    threshold=1.0,
    drift=0.01,
    min_distance=20,
    alpha=0.02,
    beta=0.02,
    mean_diff=0.3
)
pipeline.online_run(
    X=X,
    y=y,
    key_rate=key_rate,

    start_date=pd.Timestamp('2020-07-01'),   #дата начала онлайн-прогноза
    detector=detector,
    retrain_every_n_sundays=4,               # каждые retrain_every_n_sundays воскресенья переобучение без Optuna
    reoptimize_every_m_sundays=70,             # каждые reoptimize_every_m_sundays воскресенья переобучение с Optuna
    model_name="LGBM",                        # какую модель использовать
    extra_metrics=[calculate_add_margin_vectorized, normalized_add_margin,delta_pnl]  #  доп. метрики 
)
# Out:
# [I 2025-04-28 01:25:12,479] A new study created in memory with name: no-name-ed05e70a-c55d-40e8-a354-42549bc92088
# Первичное обучение до 2020-07-01
# Обучение на 1262 примерах...
# Best trial: 0. Best value: 0.257798: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# [I 2025-04-28 01:25:14,428] Trial 0 finished with value: 0.25779847581573145 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.25779847581573145.
# 2020-07-01 | MAE: 0.2718, mae_cust: 0.2718, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.1145, delta_pnl: -0.0012
# 2020-07-02 | MAE: 0.6179, mae_cust: 0.6179, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0131, delta_pnl: -0.0015
# 2020-07-03 | MAE: 0.0848, mae_cust: 0.0848, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0027, delta_pnl: -0.0004
# 2020-07-04 | MAE: 0.1766, mae_cust: 0.1766, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 2419309652.1298, delta_pnl: -0.0009
# 2020-07-05 | MAE: 0.0619, mae_cust: 0.0619, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 847793547.3748, delta_pnl: -0.0003
# 2020-07-06 | MAE: 0.0462, mae_cust: 0.0462, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.9198
# 2020-07-07 | MAE: 0.1050, mae_cust: 0.1050, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0053, delta_pnl: -0.0015
# 2020-07-08 | MAE: 0.1019, mae_cust: 0.1019, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -0.3412
# 2020-07-09 | MAE: 0.2433, mae_cust: 0.2433, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -0.5647
# 2020-07-10 | MAE: 0.0849, mae_cust: 0.0849, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0030, delta_pnl: -0.0012
# 2020-07-11 | MAE: 0.0083, mae_cust: 0.0083, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0375
# 2020-07-12 | MAE: 0.0827, mae_cust: 0.0827, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3730
# 2020-07-13 | MAE: 0.1249, mae_cust: 0.1249, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2089
# 2020-07-14 | MAE: 0.2862, mae_cust: 0.2862, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0288, delta_pnl: -0.0010
# 2020-07-15 | MAE: 0.1857, mae_cust: 0.1857, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0829, delta_pnl: -0.0008
# 2020-07-16 | MAE: 0.1372, mae_cust: 0.1372, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0081, delta_pnl: -0.0019
# 2020-07-17 | MAE: 0.2023, mae_cust: 0.2023, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1564
# 2020-07-18 | MAE: 0.1193, mae_cust: 0.1193, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1633669936.0430, delta_pnl: -0.0006
# 2020-07-19 | MAE: 0.0291, mae_cust: 0.0291, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1314
# 2020-07-20 | MAE: 0.1526, mae_cust: 0.1526, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0039, delta_pnl: -0.0002
# 2020-07-21 | MAE: 0.2071, mae_cust: 0.2071, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -0.1647
# 2020-07-22 | MAE: 0.3793, mae_cust: 0.3793, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -1.5923
# 2020-07-23 | MAE: 0.1534, mae_cust: 0.1534, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0063, delta_pnl: -0.0002
# 2020-07-24 | MAE: 0.3037, mae_cust: 0.3037, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -0.3040
# 2020-07-25 | MAE: 0.0174, mae_cust: 0.0174, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0784
# 2020-07-26 | MAE: 0.0283, mae_cust: 0.0283, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 388184171.8017, delta_pnl: -0.0001
# Регулярное переобучение без Optuna на 2020-07-26
# Обучение на 1288 примерах...
# 2020-07-27 | MAE: 0.8463, mae_cust: 0.8463, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6578
# 2020-07-28 | MAE: 0.3023, mae_cust: 0.3023, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0142, delta_pnl: -0.0008
# 2020-07-29 | MAE: 0.1529, mae_cust: 0.1529, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0007, delta_pnl: -0.0000
# 2020-07-30 | MAE: 0.0940, mae_cust: 0.0940, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0078, delta_pnl: -0.0013
# 2020-07-31 | MAE: 0.0540, mae_cust: 0.0540, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 702813634.9806, delta_pnl: -0.0003
# 2020-08-01 | MAE: 0.0235, mae_cust: 0.0235, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 305688721.3877, delta_pnl: -0.0001
# 2020-08-02 | MAE: 0.0292, mae_cust: 0.0292, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1243
# 2020-08-03 | MAE: 0.0252, mae_cust: 0.0252, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0145
# 2020-08-04 | MAE: 0.0536, mae_cust: 0.0536, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0135, delta_pnl: -0.0001
# 2020-08-05 | MAE: 0.1805, mae_cust: 0.1805, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0073, delta_pnl: -0.0025
# 2020-08-06 | MAE: 0.0361, mae_cust: 0.0361, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0032, delta_pnl: -0.0002
# 2020-08-07 | MAE: 0.1561, mae_cust: 0.1561, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0072, delta_pnl: -0.0022
# 2020-08-08 | MAE: 0.1008, mae_cust: 0.1008, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4295
# 2020-08-09 | MAE: 0.0277, mae_cust: 0.0277, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1180
# 2020-08-10 | MAE: 0.2999, mae_cust: 0.2999, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4451
# 2020-08-11 | MAE: 0.2074, mae_cust: 0.2074, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8836
# 2020-08-12 | MAE: 0.2996, mae_cust: 0.2996, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.9408
# 2020-08-13 | MAE: 0.0125, mae_cust: 0.0125, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6673
# 2020-08-14 | MAE: 0.0251, mae_cust: 0.0251, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3863
# 2020-08-15 | MAE: 0.1323, mae_cust: 0.1323, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5637
# 2020-08-16 | MAE: 0.0292, mae_cust: 0.0292, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1244
# 2020-08-17 | MAE: 0.2617, mae_cust: 0.2617, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7921
# 2020-08-18 | MAE: 0.2016, mae_cust: 0.2016, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7680
# 2020-08-19 | MAE: 0.0768, mae_cust: 0.0768, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8856
# 2020-08-20 | MAE: 0.2974, mae_cust: 0.2974, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0231
# 2020-08-21 | MAE: 0.0412, mae_cust: 0.0412, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6221
# 2020-08-22 | MAE: 0.0836, mae_cust: 0.0836, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3561
# 2020-08-23 | MAE: 0.0345, mae_cust: 0.0345, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 449255402.8583, delta_pnl: -0.0002
# Регулярное переобучение без Optuna на 2020-08-23
# Обучение на 1316 примерах...
# 2020-08-24 | MAE: 0.1675, mae_cust: 0.1675, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7447
# 2020-08-25 | MAE: 0.1030, mae_cust: 0.1030, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8295
# 2020-08-26 | MAE: 0.3540, mae_cust: 0.3540, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0029, delta_pnl: -0.0003
# 2020-08-27 | MAE: 0.0425, mae_cust: 0.0425, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2370
# 2020-08-28 | MAE: 0.3105, mae_cust: 0.3105, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0003, delta_pnl: -0.0000
# 2020-08-29 | MAE: 0.0111, mae_cust: 0.0111, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 144036313.8176, delta_pnl: -0.0001
# 2020-08-30 | MAE: 0.0231, mae_cust: 0.0231, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 300858686.2746, delta_pnl: -0.0001
# 2020-08-31 | MAE: 0.1236, mae_cust: 0.1236, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6513
# 2020-09-01 | MAE: 0.2834, mae_cust: 0.2834, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0267
# 2020-09-02 | MAE: 0.0561, mae_cust: 0.0561, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0045, delta_pnl: -0.0001
# 2020-09-03 | MAE: 0.1424, mae_cust: 0.1424, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0222, delta_pnl: -0.0004
# 2020-09-04 | MAE: 0.1775, mae_cust: 0.1775, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0065, delta_pnl: -0.0003
# 2020-09-05 | MAE: 0.0895, mae_cust: 0.0895, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1164304837.6137, delta_pnl: -0.0004
# 2020-09-06 | MAE: 0.0110, mae_cust: 0.0110, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 143748158.8494, delta_pnl: -0.0001
# 2020-09-07 | MAE: 0.0271, mae_cust: 0.0271, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8974
# 2020-09-08 | MAE: 0.1581, mae_cust: 0.1581, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1118
# 2020-09-09 | MAE: 0.1530, mae_cust: 0.1530, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.1487
# 2020-09-10 | MAE: 0.2585, mae_cust: 0.2585, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.2627
# 2020-09-11 | MAE: 0.0715, mae_cust: 0.0715, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4161
# 2020-09-12 | MAE: 0.0307, mae_cust: 0.0307, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1309
# 2020-09-13 | MAE: 0.0211, mae_cust: 0.0211, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 274544467.5205, delta_pnl: -0.0001
# 2020-09-14 | MAE: 0.0362, mae_cust: 0.0362, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.1919
# 2020-09-15 | MAE: 0.0402, mae_cust: 0.0402, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0041, delta_pnl: -0.0006
# 2020-09-16 | MAE: 0.1648, mae_cust: 0.1648, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2045
# 2020-09-17 | MAE: 0.4402, mae_cust: 0.4402, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0112, delta_pnl: -0.0010
# 2020-09-18 | MAE: 0.0165, mae_cust: 0.0165, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0018, delta_pnl: -0.0002
# 2020-09-19 | MAE: 0.0421, mae_cust: 0.0421, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 547400275.1905, delta_pnl: -0.0002
# 2020-09-20 | MAE: 0.0188, mae_cust: 0.0188, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 244275998.9802, delta_pnl: -0.0001
# Регулярное переобучение без Optuna на 2020-09-20
# Обучение на 1344 примерах...
# 2020-09-21 | MAE: 0.2016, mae_cust: 0.2016, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2496
# 2020-09-22 | MAE: 0.0540, mae_cust: 0.0540, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.1794
# 2020-09-23 | MAE: 0.1881, mae_cust: 0.1881, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2084
# 2020-09-24 | MAE: 0.0913, mae_cust: 0.0913, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1160
# 2020-09-25 | MAE: 0.0680, mae_cust: 0.0680, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6078
# 2020-09-26 | MAE: 0.0436, mae_cust: 0.0436, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1858
# 2020-09-27 | MAE: 0.0102, mae_cust: 0.0102, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 132132373.0288, delta_pnl: -0.0001
# 2020-09-28 | MAE: 0.1523, mae_cust: 0.1523, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4168
# 2020-09-29 | MAE: 0.0174, mae_cust: 0.0174, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0048, delta_pnl: -0.0002
# 2020-09-30 | MAE: 0.1062, mae_cust: 0.1062, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2207
# 2020-10-01 | MAE: 0.5901, mae_cust: 0.5901, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0064, delta_pnl: -0.0010
# 2020-10-02 | MAE: 0.1961, mae_cust: 0.1961, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0258, delta_pnl: -0.0007
# 2020-10-03 | MAE: 0.0149, mae_cust: 0.0149, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0635
# 2020-10-04 | MAE: 0.0075, mae_cust: 0.0075, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0319
# 2020-10-05 | MAE: 0.0145, mae_cust: 0.0145, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4020
# 2020-10-06 | MAE: 0.0315, mae_cust: 0.0315, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6367
# 2020-10-07 | MAE: 0.0012, mae_cust: 0.0012, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5075
# 2020-10-08 | MAE: 0.0281, mae_cust: 0.0281, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1610
# 2020-10-09 | MAE: 0.0067, mae_cust: 0.0067, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0016, delta_pnl: -0.0001
# 2020-10-10 | MAE: 0.0414, mae_cust: 0.0414, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 765.3791, delta_pnl: -0.0002
# 2020-10-11 | MAE: 0.0790, mae_cust: 0.0790, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3364
# 2020-10-12 | MAE: 0.0267, mae_cust: 0.0267, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0072
# 2020-10-13 | MAE: 0.0796, mae_cust: 0.0796, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.1156
# 2020-10-14 | MAE: 0.8294, mae_cust: 0.8294, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0028, delta_pnl: -0.0007
# 2020-10-15 | MAE: 0.0316, mae_cust: 0.0316, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1348
# 2020-10-16 | MAE: 0.0659, mae_cust: 0.0659, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6166
# 2020-10-17 | MAE: 0.0456, mae_cust: 0.0456, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 593863217.1646, delta_pnl: -0.0002
# 2020-10-18 | MAE: 0.0330, mae_cust: 0.0330, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 429300663.5221, delta_pnl: -0.0002
# Регулярное переобучение без Optuna на 2020-10-18
# Обучение на 1372 примерах...
# 2020-10-19 | MAE: 0.3902, mae_cust: 0.3902, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1890
# 2020-10-20 | MAE: 0.1009, mae_cust: 0.1009, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4114
# 2020-10-21 | MAE: 0.2287, mae_cust: 0.2287, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2036
# 2020-10-22 | MAE: 0.2578, mae_cust: 0.2578, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5846
# 2020-10-23 | MAE: 0.1398, mae_cust: 0.1398, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2457
# 2020-10-24 | MAE: 0.0096, mae_cust: 0.0096, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0410
# 2020-10-25 | MAE: 0.0403, mae_cust: 0.0403, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1715
# 2020-10-26 | MAE: 0.6400, mae_cust: 0.6400, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0317
# 2020-10-27 | MAE: 0.0472, mae_cust: 0.0472, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4298
# 2020-10-28 | MAE: 0.4677, mae_cust: 0.4677, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8121
# 2020-10-29 | MAE: 0.3646, mae_cust: 0.3646, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8025
# 2020-10-30 | MAE: 0.0966, mae_cust: 0.0966, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8787
# 2020-10-31 | MAE: 0.1529, mae_cust: 0.1529, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7339
# 2020-11-01 | MAE: 0.1228, mae_cust: 0.1228, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5229
# 2020-11-02 | MAE: 0.6411, mae_cust: 0.6411, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8589
# 2020-11-03 | MAE: 0.1859, mae_cust: 0.1859, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.1829
# 2020-11-04 | MAE: 0.0616, mae_cust: 0.0616, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2626
# 2020-11-05 | MAE: 0.0991, mae_cust: 0.0991, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7013
# 2020-11-06 | MAE: 0.2117, mae_cust: 0.2117, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.9019
# 2020-11-07 | MAE: 0.1709, mae_cust: 0.1709, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7278
# 2020-11-08 | MAE: 0.0935, mae_cust: 0.0935, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3983
# 2020-11-09 | MAE: 0.0348, mae_cust: 0.0348, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2539
# 2020-11-10 | MAE: 0.3662, mae_cust: 0.3662, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0071, delta_pnl: -0.0006
# 2020-11-11 | MAE: 0.2727, mae_cust: 0.2727, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.8263
# 2020-11-12 | MAE: 0.1450, mae_cust: 0.1450, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0109, delta_pnl: -0.0003
# 2020-11-13 | MAE: 0.3775, mae_cust: 0.3775, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0077, delta_pnl: -0.0007
# 2020-11-14 | MAE: 0.1293, mae_cust: 0.1293, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1682277379.1146, delta_pnl: -0.0006
# 2020-11-15 | MAE: 0.1277, mae_cust: 0.1277, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5440
# Регулярное переобучение без Optuna на 2020-11-15
# Обучение на 1400 примерах...
# 2020-11-16 | MAE: 0.6302, mae_cust: 0.6302, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.5784
# 2020-11-17 | MAE: 0.2297, mae_cust: 0.2297, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2554
# 2020-11-18 | MAE: 0.0287, mae_cust: 0.0287, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.1678
# 2020-11-19 | MAE: 0.0688, mae_cust: 0.0688, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6840
# 2020-11-20 | MAE: 0.0315, mae_cust: 0.0315, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7071
# 2020-11-21 | MAE: 0.0390, mae_cust: 0.0390, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1659
# 2020-11-22 | MAE: 0.1070, mae_cust: 0.1070, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4559
# 2020-11-23 | MAE: 0.0078, mae_cust: 0.0078, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.0437
# 2020-11-24 | MAE: 0.1174, mae_cust: 0.1174, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4494
# 2020-11-25 | MAE: 0.5165, mae_cust: 0.5165, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6602
# 2020-11-26 | MAE: 0.1821, mae_cust: 0.1821, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.8043
# 2020-11-27 | MAE: 0.0737, mae_cust: 0.0737, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0321
# 2020-11-28 | MAE: 0.1630, mae_cust: 0.1630, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6944
# 2020-11-29 | MAE: 0.1058, mae_cust: 0.1058, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4508
# 2020-11-30 | MAE: 0.0252, mae_cust: 0.0252, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.2484
# 2020-12-01 | MAE: 0.3547, mae_cust: 0.3547, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.6861
# 2020-12-02 | MAE: 0.0546, mae_cust: 0.0546, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5527
# 2020-12-03 | MAE: 0.0666, mae_cust: 0.0666, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6139
# 2020-12-04 | MAE: 0.0248, mae_cust: 0.0248, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5675
# 2020-12-05 | MAE: 0.0517, mae_cust: 0.0517, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2203
# 2020-12-06 | MAE: 0.0119, mae_cust: 0.0119, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 154724620.4912, delta_pnl: -0.0001
# 2020-12-07 | MAE: 0.1290, mae_cust: 0.1290, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.7780
# 2020-12-08 | MAE: 0.2120, mae_cust: 0.2120, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4992
# 2020-12-09 | MAE: 0.2308, mae_cust: 0.2308, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0949
# 2020-12-10 | MAE: 0.1237, mae_cust: 0.1237, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0073, delta_pnl: -0.0017
# 2020-12-11 | MAE: 0.2555, mae_cust: 0.2555, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0049, delta_pnl: -0.0036
# 2020-12-12 | MAE: 0.0840, mae_cust: 0.0840, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1092604518.6129, delta_pnl: -0.0004
# 2020-12-13 | MAE: 0.1003, mae_cust: 0.1003, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4275
# Регулярное переобучение без Optuna на 2020-12-13
# Обучение на 1428 примерах...
# 2020-12-14 | MAE: 0.0204, mae_cust: 0.0204, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.4321
# 2020-12-15 | MAE: 0.1550, mae_cust: 0.1550, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2933
# 2020-12-16 | MAE: 0.2133, mae_cust: 0.2133, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.5171
# 2020-12-17 | MAE: 0.4975, mae_cust: 0.4975, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0010, delta_pnl: -0.0002
# 2020-12-18 | MAE: 0.0389, mae_cust: 0.0389, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6682
# 2020-12-19 | MAE: 0.0582, mae_cust: 0.0582, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2479
# 2020-12-20 | MAE: 0.0012, mae_cust: 0.0012, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 15899061.7450, delta_pnl: -0.0000
# 2020-12-21 | MAE: 0.3628, mae_cust: 0.3628, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.9322
# 2020-12-22 | MAE: 0.3493, mae_cust: 0.3493, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.3813
# 2020-12-23 | MAE: 0.2563, mae_cust: 0.2563, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.6445
# 2020-12-24 | MAE: 0.3824, mae_cust: 0.3824, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.6785
# 2020-12-25 | MAE: 0.1654, mae_cust: 0.1654, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.0339
# 2020-12-26 | MAE: 0.1629, mae_cust: 0.1629, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.1227
# 2020-12-27 | MAE: 0.2995, mae_cust: 0.2995, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2757
# 2020-12-28 | MAE: 0.5505, mae_cust: 0.5505, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -1.8980
# Разладка на 2020-12-28 — переобучение!
# Обучение на 1443 примерах...
# [I 2025-04-28 01:25:22,497] A new study created in memory with name: no-name-50a27ffb-fbf1-41a4-b20e-52aab52750ca
# Best trial: 0. Best value: 0.277818: 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# [I 2025-04-28 01:25:24,319] Trial 0 finished with value: 0.27781823483079593 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.27781823483079593.
# 2020-12-29 | MAE: 0.0070, mae_cust: 0.0070, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0031, delta_pnl: -0.0001
# 2020-12-30 | MAE: 0.2832, mae_cust: 0.2832, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.5356
# 2020-12-31 | MAE: 0.3784, mae_cust: 0.3784, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0032, delta_pnl: -0.0004
# 2021-01-01 | MAE: 0.0440, mae_cust: 0.0440, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 573154014.5908, delta_pnl: -0.0002
# 2021-01-02 | MAE: 0.1292, mae_cust: 0.1292, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1681237572.7628, delta_pnl: -0.0006
# 2021-01-03 | MAE: 0.1897, mae_cust: 0.1897, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8079
# 2021-01-04 | MAE: 0.1120, mae_cust: 0.1120, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1426
# 2021-01-05 | MAE: 0.0729, mae_cust: 0.0729, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3620
# 2021-01-06 | MAE: 0.2603, mae_cust: 0.2603, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.1104
# 2021-01-07 | MAE: 0.3505, mae_cust: 0.3505, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4929
# 2021-01-08 | MAE: 0.0253, mae_cust: 0.0253, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.4422
# 2021-01-09 | MAE: 0.0840, mae_cust: 0.0840, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3578
# 2021-01-10 | MAE: 0.0935, mae_cust: 0.0935, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3985
# 2021-01-11 | MAE: 0.0220, mae_cust: 0.0220, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0843
# 2021-01-12 | MAE: 0.9190, mae_cust: 0.9190, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0003, delta_pnl: -0.0001
# 2021-01-13 | MAE: 0.0034, mae_cust: 0.0034, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7707
# 2021-01-14 | MAE: 0.2450, mae_cust: 0.2450, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0043, delta_pnl: -0.0003
# 2021-01-15 | MAE: 0.6135, mae_cust: 0.6135, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3595
# 2021-01-16 | MAE: 0.0327, mae_cust: 0.0327, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1394
# 2021-01-17 | MAE: 0.2004, mae_cust: 0.2004, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8538
# 2021-01-18 | MAE: 0.7468, mae_cust: 0.7468, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3524
# 2021-01-19 | MAE: 0.0406, mae_cust: 0.0406, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4536
# 2021-01-20 | MAE: 0.2210, mae_cust: 0.2210, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0038, delta_pnl: -0.0002
# 2021-01-21 | MAE: 0.2124, mae_cust: 0.2124, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7218
# 2021-01-22 | MAE: 0.4935, mae_cust: 0.4935, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7585
# 2021-01-23 | MAE: 0.2261, mae_cust: 0.2261, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0791
# 2021-01-24 | MAE: 0.0163, mae_cust: 0.0163, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0693
# Регулярное переобучение без Optuna на 2021-01-24
# Обучение на 1470 примерах...
# 2021-01-25 | MAE: 0.7198, mae_cust: 0.7198, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.3186
# 2021-01-26 | MAE: 0.0160, mae_cust: 0.0160, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.5024
# 2021-01-27 | MAE: 0.0306, mae_cust: 0.0306, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8562
# 2021-01-28 | MAE: 0.3199, mae_cust: 0.3199, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.1889
# 2021-01-29 | MAE: 0.2552, mae_cust: 0.2552, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6515
# 2021-01-30 | MAE: 0.0788, mae_cust: 0.0788, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3359
# 2021-01-31 | MAE: 0.0015, mae_cust: 0.0015, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 19222169.4968, delta_pnl: -0.0000
# 2021-02-01 | MAE: 0.0334, mae_cust: 0.0334, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.7650
# 2021-02-02 | MAE: 0.1563, mae_cust: 0.1563, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0169
# 2021-02-03 | MAE: 0.3082, mae_cust: 0.3082, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7065
# 2021-02-04 | MAE: 0.2938, mae_cust: 0.2938, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.3750
# 2021-02-05 | MAE: 0.1123, mae_cust: 0.1123, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7576
# 2021-02-06 | MAE: 0.0200, mae_cust: 0.0200, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0852
# 2021-02-07 | MAE: 0.0564, mae_cust: 0.0564, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2401
# 2021-02-08 | MAE: 0.4847, mae_cust: 0.4847, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.3005
# 2021-02-09 | MAE: 0.2013, mae_cust: 0.2013, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.3299
# 2021-02-10 | MAE: 0.4204, mae_cust: 0.4204, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.8406
# 2021-02-11 | MAE: 0.2303, mae_cust: 0.2303, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0097, delta_pnl: -0.0005
# 2021-02-12 | MAE: 0.4108, mae_cust: 0.4108, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0026, delta_pnl: -0.0003
# 2021-02-13 | MAE: 0.0061, mae_cust: 0.0061, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0260
# 2021-02-14 | MAE: 0.1070, mae_cust: 0.1070, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1392886760.2637, delta_pnl: -0.0005
# 2021-02-15 | MAE: 0.3067, mae_cust: 0.3067, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.5350
# 2021-02-16 | MAE: 0.1410, mae_cust: 0.1410, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.6059
# 2021-02-17 | MAE: 0.0500, mae_cust: 0.0500, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5722
# 2021-02-18 | MAE: 0.4260, mae_cust: 0.4260, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2046
# 2021-02-19 | MAE: 0.2337, mae_cust: 0.2337, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0799
# 2021-02-20 | MAE: 0.2465, mae_cust: 0.2465, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1276
# 2021-02-21 | MAE: 0.0451, mae_cust: 0.0451, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.1920
# Регулярное переобучение без Optuna на 2021-02-21
# Обучение на 1498 примерах...
# 2021-02-22 | MAE: 0.3198, mae_cust: 0.3198, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4036
# 2021-02-23 | MAE: 0.1193, mae_cust: 0.1193, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5083
# 2021-02-24 | MAE: 0.7568, mae_cust: 0.7568, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5342
# 2021-02-25 | MAE: 0.1351, mae_cust: 0.1351, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.6683
# 2021-02-26 | MAE: 0.1870, mae_cust: 0.1870, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7177
# 2021-02-27 | MAE: 0.0086, mae_cust: 0.0086, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 111951179.2169, delta_pnl: -0.0000
# 2021-02-28 | MAE: 0.0827, mae_cust: 0.0827, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1076424791.9007, delta_pnl: -0.0004
# 2021-03-01 | MAE: 0.5270, mae_cust: 0.5270, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.5132
# 2021-03-02 | MAE: 0.1451, mae_cust: 0.1451, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2891
# 2021-03-03 | MAE: 0.0525, mae_cust: 0.0525, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.2287
# 2021-03-04 | MAE: 0.2330, mae_cust: 0.2330, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.9366
# 2021-03-05 | MAE: 0.2007, mae_cust: 0.2007, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -0.7990
# 2021-03-06 | MAE: 0.0595, mae_cust: 0.0595, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2535
# 2021-03-07 | MAE: 0.0551, mae_cust: 0.0551, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 717437279.8169, delta_pnl: -0.0003
# 2021-03-08 | MAE: 0.4104, mae_cust: 0.4104, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.7484
# 2021-03-09 | MAE: 1.0798, mae_cust: 1.0798, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7286
# 2021-03-10 | MAE: 0.3138, mae_cust: 0.3138, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0092, delta_pnl: -1.2251
# 2021-03-11 | MAE: 0.1669, mae_cust: 0.1669, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.6352
# 2021-03-12 | MAE: 0.3730, mae_cust: 0.3730, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7109
# 2021-03-13 | MAE: 0.1139, mae_cust: 0.1139, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 1481850069.0772, delta_pnl: -0.0006
# 2021-03-14 | MAE: 0.0178, mae_cust: 0.0178, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0757
# 2021-03-15 | MAE: 0.1753, mae_cust: 0.1753, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.8897
# 2021-03-16 | MAE: 0.0714, mae_cust: 0.0714, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.8835
# 2021-03-17 | MAE: 0.3384, mae_cust: 0.3384, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2971
# 2021-03-18 | MAE: 0.2826, mae_cust: 0.2826, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.7593
# 2021-03-19 | MAE: 0.2128, mae_cust: 0.2128, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.6176
# 2021-03-20 | MAE: 0.1379, mae_cust: 0.1379, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5873
# 2021-03-21 | MAE: 0.1312, mae_cust: 0.1312, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5591
# Регулярное переобучение без Optuna на 2021-03-21
# Обучение на 1526 примерах...
# 2021-03-22 | MAE: 0.2873, mae_cust: 0.2873, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -2.3862
# 2021-03-23 | MAE: 0.3140, mae_cust: 0.3140, calculate_add_margin_vectorized: -0.0000, normalized_add_margin: -0.0099, delta_pnl: -1.0018
# 2021-03-24 | MAE: 0.5419, mae_cust: 0.5419, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.2282
# 2021-03-25 | MAE: 0.6451, mae_cust: 0.6451, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.0098
# 2021-03-26 | MAE: 2.3970, mae_cust: 2.3970, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5316
# 2021-03-27 | MAE: 0.0010, mae_cust: 0.0010, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0043
# 2021-03-28 | MAE: 0.0118, mae_cust: 0.0118, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.0532
# 2021-03-29 | MAE: 0.8221, mae_cust: 0.8221, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.8650
# 2021-03-30 | MAE: 0.0626, mae_cust: 0.0626, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -1.4061
# 2021-03-31 | MAE: 0.1303, mae_cust: 0.1303, calculate_add_margin_vectorized: 0.0000, normalized_add_margin: 0.0000, delta_pnl: -0.5874
#
# Средние метрики за период:
# MAE                                1.894043e-01
# mae_cust                           1.894043e-01
# calculate_add_margin_vectorized    8.908000e-07
# normalized_add_margin              7.562354e+07
# delta_pnl                         -5.437755e-01
# dtype: float64

# %%
class OnlineForecastRunner:
    def __init__(self, model_pipeline, cusum_detector, retrain_every_n_weeks=4, optuna_every_m_weeks=12,extra_metrics=None):
        self.model_pipeline = model_pipeline
        self.detector = cusum_detector
        self.retrain_every_n_weeks = retrain_every_n_weeks
        self.optuna_every_m_weeks = optuna_every_m_weeks
        self.retrain_counter = 0
        self.optuna_retrain_counter = 0
        self.history = []
        self.change_points = []
        
        self.extra_metrics = extra_metrics or []


    def run(self, X, y, key_rate, start_date, model_name):
        dates = X.loc[X.index >= start_date].index
        current_X = X.loc[X.index < start_date].copy()
        current_y = y.loc[y.index < start_date].copy()
        current_rate = key_rate.loc[key_rate.index < start_date].copy()

        # Первичное обучение с Optuna
        self.model_pipeline.use_optuna = True
        self.model_pipeline.best_params = {}  # Сброс параметров
        self._train_model(current_X, current_y, current_rate, model_name)

        predictions = []
        reals = []

        for current_date in dates:
            X_today = X.loc[[current_date]]
            y_today = y.loc[[current_date]]
            rate_today = key_rate.loc[[current_date]]

            y_pred = self.model.predict(X_today[self.top_features])[0]
            metric_results = self._calculate_metrics(y_today, y_pred, rate_today)

            metrics_str = ", ".join(f"{k}: {v:.5f}" for k, v in metric_results.items())
            print(f"{current_date.date()} — {metrics_str}")

            # запись прогноза
            self.history.append({
                "date": current_date,
                "real": y_today.values[0],
                "pred": y_pred,
                **metric_results
            })

            predictions.append(y_pred)
            reals.append(y_today.values[0])

            # --- детекция разладки ---
            detected_cp = self.detector.detect(pd.Series([y_today.values[0] - y_pred]))
            if detected_cp:
                print(f"ыРазладка обнаружена на {current_date.date()}! Переобучение с Optuna.")
                self.model_pipeline.use_optuna = True
                self.model_pipeline.best_params = {}
                self._train_model(X.loc[X.index <= current_date], y.loc[y.index <= current_date], key_rate.loc[key_rate.index <= current_date], model_name)
                self.change_points.append(current_date)

            # --- еженедельные переобучения ---
            if current_date.weekday() == 6:  # Воскресенье
                self.retrain_counter += 1
                self.optuna_retrain_counter += 1

                if self.optuna_retrain_counter >= self.optuna_every_m_weeks:
                    print(f"Плановое переобучение с Optuna на {current_date.date()}.")
                    self.model_pipeline.use_optuna = True
                    self.model_pipeline.best_params = {}
                    self._train_model(X.loc[X.index <= current_date], y.loc[y.index <= current_date], key_rate.loc[key_rate.index <= current_date], model_name)
                    self.optuna_retrain_counter = 0
                    self.change_points.append(current_date)
                elif self.retrain_counter >= self.retrain_every_n_weeks:
                    print(f"Плановое переобучение без Optuna на {current_date.date()}.")
                    self.model_pipeline.use_optuna = False
                    self._train_model(X.loc[X.index <= current_date], y.loc[y.index <= current_date], key_rate.loc[key_rate.index <= current_date], model_name)
                    self.retrain_counter = 0
                    self.change_points.append(current_date)

        self._plot_results()
        return pd.DataFrame(self.history)

    def _train_model(self, X_train, y_train, rate_train, model_name):
        # Без разделения на тест, всё на обучении
        run_result = self.model_pipeline.run(
            X_train,
            y_train,
            rate_train,
            test_start_date=X_train.index[-1] + pd.Timedelta(days=1),
            model_name=model_name,
            extra_metrics=[]
        )
        # сохраняем модель
        self.model = self.model_pipeline.models_config[model_name][0](**self.model_pipeline.best_params[model_name])

        # здесь правильный способ получить топовые признаки:
        selector_model = self.model_pipeline.models_config[model_name][0](**self.model_pipeline.best_params[model_name])
        selector_model.fit(X_train, y_train)
        self.top_features = self.model_pipeline._select_top_features(selector_model, X_train)

        self.model.fit(X_train[self.top_features], y_train)


    def _calculate_metrics(self, y_true, y_pred, rate):
        res = {
            "MAE": mean_absolute_error(y_true, [y_pred]),
            self.model_pipeline.metric_func.__name__: self.model_pipeline.metric_func(y_true, [y_pred], rate),
        }
        #for func in self.model_pipeline.extra_metrics:
        for func in self.extra_metrics:

            res[func.__name__] = func(y_true, y_pred, rate)
        return res

    def _plot_results(self):
        df_history = pd.DataFrame(self.history)
        plt.figure(figsize=(15, 6))
        plt.plot(df_history["date"], df_history["real"], label="Факт", linewidth=2)
        plt.plot(df_history["date"], df_history["pred"], label="Прогноз", linewidth=2)
        for cp in self.change_points:
            plt.axvline(cp, color="red", linestyle="--", alpha=0.7)
        plt.xlabel("Дата")
        plt.ylabel("Сальдо")
        plt.title("Онлайн-прогноз с разладками и переобучениями")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

df = pd.read_csv("data/merged_dataset_with_lags_rollings.csv", parse_dates=["date"]).set_index("date")
X = df.drop(columns=["balance", "income", "outcome"])
y = df["balance"]
key_rate = df["rate"]#.fillna(0.085)

display(X.head())

pipeline = ModelPipeline(
    models_config,
    metric_func=mae_cust,  # или awmae
    optuna_direction="minimize",
    n_splits=2,
    n_trials=1,
    #extra_metrics=[calculate_add_margin_vectorized, delta_pnl]
)

runner = OnlineForecastRunner(
    model_pipeline=pipeline,
    cusum_detector=UniversalCUSUMDetector(mode="adaptive", threshold=5.0, drift=0.01),
    retrain_every_n_weeks=4,
    optuna_every_m_weeks=12,
    extra_metrics=[calculate_add_margin_vectorized, delta_pnl]
)

online_results = runner.run(
    X=X,
    y=y,
    key_rate=key_rate,
    start_date=pd.Timestamp("2020-09-01"),  # твоя стартовая дата
    model_name="LGBM"
)

print(online_results.mean())
# Out:
#             is_non_working_day  day_Friday  day_Saturday  day_Sunday  \
# date
# 2017-01-16                   0           0             0           0
# 2017-01-17                   0           0             0           0
# 2017-01-18                   0           0             0           0
# 2017-01-19                   0           0             0           0
# 2017-01-20                   0           1             0           0
#
#             day_Monday  day_Tuesday  day_Wednesday  day_Thursday  \
# date
# 2017-01-16           1            0              0             0
# 2017-01-17           0            1              0             0
# 2017-01-18           0            0              1             0
# 2017-01-19           0            0              0             1
# 2017-01-20           0            0              0             0
#
#             month_January  month_February  ...  6M_rollmean3  6M_rollstd3  \
# date                                       ...
# 2017-01-16              1               0  ...     10.590000     0.000000
# 2017-01-17              1               0  ...     10.566667     0.040415
# 2017-01-18              1               0  ...     10.536667     0.047258
# 2017-01-19              1               0  ...     10.506667     0.011547
# 2017-01-20              1               0  ...     10.500000     0.000000
#
#             6M_rollmin3  6M_rollmax3  6M_rollmed3  6M_rollmean7  6M_rollstd7  \
# date
# 2017-01-16        10.59        10.59        10.59     10.588571     0.003780
# 2017-01-17        10.52        10.59        10.59     10.580000     0.026458
# 2017-01-18        10.50        10.59        10.52     10.567143     0.039461
# 2017-01-19        10.50        10.52        10.50     10.554286     0.045040
# 2017-01-20        10.50        10.50        10.50     10.541429     0.045981
#
#             6M_rollmin7  6M_rollmax7  6M_rollmed7
# date
# 2017-01-16        10.58        10.59        10.59
# 2017-01-17        10.52        10.59        10.59
# 2017-01-18        10.50        10.59        10.59
# 2017-01-19        10.50        10.59        10.59
# 2017-01-20        10.50        10.59        10.52
#
# [5 rows x 238 columns]
# [I 2025-04-27 23:39:43,118] A new study created in memory with name: no-name-54641190-d441-4584-8d46-911c17b5b95e
# 🔧 Калибровка модели: LGBM
# Best trial: 0. Best value: 0.287225: 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# [I 2025-04-27 23:39:44,695] Trial 0 finished with value: 0.2872250433087576 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.2872250433087576.
# Топ-20 признаков для LGBM: ['balance_lag3', 'brent_cost_rollstd3', 'balance_rollstd3', 'ON_rollstd7', 'income_rollstd3', 'balance_rollstd7', 'gold_cost_rub_rollstd7', '3M_rollstd7', 'usd_rub_rollstd7', 'brent_cost_rollstd7', 'outcome_rollmean3', '2W_rollstd7', 'balance_lag1', '1W_rollstd7', 'balance_rollmean7', 'balance_rollmean3', 'usd_rub_rollstd3', '6M_rollstd7', 'gold_cost_rub_rollstd3', '1M_rollstd7']
# Нет тестовых данных. Обучение модели без теста.
# 2020-09-01 — MAE: 0.33773, mae_cust: 0.33773, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00024
# 2020-09-02 — MAE: 0.08063, mae_cust: 0.08063, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00019
# 2020-09-03 — MAE: 0.27698, mae_cust: 0.27698, calculate_add_margin_vectorized: 0.00003, delta_pnl: -0.00112
# 2020-09-04 — MAE: 0.24657, mae_cust: 0.24657, calculate_add_margin_vectorized: 0.00002, delta_pnl: -0.00064
# 2020-09-05 — MAE: 0.35938, mae_cust: 0.35938, calculate_add_margin_vectorized: 0.00005, delta_pnl: -0.00180
# 2020-09-06 — MAE: 0.08005, mae_cust: 0.08005, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00040
# 2020-09-07 — MAE: 0.06387, mae_cust: 0.06387, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.05384
# 2020-09-08 — MAE: 0.16091, mae_cust: 0.16091, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.09979
# 2020-09-09 — MAE: 0.29209, mae_cust: 0.29209, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.74116
# 2020-09-10 — MAE: 0.01976, mae_cust: 0.01976, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00028
# 2020-09-11 — MAE: 0.09135, mae_cust: 0.09135, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.50081
# 2020-09-12 — MAE: 0.01165, mae_cust: 0.01165, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00006
# 2020-09-13 — MAE: 0.06610, mae_cust: 0.06610, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00033
# 2020-09-14 — MAE: 0.03316, mae_cust: 0.03316, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.20495
# 2020-09-15 — MAE: 0.28055, mae_cust: 0.28055, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.91560
# 2020-09-16 — MAE: 0.07815, mae_cust: 0.07815, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.83549
# 2020-09-17 — MAE: 0.33747, mae_cust: 0.33747, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00050
# 2020-09-18 — MAE: 0.20448, mae_cust: 0.20448, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.42384
# 2020-09-19 — MAE: 0.01805, mae_cust: 0.01805, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.07688
# 2020-09-20 — MAE: 0.04068, mae_cust: 0.04068, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.17331
# 2020-09-21 — MAE: 0.11630, mae_cust: 0.11630, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.88632
# 2020-09-22 — MAE: 0.08209, mae_cust: 0.08209, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.29901
# 2020-09-23 — MAE: 0.02361, mae_cust: 0.02361, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.10570
# 2020-09-24 — MAE: 0.10479, mae_cust: 0.10479, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.05840
# 2020-09-25 — MAE: 0.01244, mae_cust: 0.01244, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.94644
# 2020-09-26 — MAE: 0.02189, mae_cust: 0.02189, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.09323
# 2020-09-27 — MAE: 0.01460, mae_cust: 0.01460, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00007
# ♻️ Плановое переобучение без Optuna на 2020-09-27.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['balance_rollstd3', 'income_rollstd3', 'usd_rub_rollstd7', 'balance_lag3', 'brent_cost_rollstd3', 'ON_rollstd7', 'gold_cost_rub_rollstd7', 'balance_rollmean7', 'balance_rollstd7', 'brent_cost_rollstd7', '3M_rollstd7', 'outcome_rollmean3', '2W_rollstd7', 'balance_lag1', 'income_lag1', 'gold_cost_rub_rollstd3', 'balance_rollmean3', 'outcome_lag1', '6M_rollstd7', 'usd_rub_rollstd3']
# Нет тестовых данных. Обучение модели без теста.
# 2020-09-28 — MAE: 0.08541, mae_cust: 0.08541, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.70188
# 2020-09-29 — MAE: 0.08762, mae_cust: 0.08762, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.26146
# 2020-09-30 — MAE: 0.07587, mae_cust: 0.07587, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.34989
# 2020-10-01 — MAE: 0.62505, mae_cust: 0.62505, calculate_add_margin_vectorized: 0.00003, delta_pnl: -0.00115
# 2020-10-02 — MAE: 0.08336, mae_cust: 0.08336, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00009
# 2020-10-03 — MAE: 0.02203, mae_cust: 0.02203, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.09385
# 2020-10-04 — MAE: 0.08645, mae_cust: 0.08645, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.36830
# 2020-10-05 — MAE: 0.00262, mae_cust: 0.00262, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.33504
# 2020-10-06 — MAE: 0.01234, mae_cust: 0.01234, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.45227
# 2020-10-07 — MAE: 0.00802, mae_cust: 0.00802, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.47064
# 2020-10-08 — MAE: 0.03151, mae_cust: 0.03151, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.41342
# 2020-10-09 — MAE: 0.07137, mae_cust: 0.07137, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.13632
# 2020-10-10 — MAE: 0.01248, mae_cust: 0.01248, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.05319
# 2020-10-11 — MAE: 0.11560, mae_cust: 0.11560, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.49245
# 2020-10-12 — MAE: 0.07570, mae_cust: 0.07570, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.21593
# 2020-10-13 — MAE: 0.10639, mae_cust: 0.10639, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.22960
# 2020-10-14 — MAE: 0.79049, mae_cust: 0.79049, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00053
# 2020-10-15 — MAE: 0.02176, mae_cust: 0.02176, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.09269
# 2020-10-16 — MAE: 0.07385, mae_cust: 0.07385, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.58286
# 2020-10-17 — MAE: 0.00035, mae_cust: 0.00035, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00148
# 2020-10-18 — MAE: 0.10530, mae_cust: 0.10530, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00053
# 2020-10-19 — MAE: 0.30688, mae_cust: 0.30688, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.54368
# 2020-10-20 — MAE: 0.01340, mae_cust: 0.01340, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.89471
# 2020-10-21 — MAE: 0.18552, mae_cust: 0.18552, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.38762
# 2020-10-22 — MAE: 0.30564, mae_cust: 0.30564, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.38070
# 2020-10-23 — MAE: 0.22347, mae_cust: 0.22347, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00013
# 2020-10-24 — MAE: 0.06004, mae_cust: 0.06004, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.25579
# 2020-10-25 — MAE: 0.01160, mae_cust: 0.01160, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.04940
# ♻️ Плановое переобучение без Optuna на 2020-10-25.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['balance_rollstd3', 'balance_rollmean7', 'gold_cost_rub_rollstd7', 'outcome_rollmean3', 'balance_lag3', 'income_rollstd3', 'brent_cost_rollstd3', 'balance_lag1', '3M_rollstd7', 'brent_cost_rollstd7', 'balance_rollstd7', 'outcome_rollstd3', 'usd_rub_rollstd3', 'ON_rollstd7', 'usd_rub_rollstd7', 'balance_rollmean3', 'income_lag1', 'is_non_working_day', '2M_rollstd7', 'outcome_lag1']
# Нет тестовых данных. Обучение модели без теста.
# 2020-10-26 — MAE: 0.72160, mae_cust: 0.72160, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.68411
# 2020-10-27 — MAE: 0.07655, mae_cust: 0.07655, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.55460
# 2020-10-28 — MAE: 0.34380, mae_cust: 0.34380, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.33997
# 2020-10-29 — MAE: 0.33457, mae_cust: 0.33457, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.93057
# 2020-10-30 — MAE: 0.07306, mae_cust: 0.07306, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.97887
# 2020-10-31 — MAE: 0.03875, mae_cust: 0.03875, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.24756
# 2020-11-01 — MAE: 0.02206, mae_cust: 0.02206, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00011
# 2020-11-02 — MAE: 0.69867, mae_cust: 0.69867, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.61350
# 2020-11-03 — MAE: 0.17167, mae_cust: 0.17167, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.12220
# 2020-11-04 — MAE: 0.09319, mae_cust: 0.09319, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.39698
# 2020-11-05 — MAE: 0.04862, mae_cust: 0.04862, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.48632
# 2020-11-06 — MAE: 0.09747, mae_cust: 0.09747, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.41521
# 2020-11-07 — MAE: 0.14975, mae_cust: 0.14975, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.63793
# 2020-11-08 — MAE: 0.10395, mae_cust: 0.10395, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.44285
# 2020-11-09 — MAE: 0.03814, mae_cust: 0.03814, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.23980
# [I 2025-04-27 23:39:51,248] A new study created in memory with name: no-name-6a542328-512c-4693-807d-bddc86044e4b
# 2020-11-10 — MAE: 0.37818, mae_cust: 0.37818, calculate_add_margin_vectorized: 0.00002, delta_pnl: -0.00071
# 2020-11-11 — MAE: 0.20621, mae_cust: 0.20621, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.54303
# 2020-11-12 — MAE: 0.10464, mae_cust: 0.10464, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00013
# 2020-11-13 — MAE: 0.36808, mae_cust: 0.36808, calculate_add_margin_vectorized: 0.00002, delta_pnl: -0.00066
# 2020-11-14 — MAE: 0.14007, mae_cust: 0.14007, calculate_add_margin_vectorized: 0.00002, delta_pnl: -0.00070
# 2020-11-15 — MAE: 0.05655, mae_cust: 0.05655, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.24091
# 2020-11-16 — MAE: 0.68535, mae_cust: 0.68535, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.34332
# 2020-11-17 — MAE: 0.09412, mae_cust: 0.09412, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.83306
# 2020-11-18 — MAE: 0.02079, mae_cust: 0.02079, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.20155
# 2020-11-19 — MAE: 0.07486, mae_cust: 0.07486, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.70979
# 2020-11-20 — MAE: 0.03613, mae_cust: 0.03613, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.68744
# 2020-11-21 — MAE: 0.02835, mae_cust: 0.02835, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00014
# 2020-11-22 — MAE: 0.03993, mae_cust: 0.03993, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.17009
# 🔧 Плановое переобучение с Optuna на 2020-11-22.
#
# 🔧 Калибровка модели: LGBM
# Best trial: 0. Best value: 0.320325: 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]
# [I 2025-04-27 23:39:52,983] Trial 0 finished with value: 0.3203253304587009 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.3203253304587009.
# Топ-20 признаков для LGBM: ['balance_lag3', 'brent_cost_rollstd3', 'balance_rollstd3', 'ON_rollstd7', 'gold_cost_rub_rollstd7', 'brent_cost_rollstd7', 'usd_rub_rollstd7', 'outcome_rollmean3', '3M_rollstd7', 'balance_rollmean3', 'gold_cost_rub_rollstd3', '1W_rollstd7', 'balance_rollstd7', 'usd_rub_rollstd3', '2W_rollstd7', 'balance_lag1', '1M_rollstd7', '6M_rollstd7', 'ON_rollstd3', 'income_rollstd7']
# Нет тестовых данных. Обучение модели без теста.
# 2020-11-23 — MAE: 0.18978, mae_cust: 0.18978, calculate_add_margin_vectorized: 0.00000, delta_pnl: -2.81872
# 2020-11-24 — MAE: 0.00549, mae_cust: 0.00549, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.97268
# 2020-11-25 — MAE: 0.65657, mae_cust: 0.65657, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.06368
# 2020-11-26 — MAE: 0.23731, mae_cust: 0.23731, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.56925
# 2020-11-27 — MAE: 0.02515, mae_cust: 0.02515, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.23905
# 2020-11-28 — MAE: 0.23997, mae_cust: 0.23997, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.02228
# 2020-11-29 — MAE: 0.17270, mae_cust: 0.17270, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.73572
# ♻️ Плановое переобучение без Optuna на 2020-11-29.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['gold_cost_rub_rollstd7', 'balance_rollmean7', 'brent_cost_rollstd3', 'brent_cost_rollstd7', 'income_rollstd3', '6M_rollstd7', 'balance_rollstd7', 'balance_lag3', 'balance_rollstd3', 'ON_rollstd7', 'usd_rub_rollstd7', '3M_rollstd7', 'usd_rub_rollstd3', 'income_lag1', 'balance_rollmean3', '2W_rollstd7', 'balance_lag1', 'outcome_rollmean3', '1W_rollstd7', 'is_non_working_day']
# Нет тестовых данных. Обучение модели без теста.
# 2020-11-30 — MAE: 0.02141, mae_cust: 0.02141, calculate_add_margin_vectorized: 0.00000, delta_pnl: -2.26462
# 2020-12-01 — MAE: 0.36746, mae_cust: 0.36746, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.63183
# 2020-12-02 — MAE: 0.02201, mae_cust: 0.02201, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.87556
# 2020-12-03 — MAE: 0.00232, mae_cust: 0.00232, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.88756
# 2020-12-04 — MAE: 0.00427, mae_cust: 0.00427, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.68829
# 2020-12-05 — MAE: 0.04458, mae_cust: 0.04458, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00022
# 2020-12-06 — MAE: 0.03144, mae_cust: 0.03144, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00016
# 2020-12-07 — MAE: 0.08151, mae_cust: 0.08151, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.57572
# 2020-12-08 — MAE: 0.28901, mae_cust: 0.28901, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.17109
# 2020-12-09 — MAE: 0.20725, mae_cust: 0.20725, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.99456
# 2020-12-10 — MAE: 0.20967, mae_cust: 0.20967, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.27823
# 2020-12-11 — MAE: 0.19009, mae_cust: 0.19009, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.00266
# 2020-12-12 — MAE: 0.21251, mae_cust: 0.21251, calculate_add_margin_vectorized: 0.00003, delta_pnl: -0.00106
# 2020-12-13 — MAE: 0.13254, mae_cust: 0.13254, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.56460
# 2020-12-14 — MAE: 0.11336, mae_cust: 0.11336, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.87291
# 2020-12-15 — MAE: 0.26381, mae_cust: 0.26381, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00020
# 2020-12-16 — MAE: 0.20101, mae_cust: 0.20101, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.46495
# 2020-12-17 — MAE: 0.55204, mae_cust: 0.55204, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00046
# 2020-12-18 — MAE: 0.13140, mae_cust: 0.13140, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00006
# 2020-12-19 — MAE: 0.10816, mae_cust: 0.10816, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00054
# 2020-12-20 — MAE: 0.05081, mae_cust: 0.05081, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.21647
# 2020-12-21 — MAE: 0.45301, mae_cust: 0.45301, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.54782
# 2020-12-22 — MAE: 0.13746, mae_cust: 0.13746, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.47904
# 2020-12-23 — MAE: 0.21433, mae_cust: 0.21433, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.46580
# 2020-12-24 — MAE: 0.12515, mae_cust: 0.12515, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.00175
# 2020-12-25 — MAE: 0.02770, mae_cust: 0.02770, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00039
# 2020-12-26 — MAE: 0.10872, mae_cust: 0.10872, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.00152
# 2020-12-27 — MAE: 0.32406, mae_cust: 0.32406, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.38049
# ♻️ Плановое переобучение без Optuna на 2020-12-27.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['balance_lag3', 'usd_rub_rollstd7', 'gold_cost_rub_rollstd7', '6M_rollstd7', 'balance_rollmean7', 'income_rollstd3', 'balance_rollstd3', 'ON_rollstd7', 'balance_lag1', 'brent_cost_rollstd7', 'brent_cost_rollstd3', '3M_rollstd7', '3M_rollstd3', 'usd_rub_rollstd3', 'balance_rollstd7', 'outcome_rollstd3', '2M_rollstd7', 'balance_rollmean3', 'is_non_working_day', 'outcome_rollmean3']
# Нет тестовых данных. Обучение модели без теста.
# 2020-12-28 — MAE: 0.40400, mae_cust: 0.40400, calculate_add_margin_vectorized: -0.00001, delta_pnl: -1.27376
# 2020-12-29 — MAE: 0.16221, mae_cust: 0.16221, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.63512
# 2020-12-30 — MAE: 0.17276, mae_cust: 0.17276, calculate_add_margin_vectorized: -0.00001, delta_pnl: -0.06507
# 2020-12-31 — MAE: 0.39681, mae_cust: 0.39681, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00047
# 2021-01-01 — MAE: 0.07362, mae_cust: 0.07362, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.31361
# 2021-01-02 — MAE: 0.00103, mae_cust: 0.00103, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00001
# 2021-01-03 — MAE: 0.00047, mae_cust: 0.00047, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00200
# 2021-01-04 — MAE: 0.14385, mae_cust: 0.14385, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00677
# 2021-01-05 — MAE: 0.07566, mae_cust: 0.07566, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.37395
# 2021-01-06 — MAE: 0.09910, mae_cust: 0.09910, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.42360
# 2021-01-07 — MAE: 0.08894, mae_cust: 0.08894, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.37888
# 2021-01-08 — MAE: 0.05507, mae_cust: 0.05507, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.31530
# 2021-01-09 — MAE: 0.08626, mae_cust: 0.08626, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.36746
# 2021-01-10 — MAE: 0.11728, mae_cust: 0.11728, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.49963
# 2021-01-11 — MAE: 0.10787, mae_cust: 0.10787, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.63221
# 2021-01-12 — MAE: 0.74896, mae_cust: 0.74896, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.62363
# 2021-01-13 — MAE: 0.13536, mae_cust: 0.13536, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.20865
# 2021-01-14 — MAE: 0.16464, mae_cust: 0.16464, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.08391
# 2021-01-15 — MAE: 0.47712, mae_cust: 0.47712, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.94031
# 2021-01-16 — MAE: 0.06840, mae_cust: 0.06840, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.29139
# 2021-01-17 — MAE: 0.06493, mae_cust: 0.06493, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.27662
# 2021-01-18 — MAE: 0.43924, mae_cust: 0.43924, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.66257
# 2021-01-19 — MAE: 0.09069, mae_cust: 0.09069, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.24029
# 2021-01-20 — MAE: 0.08039, mae_cust: 0.08039, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.06838
# 2021-01-21 — MAE: 0.09908, mae_cust: 0.09908, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.20456
# 2021-01-22 — MAE: 0.48916, mae_cust: 0.48916, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.77682
# 2021-01-23 — MAE: 0.03458, mae_cust: 0.03458, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.26334
# 2021-01-24 — MAE: 0.02135, mae_cust: 0.02135, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00011
# ♻️ Плановое переобучение без Optuna на 2021-01-24.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['balance_lag3', 'brent_cost_rollstd7', '6M_rollstd7', 'usd_rub_rollstd7', 'balance_rollstd3', 'balance_rollmean7', 'gold_cost_rub_rollstd7', 'is_non_working_day', '3M_rollstd7', '2W_rollstd7', 'balance_lag1', 'income_rollstd3', 'outcome_rollmean3', 'outcome_lag1', 'brent_cost_rollstd3', 'balance_rollmean3', 'outcome_rollstd3', 'income_lag1', 'ON_rollstd3', 'ON_rollstd7']
# Нет тестовых данных. Обучение модели без теста.
# 2021-01-25 — MAE: 0.71976, mae_cust: 0.71976, calculate_add_margin_vectorized: 0.00000, delta_pnl: -2.31857
# 2021-01-26 — MAE: 0.01599, mae_cust: 0.01599, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.50243
# 2021-01-27 — MAE: 0.03057, mae_cust: 0.03057, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.85618
# 2021-01-28 — MAE: 0.31993, mae_cust: 0.31993, calculate_add_margin_vectorized: -0.00003, delta_pnl: -0.18886
# 2021-01-29 — MAE: 0.25525, mae_cust: 0.25525, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.65147
# 2021-01-30 — MAE: 0.07885, mae_cust: 0.07885, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.33589
# 2021-01-31 — MAE: 0.00148, mae_cust: 0.00148, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00001
# 2021-02-01 — MAE: 0.03336, mae_cust: 0.03336, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.76499
# 2021-02-02 — MAE: 0.15629, mae_cust: 0.15629, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.01693
# 2021-02-03 — MAE: 0.30818, mae_cust: 0.30818, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.70645
# 2021-02-04 — MAE: 0.29381, mae_cust: 0.29381, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.37502
# 2021-02-05 — MAE: 0.11230, mae_cust: 0.11230, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.75761
# 2021-02-06 — MAE: 0.02001, mae_cust: 0.02001, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.08522
# 2021-02-07 — MAE: 0.05636, mae_cust: 0.05636, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.24008
# 2021-02-08 — MAE: 0.48473, mae_cust: 0.48473, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.30054
# 2021-02-09 — MAE: 0.20133, mae_cust: 0.20133, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.32987
# 2021-02-10 — MAE: 0.42044, mae_cust: 0.42044, calculate_add_margin_vectorized: -0.00002, delta_pnl: -0.84064
# 2021-02-11 — MAE: 0.23025, mae_cust: 0.23025, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00049
# 2021-02-12 — MAE: 0.41085, mae_cust: 0.41085, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00034
# 2021-02-13 — MAE: 0.00611, mae_cust: 0.00611, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.02601
# 2021-02-14 — MAE: 0.10703, mae_cust: 0.10703, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00054
# 🔧 Плановое переобучение с Optuna на 2021-02-14.
#
# 🔧 Калибровка модели: LGBM
# [I 2025-04-27 23:40:01,513] A new study created in memory with name: no-name-b17ae090-280b-4cc9-add0-1cd3ef4f00ae
# Best trial: 0. Best value: 0.361513: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# [I 2025-04-27 23:40:02,863] Trial 0 finished with value: 0.3615125186145058 and parameters: {'n_estimators': 144, 'learning_rate': 0.28570714885887566, 'max_depth': 21}. Best is trial 0 with value: 0.3615125186145058.
# Топ-20 признаков для LGBM: ['balance_lag3', 'balance_rollstd3', 'brent_cost_rollstd7', 'balance_rollmean7', 'brent_cost_rollstd3', 'ON_rollstd7', 'usd_rub_rollstd7', '6M_rollstd7', 'gold_cost_rub_rollstd7', 'balance_lag1', '2W_rollstd7', 'balance_rollmean3', '1W_rollstd7', 'outcome_rollmean3', '3M_rollstd7', 'balance_rollstd7', 'gold_cost_rub_rollstd3', 'usd_rub_rollstd3', '1M_rollstd7', 'income_rollstd3']
# Нет тестовых данных. Обучение модели без теста.
# 2021-02-15 — MAE: 0.48574, mae_cust: 0.48574, calculate_add_margin_vectorized: 0.00000, delta_pnl: -3.29775
# 2021-02-16 — MAE: 0.03876, mae_cust: 0.03876, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.17025
# 2021-02-17 — MAE: 0.09297, mae_cust: 0.09297, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.38922
# 2021-02-18 — MAE: 0.28995, mae_cust: 0.28995, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.78409
# 2021-02-19 — MAE: 0.35271, mae_cust: 0.35271, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.57281
# 2021-02-20 — MAE: 0.13277, mae_cust: 0.13277, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.61231
# 2021-02-21 — MAE: 0.37074, mae_cust: 0.37074, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.57934
# ♻️ Плановое переобучение без Optuna на 2021-02-21.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['income_rollstd3', 'balance_rollmean7', 'gold_cost_rub_rollstd7', 'balance_rollstd3', 'brent_cost_rollstd3', 'usd_rub_rollstd7', 'balance_lag1', 'brent_cost_rollstd7', 'gold_cost_rub_rollstd3', 'balance_lag3', 'ON_rollstd7', 'balance_rollstd7', 'is_non_working_day', 'outcome_lag1', 'outcome_rollstd3', 'outcome_rollmean3', '1M_rollstd7', '2M_rollstd7', 'balance_rollmean3', 'ON_rollstd3']
# Нет тестовых данных. Обучение модели без теста.
# 2021-02-22 — MAE: 0.31981, mae_cust: 0.31981, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.40362
# 2021-02-23 — MAE: 0.11932, mae_cust: 0.11932, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.50832
# 2021-02-24 — MAE: 0.75678, mae_cust: 0.75678, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.53422
# 2021-02-25 — MAE: 0.13507, mae_cust: 0.13507, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.66825
# 2021-02-26 — MAE: 0.18704, mae_cust: 0.18704, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.71766
# 2021-02-27 — MAE: 0.00860, mae_cust: 0.00860, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00004
# 2021-02-28 — MAE: 0.08271, mae_cust: 0.08271, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00041
# 2021-03-01 — MAE: 0.52696, mae_cust: 0.52696, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.51325
# 2021-03-02 — MAE: 0.14508, mae_cust: 0.14508, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.28906
# 2021-03-03 — MAE: 0.05247, mae_cust: 0.05247, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.22866
# 2021-03-04 — MAE: 0.23298, mae_cust: 0.23298, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.93658
# 2021-03-05 — MAE: 0.20069, mae_cust: 0.20069, calculate_add_margin_vectorized: -0.00000, delta_pnl: -0.79901
# 2021-03-06 — MAE: 0.05951, mae_cust: 0.05951, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.25352
# 2021-03-07 — MAE: 0.05513, mae_cust: 0.05513, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00028
# 2021-03-08 — MAE: 0.41040, mae_cust: 0.41040, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.74838
# 2021-03-09 — MAE: 1.07983, mae_cust: 1.07983, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.72860
# 2021-03-10 — MAE: 0.31383, mae_cust: 0.31383, calculate_add_margin_vectorized: -0.00000, delta_pnl: -1.22512
# 2021-03-11 — MAE: 0.16691, mae_cust: 0.16691, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.63515
# 2021-03-12 — MAE: 0.37296, mae_cust: 0.37296, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.71094
# 2021-03-13 — MAE: 0.11387, mae_cust: 0.11387, calculate_add_margin_vectorized: 0.00001, delta_pnl: -0.00057
# 2021-03-14 — MAE: 0.01777, mae_cust: 0.01777, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.07570
# 2021-03-15 — MAE: 0.17526, mae_cust: 0.17526, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.88969
# 2021-03-16 — MAE: 0.07138, mae_cust: 0.07138, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.88348
# 2021-03-17 — MAE: 0.33844, mae_cust: 0.33844, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.29706
# 2021-03-18 — MAE: 0.28260, mae_cust: 0.28260, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.75933
# 2021-03-19 — MAE: 0.21279, mae_cust: 0.21279, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.61762
# 2021-03-20 — MAE: 0.13787, mae_cust: 0.13787, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.58732
# 2021-03-21 — MAE: 0.13125, mae_cust: 0.13125, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.55912
# ♻️ Плановое переобучение без Optuna на 2021-03-21.
#
# ⚡ Обучение LGBM без тюнинга (параметры по умолчанию)
# Топ-20 признаков для LGBM: ['gold_cost_rub_rollstd7', '3M_rollstd7', 'balance_lag3', 'income_rollstd3', 'brent_cost_rollstd3', 'brent_cost_rollstd7', 'usd_rub_rollstd7', 'ON_rollstd7', 'balance_rollmean7', 'balance_rollstd3', 'outcome_rollmean3', 'balance_rollmean3', 'balance_lag1', 'income_lag1', '1W_rollstd7', 'is_non_working_day', 'usd_rub_rollstd3', '2M_rollstd7', 'outcome_lag1', 'balance_rollstd7']
# Нет тестовых данных. Обучение модели без теста.
# 2021-03-22 — MAE: 0.28725, mae_cust: 0.28725, calculate_add_margin_vectorized: 0.00000, delta_pnl: -2.38624
# 2021-03-23 — MAE: 0.31402, mae_cust: 0.31402, calculate_add_margin_vectorized: -0.00001, delta_pnl: -1.00182
# 2021-03-24 — MAE: 0.54191, mae_cust: 0.54191, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.22823
# 2021-03-25 — MAE: 0.64512, mae_cust: 0.64512, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.00979
# 2021-03-26 — MAE: 2.39702, mae_cust: 2.39702, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.53160
# 2021-03-27 — MAE: 0.00095, mae_cust: 0.00095, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.00430
# 2021-03-28 — MAE: 0.01181, mae_cust: 0.01181, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.05325
# 2021-03-29 — MAE: 0.82205, mae_cust: 0.82205, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.86503
# 2021-03-30 — MAE: 0.06265, mae_cust: 0.06265, calculate_add_margin_vectorized: 0.00000, delta_pnl: -1.40606
# 2021-03-31 — MAE: 0.13025, mae_cust: 0.13025, calculate_add_margin_vectorized: 0.00000, delta_pnl: -0.58745
# date                               2020-12-15 12:00:00
# real                                         -0.209618
# pred                                         -0.127593
# MAE                                           0.194813
# mae_cust                                      0.194813
# calculate_add_margin_vectorized               0.000001
# delta_pnl                                    -0.622996
# dtype: object
